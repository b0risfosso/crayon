# %%
from search import search_library
import random
from dotenv import load_dotenv
from openai import OpenAI, OpenAIError
import os

def ask(sys_msg, usr_msg):
    resp = client.chat.completions.create(
        model=OPENAI_MODEL,
        messages=[
            {"role": "system", "content": sys_msg},
            {"role": "user", "content": usr_msg}
        ]
    )
    return resp.choices[0].message.content

def sample_text(text, x):
    max_start = max(0, len(text) - x)
    random_start = random.randint(0, max_start)
    excerpt = text[random_start:random_start + x]
    return excerpt


load_dotenv()
client = OpenAI()
OPENAI_MODEL = os.getenv("OPENAI_MODEL", "o4-mini-2025-04-16")
DB_FILE = "library.sqlite"
MAX_RESULTS = 100

# %%
KEYWORDS = ["hindgut morphogenesis", "hindgut", "active tension network"]
search_results = search_library(DB_FILE, KEYWORDS, MAX_RESULTS, match_all=False)
hindgut = {}
for r in search_results:
    title, text = r['title'], r['text']
    hindgut[title] = text


rem = ["Electrical Stimulation for Pelvic Floor Disorders", None, "Fundamental Neuroscience (3rd edition)", "Clinical Emergency Medicine", "Harrison's Principles of Internal Medicine 15th Edition"]
for r in rem:
    if r in hindgut:
        del hindgut[r]

for title, text in hindgut.items():
    print(title)
# Out:
# The Drosophila actin nucleator DAAM is essential for left-right asymmetry
# Myosin1D is an evolutionarily conserved regulator of animal left–right asymmetry
# An unconventional myosin in Drosophila reverses the default handedness in visceral organs
# Chiral cell sliding drives left-right asymmetric organ twisting
# Cell Chirality Drives Left-Right Asymmetric Morphogenesis
# Chirality in Planar Cell Shape Contributes to Left-Right Asymmetric Epithelial Morphogenesis
# Vertebrate myosin 1d regulates left–right organizer morphogenesis and laterality
# Active Tension Network Model in Epithelial Tissues
# The Geometric Basis of Epithelial Convergent Extension
# Distinct Cellular and Junctional Dynamics Independently Regulate the Rotation and Elongation of the Embryonic Gut in Drosophila
# Genital disc growth in Drosophila
# Understanding Laterality Disorders and the Left-Right Organizer: Insights from Zebrafish
# Generating Active T1 Transitions through Mechanochemical Feedback
# Left–right Myosin-Is, Myosin1C, and Myosin1D exhibit distinct single molecule behaviors on the plasma membrane of Drosophila macrophages
# Developmental Biology, 7th Edition
# It Takes Guts: The Drosophila Hindgut as a Model System for Organogenesis

# %%
for _ in range(3):
    n = random.randint(0, len(hindgut)-1)
    title, text = list(hindgut.keys())[n], list(hindgut.values())[n]
    excerpt = sample_text(text, 10000)
    act1 = ask("If I have a lightsheet imaging dataset of hindgut development over time, what hypothesis driven inquires should be performed based the following information?", excerpt)
    act2 = ask("If I have a 2D movie of the developing Drosophila hindgut acquired by identifying and unraveling the apical surface of the epithelial tissue of a lightsheet dataset of developing hindgut, what hypothesis driven inquires should be performed based on the following information?", excerpt)
    
    print("\n\nACT 1:\n", act1)
    print("\n\nACT 2:\n", act2)
# Out:
# ACT 1:
#  Here is a set of hypothesis-driven inquires you can address with your lightsheet time-lapse of hindgut development.  Each question ties back to one or more of the loci or processes in your table, points to a measurable imaging readout, and suggests what you would expect if the hypothesis is correct.
#
# 1.    Primordium formation and maintenance (byn/Brachyury, fkh/HNF-3, wg/Wnt)
#   •  Hypothesis: early wg and fkh activities are required to maintain the hindgut primordium by preventing apoptosis and driving cell internalization.
#   •  Imaging assay: follow a byn>GFP or fkh>GFP reporter through gastrulation and early gut invagination.  Overlay with a live apoptosis marker (e.g. caspase sensor) and track cell delamination events.
#   •  Readouts:
#      –  Number and position of apoptotic cells compared to wild type.
#      –  Degree of basal extrusion or collapse of the primordium in loss-of-function or T-s wg mutants.
#   •  Expected if hypothesis holds: increased apoptotic/cell-loss events in primordium, failure to maintain a contiguous sheet of gut cells.
#
# 2.    Small intestine elongation (drm, lin, D/Sox, upd/JAK-STAT):
#   •  Hypothesis A (drm, lin, D): these nuclear transcription factors coordinate polarized cell intercalation in the small intestine region.
#   •  Imaging assay: use membrane label (e.g. E-cad::GFP) to segment individual epithelial cells in the elongating mid/hindgut.  Compute cell neighbor exchanges (“T1 transitions”), planar cell polarity (cell long axis orientation) over time in wild type and drm/lin/D mutants.
#   •  Readouts:
#      –  Rate of T1 transitions per unit length.
#      – Distribution of cell aspect ratios and their alignment with the AP axis.
#   •  Expected: mutants will show fewer intercalations and/or more isotropic cell shapes, correlating with shorter, wider gut.
#
#   •  Hypothesis B (upd/JAK-STAT): a gradient of Upd specifies the rate of posterior proliferation contributing to elongation.
#   •  Imaging assay: co-image a nuclear cell-cycle sensor (e.g. FUCCI) with an upd reporter and track cell-cycle length along the AP axis.
#   •  Readouts: spatial map of cell-cycle timing vs. upd expression domain.
#   •  Expected: loss of upd reduces posterior mitoses and slows elongation; ectopic upd accelerates local cycles.
#
# 3.    Boundary cell specification (en, otp, Dl/Notch, Ser):
#   •  Hypothesis: Notch signaling via Dl/Ser downstream of en and otp establishes the hindgut/large-intestine boundary.
#   •  Imaging assay: time-lapse Notch activity reporter (e.g. Su(H)::GFP) in wild type and Dl or Ser mutants, plus a boundary cell marker (e.g. Fas3).
#   •  Readouts:
#      – Onset and spatial precision of Notch reporter activation.
#      – Emergence and persistence of boundary cell morphology (e.g. cell size, shape, position).
#   •  Expected: Dl mutants will never activate boundary reporter and boundary cells will never acquire their characteristic wedge shape; Ser mutants may activate but fail to maintain boundary.
#
# 4.    Large-intestine patterning and growth (wg/Wnt, hh/Hh, dpp/BMP, raw, mmy):
#   •  Hypothesis: wg and hh jointly maintain the proliferative zone in the rectum and large intestine, while dpp controls endoreplication in the large intestine epithelium.
#   •  Imaging assay: combine membrane and nuclear markers with reporters for Wnt, Hh, and BMP pathway activity.  Use a DNA content sensor to distinguish endoreplicating cells.
#   •  Readouts:
#      – Regional proliferation index vs. reporter levels.
#      – Timing and extent of endocycles in large intestine cells in dpp mutants.
#   •  Expected: wg or hh loss shrinks the proliferative zone and arrests gut elongation; dpp loss prevents endoreplication so nuclei remain 2C.
#
# 5.    Epithelial polarity and lumen morphology (crb, fas, rib):
#   •  Hypothesis A (crb): Crumbs is required to establish apical surface and maintain epithelial integrity; its loss causes focal breaks and lumen collapse.
#   •  Imaging assay: apical marker (aPKC::GFP) plus basolateral marker (Dlg::RFP) to report polarity in real time.  Examine crb mutants for junctional continuity and lumen cross-section.
#   •  Readouts:
#      – Frequency of apical discontinuities.
#      – Lumen diameter variability and local bulges.
#   •  Expected: crb mutants show fragmented apical domain and focal lumen constrictions.
#
#   •  Hypothesis B (fas): Fas2-mediated adhesion is required to hold large intestine cells together under elongation tension.
#   •  Imaging assay: fluorescently tag Fas2, track cell–cell overlap surfaces, quantify intercellular gap formation under extension.
#   •  Readouts: number and size of intercellular gaps; correlation with local elongation strain.
#   •  Expected: fas mutants show increased gaps and uneven lumen shape.
#
#   •  Hypothesis C (rib): Rib regulates cell shape/movement at the boundary of small vs. large intestine.
#   •  Imaging assay: track individual border cells with membrane label; compute speed and directionality in wild type vs. rib mutants.
#   •  Readouts: average speed, persistence of migration, final cell arrangements.
#   •  Expected: rib mutants move less or lose directionality, leading to more squamous epithelial regions.
#
# 6.    Cell division and cycle control (thr, phm/exo):
#   •  Hypothesis A (thr): Thr is required for proper sister-chromatid separation during hindgut mitoses; its loss causes aneuploidy or mitotic delay.
#   •  Imaging assay: label chromatin (H2A::GFP) and microtubules (Tubulin::RFP) to follow mitotic figures in vivo.  Measure mitotic duration, lagging chromosomes, cytokinesis failures in thr mutants.
#   •  Readouts:
#      – Time from NEBD to anaphase onset;
#      – Frequency of lagging/chained chromatids;
#      – Rate of binucleate cells.
#   •  Expected: thr mutants show prolonged mitosis and increased chromosome segregation errors.
#
#   •  Hypothesis B (phm): Phm affects the number of cells contributing to elongation; loss causes altered cell-cycle exit or extra divisions yielding hypercurved gut.
#   •  Imaging assay: count total epithelial cell number over time in exo mutants vs. control, track division planes orientation.
#   •  Readouts: final cell count, spatial distribution of extra divisions, curvature quantification.
#   •  Expected: exo mutants show extra divisions localized to a domain, resulting in localized bending.
#
# 7.    RNA processing/spliceosome function (crn/yok):
#   •  Hypothesis: Yok is required to process mRNAs that drive elongation; its loss yields narrow, rugose lumen due to mis-spliced adhesion or cytoskeletal regulators.
#   •  Imaging assay: use a photoconvertible mRNA splicing reporter (if available) or co-image tagged cytoskeletal proteins (e.g. actin) in yok mutants, quantifying cell shape changes.
#   •  Readouts: changes in cortical actin organization, cell height vs. width ratios, lumen surface roughness.
#   •  Expected: yok mutants show altered cortical cytoskeleton, creating “rugose” lumen walls and impaired elongation.
#
# General strategy for all inquiries
#  •  Generate time-resolved, cell-level quantitative maps of (1) cell shape and neighbor topology, (2) division timing and orientation, (3) reporter activity for polarity/signaling/transcription, (4) apoptosis or extrusion events, and (5) tissue-level metrics (length, width, curvature).
#  •  For each gene/condition, compare these metrics to wild type using automated segmentation and tracking.
#  •  Link deviations directly to the hypothesized molecular function (e.g. decreased T1 intercalations when a TF for PCP is lost; failed apical constriction when Crumbs is missing).
#
# By systematically pairing genetic perturbations with these live-imaging assays you will both test the roles suggested by the table and uncover the dynamic cellular behaviors that underlie hindgut morphogenesis.
#
#
# ACT 2:
#  Below is a menu of hypothesis-driven questions you can attack with your 2D time-lapse of the hindgut apical surface, together with the key genetic perturbations and the kinds of measurements you would make in each case.  Most of these capitalize on your ability to segment and track every apical cell as the hindgut elongates and as boundary cells and the visceral-mesoderm interface form.
#
# 1.  Role of the “cassette” (byn/D, cad/Cdx, wg/Wnt, fkh/HNF-3) in convergent‐extension–type intercalations
#     Hypothesis: byn and wg drive anisotropic neighbor exchanges (T1 transitions) that underlie elongation.
#     Experiment: compare the frequency and orientation of T1 events, cell aspect ratio trajectories, and overall gut aspect‐ratio increase in wild‐type vs. byn or wg mutants (temperature‐sensitive or RNAi).
#     Readout: reduced directional T1s and more isotropic cell shapes in mutants.
#
# 2.  cad family in small-intestine domain elongation
#     Hypothesis: cad mutants (7, 8; drm alleles) fail to repress a proximal transcriptional program and thus show broader, slower elongation.
#     Experiment: image drm mutants (shorter, wider) and quantitate per-cell strain rates (Δlength/Δtime along A–P vs. D–V).
#     Readout: reduced ΔAP strain coupled with increased ΔDV strain relative to WT.
#
# 3.  fkh/HNF-3 in epithelial survival and maintenance of apical area
#     Hypothesis: in fkh mutants cells undergo apical contraction and delamination/apoptosis, halting elongation.
#     Experiment: use a caspase‐reporter or nuclear fragmentation marker in fkh mutant movies and quantify the timing and location of cell loss.  Measure cell apical‐area trajectories preceding apoptosis.
#     Readout: spikes of apical‐area collapse followed by disappearance, correlating with failed local extension.
#
# 4.  Boundary-cell specification (en, otp, Dl, Ser, hh)
#     Hypothesis: Notch‐ and Hh-pathway inputs regulate when and where boundary cells emerge, and boundary cells have distinct intercalation dynamics.
#     Experiment: in Dl or Ser mutants (extreme or normal boundary defects respectively), segment the boundary cell row(s) via an en>GFP or otp>GFP reporter.  Track their intercalation vs. neighbors and compare cell‐shape changes.
#     Readout: in Dl mutants boundary cells fail to adopt elongated/tipped morphology and show aberrant neighbor‐exchange patterns.
#
# 5.  Visceral‐mesoderm→epithelium signaling (bap, hh, wg, dpp, upd)
#     Hypothesis: signals from the visceral mesoderm polarize epithelial cells and orient their elongation.
#     Experiment: label both tissues (e.g. Ecad–GFP in epithelium, Twist–RFP in mesoderm).  In bap or upd mutants (shorter, wider), test whether the onset of planar‐polarity (e.g. tricellular‐junction alignment) is lost/delayed.
#     Readout: absence or reduction of global alignment of cell long axes towards the A–P axis.
#
# 6.  Apical polarity (crb, raw, mmy)
#     Hypothesis: crb is needed to maintain a coherent apical domain; loss leads to transient apical ruptures visible as holes or cell shape collapse.
#     Experiment: in crb mutants, track apical junction continuity over time and quantify “gaps” or sudden changes in perimeter.
#     Readout: increased frequency of apical discontinuities and associated local failure of elongation.
#
# 7.  Cell‐division orientation (thr, rib)
#     Hypothesis: oriented mitoses contribute to net tissue elongation.  thr (sister-chromatid sep.) mutants have altered division angles.
#     Experiment: identify mitotic figures in your movie (condensed chromosomes) or use H2B–GFP and measure the angle between the division axis and the gut’s A–P axis in WT vs. thr mutants.
#     Readout: loss of bias toward divisions parallel to the elongation axis in thr mutants.
#
# 8.  Lumen morphogenesis (crn/yok, phm/exo)
#     Hypothesis: crn mutants produce a narrow, rugose lumen by altering epithelial cell packing; phm mutants lengthen the gut by adding cells or extra convergent‐extension.
#     Experiment: segment the lumen contour in crn or phm movies and compute curvature and total length over time.  Also track neighbor topologies to see if rosette‐like rearrangements are increased or stalled.
#     Readout: aberrant curvature fluctuations in crn; super‐normal neighbor‐exchange rates in phm.
#
# 9.  Cross‐talk among cassette genes—epistasis in cell‐behavior space
#     Hypothesis: wg→byn and byn→wg regulatory loops set up the timing of cell intercalation waves.
#     Experiment: build double‐mutant or mosaic clones (e.g. byn−/− patches in a wgts background) and map local extension rates and neighbor exchanges in and around the clone.
#     Readout: disrupted wave‐front of intercalations emanating from the primordium.
#
# 10.  Quantitative comparison of strain fields under different signaling inputs (JAK/STAT vs. BMP)
#     Hypothesis: upd (JAK/STAT) and dpp (BMP) tune the magnitude but not the orientation of cell‐shape changes.
#     Experiment: calculate per-cell local strain tensors in upd vs. dpp mutants and compare eigenvalue magnitudes (total shape change) and eigenvector angles.
#     Readout: upd mutants show reduced total strain magnitude; dpp mutants show normal magnitude but slight rotation of strain axis.
#
# In each case you leverage your apical‐surface movie for
# – cell segmentation and neighbor‐exchange analysis
# – cell‐shape and area/aspect‐ratio trajectories
# – division‐angle measurements
# – apoptosis or delamination events
# – lumen‐contour morphometrics
# and (where possible) co-imaging of fluorescent reporters for gene expression or tissue identity.  Together, these hypothesis-driven inquiries will link each gene’s known transcriptional or signaling function to the dynamic cell‐biological behaviors that sculpt the elongating hindgut.
# ACT 1:
#  Below is a non‐exhaustive list of hypothesis–driven questions you can address with your 4D lightsheet dataset of Drosophila hindgut morphogenesis.  I’ve grouped them by theme—signaling/genetic inputs, cell behaviors, and tissue‐level mechanics—and sketched out the kind of analysis you’d need to test each one.
#
# 1. Signaling and gene‐regulatory inputs
#    a. Hedgehog (Hh)→Bmp-4→Hox at the hindgut tip (after Roberts et al. 1995)
#       Hypothesis: endodermal Hh induces a posterior Bmp/Hox domain that drives terminal cell fates.
#       Test: image a Hh reporter (e.g. hh-GFP) and a Bmp/Hox transcriptional reporter in the same embryo; correlate signaling‐domain size/intensity with cell‐fate marker onset and local proliferation rates.  Compare wild-type vs tissue‐specific Hh inhibition (e.g. ptc overexpression).
#    b. Wnt/Wingless (Wg) control of regional proliferation (after Skaer & Martinez-Arias 1992, Takashima & Murakami 2001)
#       Hypothesis: a graded Wg signal from the ectoderm controls the anterior–posterior proliferation gradient in the hindgut epithelium.
#       Test: co–image Wg reporter and a cell‐cycle sensor (e.g. FUCCI).  Quantify local mitotic index vs reporter intensity over time.  Perturb Wg signaling (RNAi or wg temperature‐sensitive) and re‐measure.
#    c. Brachyenteron (byn) and gut regionalization (after Singer et al. 1996)
#       Hypothesis: byn expression domain delineates midgut–hindgut boundary and guides cell rearrangements during tube twisting.
#       Test: use byn-GFP knock-in; segment cells inside vs just outside the byn domain; compare cell intercalation rates and oriented divisions.  In byn mutants, quantify disruption in cell neighbor‐exchange and final tube morphology.
#    d. Dichaete/Sox in hindgut cell identity (after Sanchez-Soriano & Russell 2000)
#       Hypothesis: Dichaete regulates late epithelial differentiation and barrier formation.
#       Test: co–image a barrier‐function reporter (e.g. septate junction marker) and Dichaete reporter.  Assess timing of junction assembly in WT vs Dichaete knockdown.
#
# 2. Cell‐biological behaviors
#    a. Oriented cell division and tube elongation (Smith & Orr-Weaver 1991)
#       Hypothesis: transition to endocycles (polyteny) in hindgut cells correlates with a switch from elongation by division to elongation by cell shape change.
#       Test: track divisions in 3D; measure spindle orientation; measure cell aspect ratio before/after the mitotic‐to‐endocycle transition; quantify contribution of cell‐shape‐driven elongation vs. proliferation to overall tube length.
#    b. Epithelial cell rearrangement (Tepass et al. 1996; Tepass & Hartenstein 1994)
#       Hypothesis: Crumbs‐dependent apical polarity is required for neighbor exchanges during tube bending.
#       Test: visualize apical markers (Crb::GFP or E-cad::GFP) plus cell outlines; automatically detect T1 transitions; compare frequency and directionality in WT vs crumbs mutants.
#    c. Collective cell migration and twisting (Shim et al. 2001 on ribbon; San Martin & Bate 2001 on mesoderm–endoderm interactions)
#       Hypothesis: visceral mesoderm provides a migratory substrate/template that guides endoderm invagination and hindgut looping.
#       Test: dual‐color labeling of endoderm vs mesoderm; track relative displacements; laser‐ablate segments of the mesoderm at specific timepoints and measure resulting changes in endodermal trajectories and final gut curvature.
#
# 3. Tissue‐level mechanics and morphometrics
#    a. Tissue curvature and tension during loop formation
#       Hypothesis: anisotropic tissue stress drives the characteristic 180° twist of the hindgut.
#       Test: reconstruct the 3D centerline of the hindgut tube at each timepoint; compute local curvature and torsion; correlate with local cell‐shape anisotropy (from cell segmentation).  Use optogenetic modulation of Myosin II to alter tension and re‐measure curvature dynamics.
#    b. Volume changes and lumen formation (Poole & Steinberg 1981)
#       Hypothesis: directed fluid secretion into the forming lumen drives epithelial thinning and tube expansion.
#       Test: measure epithelial cell volume from membranes and nuclear markers; quantify lumen volume over time; perturb Na/K‐ATPase function (chemical inhibitor) and assay effects on cell volume dynamics and lumen inflation.
#    c. Apoptosis‐driven remodeling
#       Hypothesis: localized cell death sculpts the final hindgut morphology at metamorphosis (Robertson 1936).
#       Test: include a caspase reporter (e.g. CaspaseTracker) in your time series; map apoptotic events onto morphogenetic landmarks.  Genetically block apoptosis (p35 expression) and quantify defects in tube pruning or shape refinement.
#
# 4. Integration & comparative approaches
#    a. Cross‐species regulatory logic (Peterson et al. 1999 a/b; Technau & Bode 1999)
#       Hypothesis: core network topology (e.g. Brachyury→Wnt11→cell‐polarity) is conserved in hindgut across insects and basal deuterostomes.
#       Test: if you have e.g. Tribolium or a basal insect line, replicate live imaging with analogous reporters and compare timing and spatial arrangement of network‐driven behaviors.
#    b. Axis‐defining signals and cell‐polarity readouts (Ruiz i Altaba et al. 1993; Sasaki & Hogan 1993)
#       Hypothesis: dorsoventral patterning cues (e.g. Dpp, Sog) intersect with AP‐patterning in specifying the gut’s circumferential cell polarity.
#       Test: combine Dpp/Sog reporters with fluorescent polarity markers (Bazooka/PAR3); map co‐localization to cell neighbor topology over time; genetically shift Dpp gradients and see whether cells reorient their polarity axes.
#
# General notes on turning these into true hypothesis tests:
#  • Always include a quantitative readout (cell shape, neighbor exchange rate, fluorescence intensity).
#  • Compare the behavior in a genetically or chemically perturbed background to wild type.
#  • Ideally automate segmentation and tracking so you can extract statistically robust correlations.
#  • Overlay gene‐reporter patterns on the same dataset, or register multiple embryos by landmark‐based time warping (e.g. germband retraction = t₀).
#
# By formulating your lightsheet observations around one of these specific, literature‐grounded hypotheses—and designing your image analysis to yield quantitative metrics (e.g. rates, length changes, intensity profiles)—you’ll be able to move from descriptive imaging to true mechanistic insight into hindgut organogenesis.
#
#
# ACT 2:
#  Below is a non‐exhaustive set of hypothesis‐driven questions you can ask of your 2D “unraveled” apical‐surface movie of the Drosophila hindgut.  For each I’ve sketched (1) the biological hypothesis, (2) the measurable prediction in your dataset, and (3) a possible follow‐up perturbation or marker stain.
#
# 1.  Oriented cell division drives tube elongation
#     •  Hypothesis: Hindgut cells preferentially divide along the anterior–posterior (A–P) axis to elongate the tube.
#     •  Prediction: Mitotic spindles (and daughter‐cell separation axes) will align within ±20° of the A–P axis.
#     •  Test:  Track divisions, compute spindle/division axis versus organ axis histogram.  Then in mutants of cell‐polarity genes (e.g. mud, pins) look for randomized division angles and reduced elongation.
#
# 2.  T1 neighbor exchanges (intercalations) power convergent extension
#     •  Hypothesis: Cells undergo directed T1 transitions (neighbor exchanges) preferentially along the circumferential axis, driving lengthening of the hindgut.
#     •  Prediction: You will observe a net gain of A–P neighbor contacts over time and a characteristic signature of shrinking junctions orthogonal to tube axis.
#     •  Test:  Segment and lineage‐track cells to count T1 events, map their orientations.  Perturb Planar Cell Polarity (PCP) genes (fz, dsh, strabismus) and assay for loss of directional intercalation.
#
# 3.  Apical constriction in a subset of cells sculpts hindgut curvature
#     •  Hypothesis: A patch of cells in the presumptive small‐intestine bend constricts apically (via actomyosin) to generate curvature.
#     •  Prediction: Those cells will show a sustained drop in apical area and elevated anisotropic shape index prior to bending.
#     •  Test:  Measure cell area over time; co‐image Sqh::GFP or p‐Myosin II to show local enrichment.  Inhibiting myosin II (ROCK inhibitor or sqh mutants) should reduce curvature.
#
# 4.  Graded morphogen input patterns cell behaviors
#     •  Hypothesis: Wg, Hh or Dpp expression domains along the hindgut induce distinct cellular behaviors: e.g. proliferation vs. rearrangement vs. constriction.
#     •  Prediction: Cells in the Wg domain will show higher proliferation (division rate), Hh domain more intercalations, Dpp domain more apical‐area modulation.
#     •  Test:  Overlay live Wg‐GFP / Hh‐GFP reporters onto your movie, segment the hindgut into bins by signal intensity, then correlate local behavior metrics.  In loss‐of‐function for each morphogen, check for selective loss of the corresponding behavior.
#
# 5.  Brachyenteron (byn) regulates epithelial cell adhesion
#     •  Hypothesis: byn regulates E‐cadherin localization or turnover in the hindgut epithelium, influencing tissue cohesion and cell rearrangements.
#     •  Prediction: In byn mutants (or RNAi), junctional E‐cadherin levels will be reduced, and you will observe increased cell‐cell gaps or irregular neighbor‐exchange patterns.
#     •  Test:  Cross in E-cad::GFP, compare apical‐junction intensity over time, quantify the frequency of “detachment” events or abnorm al T1 rates.
#
# 6.  Crumbs‐mediated apical membrane growth controls columnar cell shape
#     •  Hypothesis: Apical‐polarity regulator Crumbs sets overall apical area and thus cell height; in its absence cells adopt a more squamous shape.
#     •  Prediction: crb mutant hindgut cells will have smaller apical footprints and altered neighbor geometry (more hexagonal vs. elongated shapes).
#     •  Test:  Segment apical areas in crb^–/^– embryos; quantify cell‐shape descriptors (aspect ratio, solidity).  Rescue by overexpressing Crb should restore wild‐type area.
#
# 7.  JAK/STAT signaling in visceral mesoderm non‐autonomously patterns epithelium
#     •  Hypothesis: Visceral‐mesoderm‐derived ligands (e.g. Upd) signal via JAK/STAT in the endoderm to modulate proliferation or rearrangements in the hindgut epithelium.
#     •  Prediction: In stat92E mutants, epithelial cell division rate or T1 frequency in the adjacent rows will be altered.
#     •  Test:  Film stat92E^–/^– or mesoderm‐specific Upd knockdown and compare mitotic indices and neighbor exchanges to wild type.
#
# 8.  Transition from secondary to tertiary tube shapes involves differential cell behaviors
#     •  Hypothesis: The preliminary “U‐shaped” tube remodels by focal cell intercalation in the caudal region to adopt the final 3D cobra‐like shape.
#     •  Prediction: You will see a burst of cell rearrangements localized to that region exactly when the 2D projection begins to deviate from a simple curve.
#     •  Test:  Precisely timestamp the onset of tertiary‐shape emergence and overlay local cell‐movement vectors; perturb candidates (e.g. ribbon or tailless) known to affect late hindgut shaping.
#
# 9.  Mechanical feedback coordinates cell behaviors across the epithelium
#     •  Hypothesis: Tissue‐scale tension arising from curvature feeds back to regulate local cell area or division orientation.
#     •  Prediction: Regions of high curvature will show altered rates of cell division orientation or slower intercalation.
#     •  Test:  Compute local curvature from your 2D map, bin cells by curvature, and correlate behavior metrics.  Softening the tissue (e.g. laser ablation or reducing junctional myosin) should decouple curvature and behavior.
#
# 10. Genetic hierarchy ordering hindgut patterning genes
#     •  Hypothesis: Tailless (tll) acts upstream of brachyenteron in specifying hindgut primordium—loss of tll will delay or abolish the onset of the behaviors driven by byn.
#     •  Prediction: In tll mutants, the spatiotemporal wave of byn‐dependent cell shapes or divisions will be absent.
#     •  Test:  Film tll^–/^– embryos labeled for byn reporter plus apical‐surface marker, then quantify the timing and positioning of the first cell‐behavior changes.
#
# ––––––––––––––––––––––––
# Implementation notes:
# •  Start by fully segmenting & tracking every cell in your 2D surface movie.  Extract per‐cell features: apical area, shape anisotropy, division events, neighbor identity changes, and local curvature.
# •  Overlay fluorescent reporters or perform parallel fixed‐embryo stains for key markers (Sqh, E-cad, Wg/Hh/Dpp, byn‐GFP, Crb) to assign cells to genotypic or signaling domains.
# •  Use loss‐ and gain‐of‐function alleles, cell‐type‐specific drivers (Gal4/UAS), and optogenetic or pharmacologic perturbations to challenge each hypothesis.
# •  Quantify each “behavior metric” in controls versus perturbation, and test for statistically significant changes in orientation, frequency, or magnitude.
# ACT 1:
#  Below is a non‐exhaustive list of hypothesis-driven questions you can ask of your lightsheet time-lapse data, together with the quantitative measurements you would extract in order to test each one.  You will recognize many of the parameters and processes (cell shape anisotropy, volume changes, T1 transitions) from the Honda–Nagai–Honda vertex model and from the polygon inertial‐ellipse analysis described in Inaki et al.
#
# 1.  Is cell intercalation (T1 transitions) required for the onset of hindgut rotation?
#     – Hypothesis: oriented T1s generate the torque that twists the tube.
#     – Measurement: segment and track individual cells in 3D; detect when an edge length falls below the critical “reconnection” threshold (d ≃ 0.3·Ro) and record each neighbor exchange.  Compute (a) the global T1 rate as a function of time, and (b) the spatial and directional bias of T1s (circumferential vs. longitudinal).
#
# 2.  Do cells become anisotropic in shape before or concomitant with rotation?
#     – Hypothesis: buildup of apical/circumferential cell elongation produces mechanical stress that drives twist.
#     – Measurement: for each cell apical surface, fit the momental inertial ellipse, extract the major‐axis orientation and the deviation index (dmax–dmin)/(dmax+dmin).  Plot histograms of cell‐axis angles relative to the tube’s longitudinal axis as a function of developmental time.
#
# 3.  Is apical surface area (or cell volume) dynamically regulated to produce bending and twisting?
#     – Hypothesis: local apical constriction or volumetric growth precedes chirality.
#     – Measurement: segment apical surfaces and/or full 3D cell volumes; compute area(t) or V(t) for each cell.  Look for spatiotemporal patterns (e.g. ventral vs. dorsal differences) and correlate those with the twist angle of the tissue.
#
# 4.  Does the distribution of cortical tension (Myosin II activity) predict where and when rotation occurs?
#     – Hypothesis: enrichment of Myosin II on one side of the tube sets up differential contractility.
#     – Measurement: if you have a sqh-GFP or GFP-moesin marker, quantify fluorescence intensity on each cell’s cortex over time.  Map intensity onto the 3D surface and test whether regions of higher tension coincide with cell shape changes or T1 hotspots.
#
# 5.  Can the measured cell behaviors be recapitulated by the vertex model with parameters (kS, kV, kB) as in Inaki et al.?
#     – Hypothesis: a minimal set of mechanical rules underpins the morphogenesis.
#     – Measurement: from your live data extract time series of (a) mean edge lengths, (b) T1 frequency, (c) cell shape indices, (d) global tube radius and twist.  Fit or compare these to simulations run with varied kS, kV, kB and ask which parameter combinations best reproduce the in vivo trajectories.
#
# 6.  Do individual cells display intrinsic chirality prior to collective rotation?
#     – Hypothesis: cell-inherent left‐right polarity biases neighbor rearrangements.
#     – Measurement: track single‐cell vertex configurations in 3D (e.g. count how often tri‐cellular junctions pivot one way vs. the other) and test for a statistical handedness bias at the single‐cell level before the tissue‐scale twist begins.
#
# 7.  Is hindgut rotation autonomous to the gut epithelium, or does it require external attachments?
#     – Hypothesis: the epithelium alone suffices.
#     – Measurement: use lightsheet imaging of explanted guts (the GFP-moesin assay) and quantify rotation rate and cell behaviors in isolation versus in situ.  Compare T1 rates, cell shapes, and twist angles.
#
# 8.  Does lumen volume change drive or respond to rotation?
#     – Hypothesis: the tube inflates (or deflates) asymmetrically, creating a torque.
#     – Measurement: segment lumen in 3D and compute its volume V(t).  Correlate dV/dt with the onset and speed of rotation, and with local changes in cell apical areas.
#
# 9.  Are there regional differences in mechanics along the proximo–distal axis of the hindgut?
#     – Hypothesis: only a subset of segments initiate twisting.
#     – Measurement: subdivide the tube into bins along its length; in each bin extract cell‐shape anisotropy, T1 density, cortical‐tension marker intensity, and local curvature.  Test whether certain regions lead or lag in the developmental sequence.
#
# 10.  How does the global geometry of the tube (radius, curvature) evolve, and does it feed back on cell behaviors?
#     – Hypothesis: bending of the tube alters local cell packing and thus induces chirality.
#     – Measurement: fit the central axis and local tube radius R(t) from the cell centroids or vertex positions; compute curvature κ(s, t).  Correlate curvature changes with local cell anisotropy and T1 events.
#
# Each of these questions ties a qualitative idea about the mechanics or cell biology of hindgut morphogenesis back to a concrete, testable quantification you can perform on your lightsheet dataset.  By systematically measuring cell shapes, volumes, neighbor rearrangements, cortical‐tension reporters, and tube‐level geometry you will be in a strong position to support or falsify each hypothesis.
#
#
# ACT 2:
#  Here are a number of hypothesis‐driven questions you can immediately begin to ask (and in many cases quantify from your 2D movie) now that you have both a vertex‐model framework (Eqs. 8–12) and high‐quality apical-surface recordings of the Drosophila hindgut.  Each of these can be turned into a concrete measurable assay, matched back to the model, and then perturbed genetically or pharmacologically.
#
# 1.   Is oriented T1 intercalation driving rotation?
#      •  Hypothesis: cell neighbor‐exchange (T1) events are polarized along the circumferential (“around‐tube”) axis, and that bias produces net tissue rotation.
#      •  Measurement: segment the movie, detect T1 events, record their orientation relative to the tube axis, and ask whether there is a statistically significant bias.
#      •  Perturbation: inhibit intercalation (e.g. block myosin II or Rho‐kinase activity, or express dominant‐negative E-cadherin) and ask whether rotation stalls or reverses (cf. the “no‐reconnection” simulation in Fig. 4B of Inaki et al.).
#
# 2.   Does cell shape anisotropy correlate with model parameters kS, kV, kB?
#      •  Hypothesis: cells under higher effective cortical tension (kS) will be rounder; cells under strong volume constraint (kV) will have more uniform area; cells in regions of high curvature will show bending‐related distortions (kB).
#      •  Measurement: for each cell at each time point, compute the ellipse of inertia, extract (dmax–dmin)/(dmax+dmin), and map this onto local curvature of the mapped cylinder.  Fit these data to infer effective kS, kV, kB from your actual tissue.
#      •  Perturbation: up‐ or down-regulate cortical tension (e.g. optogenetic activation of RhoA, or sqhGFP overexpression) and watch for predicted shifts in cell shape distributions.
#
# 3.   Are apical area fluctuations linked to bending or volume penalties?
#      •  Hypothesis: if the apical area is tightly constrained (large kV in the model), then you should see cell areas remaining near a constant value even under large curvature changes; if kB dominates, apical contours will distort more in high‐curvature zones.
#      •  Measurement: plot individual cell apical area over time versus their instantaneous curvature (from the 2D unwrapped sheet).  Test for correlations.
#      •  Perturbation: express aquaporins or shrink extracellular space chemically (alter effective volume constraints) and test whether area–curvature coupling changes.
#
# 4.   Does myosin II enrichment predict the orientation and timing of T1 events?
#      •  Hypothesis: before a T1 transition, myosin II (sqhGFP) pulses or enrichments appear on the shrinking junction, consistent with an increase in local kS.
#      •  Measurement: align your 2D movie with sqhGFP signals, track junction length versus local sqh fluorescence, and ask whether increased myosin concentration always precedes edge shrinkage.
#      •  Perturbation: locally inhibit myosin with laser ablation or pharmacology (Y-27632) and ask if the corresponding T1 event is delayed or prevented.
#
# 5.   Can you observe the predicted dependence of rotation on tube radius (RTop, RBottom)?
#      •  Hypothesis: the model predicts that having RTop≠RBottom will bias the rotation direction or speed in a predictable manner (through the bending energy term kB).
#      •  Measurement: in your 2D map, measure local tube radius over time (from tissue geometry) and correlate with the instantaneous local rotation velocity (via PIV or landmark tracking).
#      •  Perturbation: genetically perturb factors that change tube diameter (for instance, modulate tracheal tube‐size regulators) and test whether rotation speed scales as the model predicts.
#
# 6.   Is rotation an intrinsic property of the hindgut or does it require external mechanical cues?
#      •  Hypothesis: if rotation is cell‐autonomous and driven by the internal balance of kS/kV/kB and T1 reconnection, then isolated explants should still rotate.  If the surrounding tissues supply essential forces, explants will fail to rotate.
#      •  Measurement: take your 2D explant movies, unwrap and quantify rotation rate and cell rearrangements.
#      •  Perturbation: compare intact embryos versus explanted hindguts (with and without added ECM or fly extract) to see whether rotation persists.
#
# 7.   Does reversing individual‐cell chirality reverse the direction of hindgut rotation?
#      •  Hypothesis: as shown by Hatori et al. 2014, intrinsic cell chirality can set the global handedness.  If you flip cell chirality genetically (e.g. alter specific cytoskeletal regulators), you should flip rotation direction.
#      •  Measurement: in your movie, use cell‐shape asymmetry metrics (vertex skewness, edge‐length bias) to quantify cell chirality and correlate cell‐by‐cell with local rotation direction.
#      •  Perturbation: express known chirality‐reversing factors (e.g. atypical cadherin dachsous mutants) and test whether the entire hindgut rotates the opposite way.
#
# 8.   Can you validate the energy budget of the model directly from your data?
#      •  Hypothesis: the sum of area, perimeter, and bending energies (kS·(Sa–So)² + kV·(V–V0)² + kB·bending) should decrease over time as the tissue approaches its stable shape.
#      •  Measurement: compute for each cell the deviation (Sa–So), the per-cell volume (approximated from apical area and known cell height), and local curvature; then sum these “energies” and see whether they monotonically decrease towards your observed final configuration.
#      •  Perturbation: transiently block any one energy term (e.g. inhibit volume regulation by osmotic shock) and see if the system fails to relax its total energy as your model would predict.
#
# ---
#
# By turning each of these into quantitative assays in your 2D movie—and then matching the results to predictions of Eq. (12) while perturbing the corresponding biological parameter—you will be testing very specific, hypothesis-driven links between your vertex model and the real mechanics and genetics of hindgut morphogenesis.

# %%
# so what? How do we reach a coherent narrative?
# how well does this hypothesis fit the following data. 
act = "" # what would be performed on a wild-type dataset?
# Out:
#   Cell In[5], line 3
#     act = # what would be performed on a wild-type dataset?
#           ^
# SyntaxError: invalid syntax

# %%
phrases = [
    "Gut tube rotation dynamics",
    "Cell and tissue behaviors",
    "LR symmetry-breaking perturbations",
    "Mechanical-network update rules",
    "T1 neighbor exchanges",
    "Epithelial cell behaviors",
    "Geometric & topological disorder in cell array",
    "Extract specific observations and theories",
    "Summarize a paragraph into a concise gem",
    "Thematic survey of hindgut literature",
    "Parameters you can experimentally change",
    "Independent developmental story lines",
    "Key intellectual targets",
    "Cell-angle, shape, and tension nematics",
    "Stress distribution along the hindgut",
    "Surface-parameterizing math equations",
    "Math / logic / image integration for full story",
    "Timescale-dependent assumptions & implications",
    "Definition and measurement of curvature",
    "Infer stresses from shape evolution",
    "Math/physics question set for the hindgut",
    "Active, latent, viscous & elastic stresses",
    "Waddington landscape embeddings",
    "Frame questions in terms of cells & inference",
    "Compare hindgut to quail gastrulation tensile ring",
    "Information content in constriction stiffness",
    "Origins of intuitive hindgut models",
    "Calcium activity vs. constriction dynamics",
    "Active stress versus viscoelasticity",
    "Soft vs. hard constraint implications",
    "Universal biological questions applied to hindgut",
    "Simulation predictions that are measurable",
    "Probabilistic differentiation & growth strategies",
    "Link Waddington landscape to optimal transport",
    "Optimal transport analogs (econ, coal, sand, bio)",
    "Genetic manifold distance & dynamics",
    "Schrödinger bridge narrative in development",
    "Costs and rewards of development",
    "Dialogue of math language within biology",
    "Complete stories of hindgut development",
    "Comprehensive toolset for hindgut study",
    "Treating idea space as real space"
]

# %%
p = random.randint(0, len(phrases)-1)
phrase = phrases[p]
print(phrase)
# Out:
# Schrödinger bridge narrative in development

# %%
act1 = ask("If I have a lightsheet imaging dataset of hindgut development over time, what hypothesis driven inquires should be performed on the following information?", phrase)
act2 = ask("If I have a 2D movie of the developing Drosophila hindgut acquired by identifying and unraveling the apical surface of the epithelial tissue of a lightsheet dataset of developing hindgut, what hypothesis driven inquires should be performed on the following information?", phrase)
print(act1)
print(act2)
# Out:
# Here are several hypothesis‐driven lines of inquiry you can pursue by combining your lightsheet time‐series of hindgut morphogenesis with a Schrödinger-bridge (SB) or optimal-transport framework. The idea is to treat your 4D image data as a sequence of spatial cell‐density (or marker‐intensity) “snapshots” and ask what the most likely continuous flow (bridge) is that carries you from an early stage to a later stage.  Each bullet below represents a concrete hypothesis you could test with experiment or in silico perturbation.
#
# 1.  Optimal‐transport of cell density
#     •  Hypothesis: The tissue‐scale reorganization of cells during gut invagination follows a minimum‐energy (Wasserstein) path.
#     •  Test: Fit an SB model between an early “flat endoderm” state and a mid-stage “tube forming” state. Compare the inferred transport plan (vector field of cell movements) to actual cell‐tracking trajectories from the lightsheet data. Significant deviations would falsify a purely energy‐minimizing hypothesis.
#
# 2.  Entropy production and developmental staging
#     •  Hypothesis: Transitions between certain stages (e.g. onset of circularization vs. completion of lumen) are marked by peaks of entropy production in the SB model.
#     •  Test: Compute the time‐dependent entropy of the SB bridge. Does it spike at known morphogenetic “decision points”? Correlate those maxima with changes in cell shape, division rates or gene‐reporter fluctuations.
#
# 3.  Gene‐regulatory influence on the transport plan
#     •  Hypothesis: Expression domains of key transcription factors (e.g. Sox17, FoxA2) bias the SB flow—cells in high-Sox17 regions are “pulled” preferentially toward the midline.
#     •  Test: Co‐register live or fixed imaging of gene-reporter intensity with your density fields. Augment the SB cost functional by an advection term proportional to the local reporter signal. See if it better predicts actual cell trajectories than the pure SB solution.
#
# 4.  Mechanical‐force constraints
#     •  Hypothesis: The SB-inferred velocity field aligns with stress‐oriented actomyosin cables revealed by live myosin markers or computed via finite‐element tissue mechanics.
#     •  Test: Overlay tension‐direction readouts on the SB vector field. Correlation would suggest that the SB solution is capturing an underlying mechanical optimum, not just statistical averaging.
#
# 5.  Robustness and canalization
#     •  Hypothesis: Mild perturbations (e.g. partial knockdown of an ECM‐remodeling enzyme) shift the optimal bridge only locally; the global path remains canalized.
#     •  Test: Perform low‐level drug or RNAi perturbations, re‐image, re-compute SB between the same start/end stages. Quantify how much the bridge changes. A small variation supports canalization.
#
# 6.  Inverse inference of unobserved stages
#     •  Hypothesis: The SB framework can accurately “fill in” poorly sampled or missing time-points by interpolating density and marker distributions.
#     •  Test: Remove one or more time frames from your dataset, infer them with SB conditioning on bracketing times, then compare to the withheld actual images.
#
# 7.  Cell‐fate lineage branching
#     •  Hypothesis: Regions in the SB transport plan where the flow field “bifurcates” correspond to future lineage branches (e.g. ventral vs. dorsal gut progenitors).
#     •  Test: Map single‐cell trajectories (via nucleus tracking) onto the SB velocity field and ask whether splits in flow coincide with fate‐specified expression patterns observed later.
#
# 8.  Energetic cost vs. proliferation
#     •  Hypothesis: High‐proliferation zones reduce the need for long‐range transport (i.e. division supplies local mass), so the SB path avoids costly cell migrations in these regions.
#     •  Test: Quantify proliferation (e.g. via mitotic markers) over space/time, and see whether the SB vector magnitudes are lower in those zones compared to low‐division areas.
#
# By formulating your questions in this way you (a) ground your analysis in a clear, quantitative “most‐likely path” model, and (b) generate testable predictions about cell trajectories, gene‐expression profiles, mechanical cues, and robustness. Each hypothesis can be validated (or falsified) by comparing the SB‐predicted flows and intermediate densities against direct measurements or perturbation experiments.
# Here are several hypothesis‐driven inquiries you could pursue now that you have an “unraveled” 2D movie of the Drosophila hindgut apical surface and want to cast its morphogenesis in a Schrödinger‐bridge (i.e. entropy‐regularized optimal‐transport) framework:
#
# 1. Do observed cell trajectories minimize an entropy‐regularized energy cost?
#    • Hypothesis: The actual paths cells take between an early and late hindgut shape coincide (within noise) with the Schrödinger‐bridge solution linking those two apical‐surface distributions.
#    • Inquiry:
#      – Compute the SB (Schrödinger Bridge) map from initial to final cell‐centroid distributions.
#      – Compare predicted SB displacements with measured displacements (e.g. by mean squared error or correlation).
#      – Test whether increasing the entropic regularization term improves or worsens the fit.
#
# 2. Are neighbor‐exchange (“T1”) events arranged to maximize path‐space entropy subject to boundary‐condition constraints?
#    • Hypothesis: Tissue fluidity arises because the pattern of cell‐cell rearrangements implements a maximum‐entropy transport of cells along the unfolding.
#    • Inquiry:
#      – Identify T1 transitions in your movie.
#      – Ask whether their spatiotemporal statistics match those generated by sampling from the SB ensemble.
#      – Perturb cadherin or actomyosin and see if deviations from SB predictions increase.
#
# 3. Does the inferred SB “potential” field correlate with known morphogen or mechanical‐stress patterns?
#    • Hypothesis: Areas of high SB potential correspond to regions of high FGF/BMP signaling or elevated myosin tension.
#    • Inquiry:
#      – Overlay SB scalar potential (from the log‐density ratio) onto your movie frames.
#      – Quantify correlation between potential and reporter‐fluorescence signals.
#      – Use mutants or inhibitors to test causality.
#
# 4. Can you reconstruct a self‐consistent developmental pseudotime?
#    • Hypothesis: Ordering frames (or cells) by increasing SB action (cumulative cost) yields a biologically meaningful “morphogenetic clock.”
#    • Inquiry:
#      – Integrate the SB Lagrangian along each cell’s trajectory to define a path‐dependent “time.”
#      – Compare that pseudotime ordering to traditional markers of hindgut stage (e.g. gene expression onset).
#
# 5. How does tissue curvature or geometry affect the SB predictions?
#    • Hypothesis: Flattening the apical surface into 2D introduces metric distortions that shift the SB map.
#    • Inquiry:
#      – Re‐compute the SB on the original curved surface (using a discretized manifold metric) versus your flattened map.
#      – Measure how predicted paths diverge, and whether cells actually follow one or the other.
#
# 6. What is the response of the SB‐predicted flow under genetic or mechanical perturbations?
#    • Hypothesis: Knocking down a key cytoskeletal regulator (e.g. Rho‐kinase) will systematically bias observed cell paths away from the SB‐optimal solution.
#    • Inquiry:
#      – Acquire an “unraveled” movie in the perturbed embryo.
#      – Compute SB maps for wildtype and perturbed boundary shapes.
#      – Quantify the change in path‐space divergence (e.g. Kullback–Leibler) between predicted and actual trajectories.
#
# By systematically asking whether the tissue’s unfolding can be seen as an entropy‐regularized transport problem—and then testing against perturbations or alternative metrics—you turn your 2D movie into a quantitative, hypothesis‐driven dissection of hindgut morphogenesis.

# %%
answer1 = ask("You are going to be given a set of hypotheses about Drosophila hindgut development. Your role is to describe the narrative for each hypotheses. Describe possible outcomes, what data confirms/falsified the hypothesis and the implications for future hypotheses.", act1)
answer2 = ask("You are going to be given a set of hypotheses about Drosophila hindgut development. Your role is to describe the narrative for each hypotheses. Describe possible outcomes, what data confirms/falsified the hypothesis and the implications for future hypotheses.", act2)
print(answer1)
print(answer2)
# Out:
# Below is a narrative for each of the ten hypotheses. For each one I outline (a) the biological story, (b) possible outcomes, (c) how your lightsheet data would confirm or falsify the hypothesis, and (d) what you’d do next depending on the result.
#
# 1. Growth-rate law of the hindgut tube
# a. Story: We want to know if hindgut cross-sectional area A(t) simply grows unchecked (exponential) or whether it slows as it approaches a maximum size (logistic).
# b. Outcomes:
#    • Exponential wins → tissue expansion is unregulated over the observed window.
#    • Logistic wins → there is an effective “carrying capacity” (e.g. mechanical confinement or feedback) limiting growth.
# c. Data check: Fit A(t) to both models by nonlinear least squares. Compare AIC or adjusted R².
#    • Confirmation of exponential: significantly lower AIC for exp model, residuals show no systematic curvature.
#    • Confirmation of logistic: best-fit K is biologically plausible; residuals random.
#    • Falsification: neither model fits (structured residuals) suggests more complex dynamics (e.g. oscillations or multi-phase growth).
# d. Next steps:
#    • Exponential → probe whether growth eventually saturates at later stages or under different mechanical load.
#    • Logistic → identify molecular or mechanical signals that set K; test by perturbing confinement or signaling pathways.
#    • Neither → propose a multi-phase or delay differential model, collect higher‐resolution time courses.
#
# 2. Correlation between local curvature and proliferation rate
# a. Story: Do tightly curved regions of the tube (e.g. bends) spur cell division?
# b. Outcomes:
#    • Positive α (slope) → high curvature predicts higher p.
#    • α ≈ 0 → no link.
#    • Negative α → curvature suppresses division.
# c. Data check: Sample curvature k(s,t) and division rate p(s,t) along the medial axis, run linear regression p = p₀ + αk. Test α=0 by t-test.
#    • Confirmed if α>0 and p < 0.05.
#    • Falsified if CI for α overlaps zero.
# d. Next steps:
#    • α>0 → mechanically‐induced proliferation hypothesis; disrupt curvature (e.g. by laser ablation) and measure p.
#    • α≈0 → look for other geometric metrics (e.g. strain rate, thickness).
#    • α<0 → consider curvature‐dependent stress inhibiting mitosis; test tension sensors.
#
# 3. Pattern of collective cell migration
# a. Story: Are cells moving coherently from posterior to anterior as the organ elongates?
# b. Outcomes:
#    • Mean projection ⟨v∥⟩≫0 → clear directed flow.
#    • ⟨v∥⟩≈0 → random or isotropic motion.
#    • Negative ⟨v∥⟩ → reverse flow.
# c. Data check: Compute local velocity vectors v(x,t), define the AP unit vector d̂, project v∥=v·d̂, test whether time‐averaged ⟨v∥⟩ is significantly positive by a one‐sample t-test. Quantify variance Var[δv].
# d. Next steps:
#    • Directed flow → map guidance cues (chemotactic or mechanical) along the axis.
#    • No flow → focus on local rearrangements; use pair‐correlation or nematic order parameters.
#    • Spatial heterogeneity (high Var[δv]) → segment tissue into domains, test local guidance differences.
#
# 4. Evolution of lumen volume
# a. Story: Does the central cavity inflate at a constant rate or accelerate (e.g. via fluid pumping mechanisms)?
# b. Outcomes:
#    • Linear best → simple filling.
#    • Quadratic best → accelerating expansion.
#    • Neither → complex multi‐stage filling.
# c. Data check: Fit V_L(t) to linear vs quadratic; use F-test on residual sums of squares to see if adding t² significantly improves fit.
# d. Next steps:
#    • Linear → investigate sources of lumen fluid (passive vs active transport).
#    • Quadratic → track expression of ion pumps over time; manipulate transporters.
#    • Complex → consider piecewise fits or models with feedback (e.g. pressure‐dependent permeability).
#
# 5. Anisotropy of cell-division orientations
# a. Story: Mitotic spindles might align along the AP axis to drive elongation.
# b. Outcomes:
#    • Significant Rayleigh test → non‐uniform distribution peaked at 0°/180°.
#    • Non‐significant → random orientations.
#    • Peak at 90° → transverse divisions dominating.
# c. Data check: For each mitosis measure θ_i, run a Rayleigh test; compute resultant length R and p-value.
# d. Next steps:
#    • AP bias → look for anisotropic cues (e.g. planar cell polarity proteins); perturb PCP.
#    • No bias → cell rearrangements, not oriented divisions, drive shape change.
#    • Transverse bias → explore tissue thinning mechanisms.
#
# 6. Mass conservation and proliferation/apoptosis balance
# a. Story: Does local density ρ obey the continuity equation ∂ρ/∂t + ∇·(ρv)=σ, with σ the net source from divisions/minus deaths?
# b. Outcomes:
#    • Residuals ≈ 0 → mass conserved, σ explains density change.
#    • Systematic residual patterns → missing physics (e.g. cell ingress/egress).
# c. Data check: Compute LHS and RHS voxelwise, calculate spatio-temporal RMSE. Use permutation tests to see if residuals are significantly larger than noise.
# d. Next steps:
#    • Good fit → use the same framework to test mutants (altered proliferation/apoptosis).
#    • Poor fit → add terms for cell intercalation flux or tissue remodeling; track neighbor‐exchange events.
#
# 7. Shape mode decomposition (PCA of morphology)
# a. Story: Can the evolving hindgut boundary be described by a handful of principal shape modes?
# b. Outcomes:
#    • k small modes explain >90% variance → low‐dimensional morphospace.
#    • Many modes needed → high complexity.
# c. Data check: Stack boundary coordinates X(t), perform PCA, compute cumulative variance for first k modes.
# d. Next steps:
#    • Low-dim → correlate mode amplitudes with genetic or mechanical perturbations.
#    • High-dim → try nonlinear embeddings (e.g. diffusion maps) or segment into phases.
#
# 8. Mechanical stress-curvature feedback
# a. Story: Does local tissue curvature drive mechanical stress (or vice versa)?
# b. Outcomes:
#    • Positive β → stress increases with curvature (feedback).
#    • β≈0 → no direct link.
#    • Negative β → curved regions relieved of stress.
# c. Data check: Measure curvature k(x,t) and tension sensor signal S(x,t). Fit S = βk + c by linear regression; test β>0.
# d. Next steps:
#    • β>0 → model mechanochemical feedback loops; test by pharmacologically reducing contractility.
#    • β≈0 → seek other stress determinants (e.g. cell density, active forces).
#    • β<0 → explore curvature‐driven stress release mechanisms (e.g. blebbing).
#
# 9. Scaling law of hindgut length
# a. Story: Is elongation isometric (α=1) or does it speed up/slows down over time (α≠1)?
# b. Outcomes:
#    • α≈1 → simple linear scaling.
#    • α>1 → super‐linear (accelerating elongation).
#    • α<1 → sub‐linear.
# c. Data check: Fit log L vs log t, extract slope α, test α=1 by t-test on slope estimate.
# d. Next steps:
#    • α=1 → look for constant‐rate drivers (steady cell intercalation).
#    • α>1 or <1 → incorporate time-dependent parameters (e.g. changing proliferation or migration rates).
#
# 10. Periodicity in cell-cycle entry
# a. Story: Do waves of proliferation move along the AP axis with a characteristic period or wavelength?
# b. Outcomes:
#    • Distinct peaks in P(ω_s,ω_t) → recurring spatio-temporal proliferation patterns.
#    • Flat spectrum → no periodicity.
# c. Data check: Compute 2D FFT of p(s,t), identify spectral peaks above permutation-derived thresholds.
# d. Next steps:
#    • Significant periodicity → track molecular oscillators (e.g. segmentation clock homologues) and perturb them.
#    • No periodicity → focus on local regulation (e.g. neighbor inhibition) rather than global waves.
#
# ––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
# By following each narrative—assessing model fit or hypothesis tests, interpreting outcomes, and then designing targeted follow-up experiments—you close the loop between quantitative analysis and biological insight in Drosophila hindgut morphogenesis.
# Below is a narrative for each of the ten hypotheses.  For each, we sketch (a) possible experimental outcomes, (b) how you’d recognize support versus refutation in your quantitative readouts, and (c) what you’d do next in either case.
#
# 1. Regional curvature drives differential tissue elongation
#    • Possible outcomes
#      – Positive result: ∂L/∂t(s) and κ(s,t) co‐vary strongly (e.g. Pearson r > 0.7, P < 0.05).  Regions of high curvature elongate faster.
#      – Negative result: no significant correlation (r≈0, wide confidence intervals); elongation is uniform or uncorrelated with κ.
#    • Confirmation criteria
#      – Significant slope in linear regression of ∂L/∂t vs. κ, low P‐value, residuals unstructured.
#    • Refutation criteria
#      – Flat regression line, non‐significant model F‐test, random scatter in cross‐correlation.
#    • Next steps
#      – If supported: perturb midline curvature (laser ablation or mechanical bending) and re‐measure ∂L/∂t to test causality.
#      – If refuted: examine upstream drivers (e.g. gene‐expression or contractility waves) as potential regulators of elongation.
#
# 2. Anisotropic cell shape changes underlie tube bending
#    • Possible outcomes
#      – Support: mean aspect ratio α_i rises monotonically with local κ; high‐curvature bins have significantly larger α (ANOVA P < 0.01).
#      – No effect: α_i distribution identical across curvature bins, no trend.
#    • Confirmation
#      – Clear systematic increase of α versus κ, reproducible across embryos, effect size beyond measurement noise.
#    • Refutation
#      – Overlapping α distributions, non‐significant pairwise tests, PCA of shapes shows no orientation bias.
#    • Next steps
#      – If supported: disrupt cytoskeletal regulators (e.g. Rho kinase inhibitors) and check if bending or α‐curvature link breaks.
#      – If refuted: look for multicellular rearrangements or localized contractile pulses as other bending drivers.
#
# 3. A wave of contractile force travels along the hindgut
#    • Possible outcomes
#      – Traveling‐wave: kymograph of ∂v/∂s shows a clear diagonal ridge; fitting yields consistent ω, k across embryos.
#      – No wave: kymograph is static or noisy; sinusoidal fit fails (low R²).
#    • Confirmation
#      – Good fit to v(s,t)=A sin(ωt–ks+φ) (R²>0.8), reproducible phase velocity c=ω/k.
#    • Refutation
#      – Poor fit (R²<0.2), phase velocity varies randomly, no shifting patterns in kymograph.
#    • Next steps
#      – If supported: map upstream triggers (e.g. calcium/CaMK waves) and perturb amplitude A or frequency ω pharmacologically.
#      – If refuted: quantify steady‐state contractility (spatially uniform) or test for multiple overlapping waves.
#
# 4. Cell rearrangements (T1 transitions) relieve stress and enable invagination
#    • Possible outcomes
#      – Threshold behavior: ρ_T1 jumps when inferred stress σ passes a critical value σ_c.
#      – Graded response: ρ_T1 increases gradually with σ, no sharp threshold.
#      – No relationship: ρ_T1 uncorrelated with area‐strain rate.
#    • Confirmation
#      – Plot ρ_T1 vs. ∂(area)/∂t shows a kink or step‐like rise; piecewise regression finds break‐point.
#    • Refutation
#      – Smooth or flat curve, low mutual information between σ and ρ_T1.
#    • Next steps
#      – If thresholded: look for mechanosensitive molecules (e.g. E‐cadherin tension sensors) that trigger T1s.
#      – If graded or absent: consider uniform actomyosin contractility or alternative stress‐relief modes (apical constriction).
#
# 5. Global tissue deformation follows a minimal‐energy (elastic) model
#    • Possible outcomes
#      – Elastic model fits well: least‐squares error small, consistent E, T, ρ across stages.
#      – Model fails: systematic deviations, time‐dependent parameters required.
#    • Confirmation
#      – Residuals random, parameter confidence intervals small, same constants reproduce multiple movies.
#    • Refutation
#      – Spatially structured residuals, needed to add damping or active forcing terms.
#    • Next steps
#      – If confirmed: predict response to applied force (e.g. micropipette pulling) using the fitted EI and test experimentally.
#      – If refuted: extend model to include viscoelasticity or active stress generation.
#
# 6. Spatial gradients of gene‐expression patterns set the curvature profile
#    • Possible outcomes
#      – ∂G/∂s and ∂κ/∂s are correlated (Pearson r > 0.6), mutual information high.
#      – No spatial alignment: gene gradient and curvature peaks are offset.
#    • Confirmation
#      – Significant spatial correlation, holds across time‐points and multiple embryos.
#    • Refutation
#      – Low or negative correlation, random scatter in (∂G/∂s, ∂κ/∂s) plot.
#    • Next steps
#      – If supported: use optogenetic knock‐down/overexpression of the morphogen locally to shift curvature.
#      – If refuted: search for post‐transcriptional regulation or mechanical feedback shaping curvature.
#
# 7. Growth kinetics follow a logistic law along the A–P axis
#    • Possible outcomes
#      – Fit converges, parameters stable (L_max matches anatomical limit, k,t₀ biologically plausible), residuals random.
#      – Poor logistic fit: systematic early‐ or late‐time deviations.
#    • Confirmation
#      – Non‐linear regression yields high R² (>0.9), narrow CIs on L_max,k,t₀.
#    • Refutation
#      – Low R², structured patterns in residuals indicating multi‐phase growth.
#    • Next steps
#      – If logistic holds: correlate k or t₀ with genetic background or environmental conditions to map regulators of growth rate.
#      – If not: fit piecewise or more complex growth laws (Gompertz, bilinear) and test phase transitions.
#
# 8. Mechanical feedback stabilizes tube diameter
#    • Possible outcomes
#      – σ_w(s) minimal in mid‐region (one‐way ANOVA P < 0.01), width fluctuations suppressed where curvature peaks.
#      – Uniform σ_w or highest σ_w at mid‐region (no stabilization).
#    • Confirmation
#      – Significant regional differences in σ_w; post‐hoc tests highlight mid‐domain.
#    • Refutation
#      – No regional variance or opposite trend.
#    • Next steps
#      – If confirmed: identify feedback loops (e.g. stretch‐activated ion channels) and inhibit them to see diameter destabilization.
#      – If refuted: consider purely passive elastic narrowing driven by cell shape change rather than active feedback.
#
# 9. Principal modes of deformation are low‐dimensional
#    • Possible outcomes
#      – First two PCs capture >90% variance, modes interpretable (e.g. bending + uniform elongation).
#      – Need >5 modes to reach 90%, indicating complex, high‐dimensional shape changes.
#    • Confirmation
#      – Scree plot elbow at PC2, reconstructions with two modes closely match the movie.
#    • Refutation
#      – Gradual decay of eigenvalues, poor reconstruction with two modes.
#    • Next steps
#      – If low‐dimensional: use these modes to build reduced dynamical models (e.g. limit‐cycle oscillators).
#      – If high‐dimensional: segment the process into sub‐regions or sub‐processes to reduce complexity.
#
# 10. Timing of invagination steps is stereotyped across embryos
#    • Possible outcomes
#      – Low CV (<10%) for t₁,t₂,t₃ across N embryos, showing tight control.
#      – High CV (>30%), indicating variability or stage asynchrony.
#    • Confirmation
#      – Calculated CVs small, pairwise embryo alignment shows consistent milestone ordering.
#    • Refutation
#      – Wide distributions, overlapping windows of events, inconsistent sequences.
#    • Next steps
#      – If stereotyped: search for molecular “timer” (e.g. transcriptional cascade) that paces invagination.
#      – If variable: investigate sources of noise (temperature, embryo size) or feedback mechanisms that can tighten timing.
#
# By carrying out these measurements, checking against the criteria above, and then branching your experimental plan based on confirmation or refutation, you’ll iteratively refine mechanistic models of hindgut morphogenesis.

# %%
print(answer1)
print(answer2)

# %%
print(answer)
# Out:
# Below is a narrative outline for each of the ten hypothesis‐driven targets.  For each I sketch (a) how you would test it in a lightsheet movie, (b) the possible outcomes you might observe, (c) what data would confirm or refute the hypothesis, and (d) the implications for follow-up experiments.
#
# 1. Tissue-scale shape change and growth
# Hypotheses:
#   A. Elongation is driven mainly by convergent-extension (CE) rather than oriented cell division.
#   B. There is an A–P gradient of growth rate (faster in rostral vs. caudal).
#   C. Volumetric strains during elongation are anisotropic (aligned with the midline) rather than isotropic.
#
# (a) Approach
#   • Segment and track all cells over time, compute local strain tensors (decomposed into extension/compression axes) and record division events with orientation.
#   • Map instantaneous area/volume changes in contiguous tissue patches along the A–P axis.
#
# (b) Possible outcomes
#   • Strong enrichment of T1 neighbor exchanges and anisotropic strain along A–P, with few divisions aligned to the axis.
#   • Conversely, many divisions oriented A–P contribute most of the length increase, with relatively isotropic neighbor rearrangements.
#   • A smooth gradient of expansion rates peaking in rostral segments, or uniform rates throughout.
#
# (c) Confirmation vs. falsification
#   • Confirmation of CE-driven growth: spatial maps show high rates of cell intercalation (T1s) oriented mediolateral → A–P, significant anisotropic strain eigenvalues, and division rates/orientations random.
#   • Falsification: if oriented mitoses account quantitatively for >50% of length gain (by counting daughter displacement vectors), CE is a minor contributor.
#   • A clear monotonic increase of strain magnitude in rostral regions confirms the growth gradient; a flat profile refutes it.
#
# (d) Implications / next steps
#   • If CE dominates, perturb known regulators of intercalation (e.g. PCP components) and test whether elongation stalls.
#   • If oriented divisions dominate, test spindle-orientation mutants (mud, pins) to see if tube length is reduced.
#   • If a growth gradient exists, seek upstream patterning cues (FGF, Wnt) that could establish it.
#
# 2. Single-cell behaviors
# Hypotheses:
#   A. Individual endodermal cells actively migrate toward the midline with time‐dependent speed/persistence.
#   B. Divisions are biased along the A–P axis.
#   C. Cell shape anisotropy evolves as the tube forms (cells become elongated along one axis).
#
# (a) Approach
#   • Track individual nuclei/cell centroids, compute trajectories relative to a midline reference.
#   • For each mitosis, measure the angle between daughter–daughter vector and the A–P axis.
#   • Extract cell outlines to quantify length/width ratio over time.
#
# (b) Possible outcomes
#   • Persistent, directed motion vectors pointing inward early, then slowing as cells pack into the tube.
#   • Division angles clustered around 0° (A–P) versus random or 90° (M–L).
#   • A monotonic increase in cell aspect ratio aligned with the elongation axis.
#
# (c) Confirmation vs. falsification
#   • Directional migration confirmed if mean net displacement/timestep toward midline is significantly >0 and persistence length increases or decreases in a predictable way. If tracks are random walks, the hypothesis is false.
#   • A significant non-uniform circular distribution of division angles (Rayleigh test, p<0.05) toward A–P confirms oriented mitosis.
#   • No change in shape anisotropy over time falsifies the shape-change hypothesis.
#
# (d) Implications / next steps
#   • If active migration is key, probe the role of cytoskeletal regulators (Rac, Cdc42) by live reporters or mutants.
#   • If division orientation is prominent, manipulate spindle orientation machinery.
#   • If cell elongation is important, test whether mechanically stiffening the ECM alters cell shape dynamics.
#
# 3. Cell rearrangements and neighbor exchange
# Hypotheses:
#   A. T1 transitions peak in specific regions/time windows in support of CE.
#   B. The rate of neighbor exchange correlates with local curvature/bending.
#
# (a) Approach
#   • Build a neighbor graph and log T1 events with spatial and temporal coordinates.
#   • Compute local curvature of the tissue mid-surface and bin neighbor-exchange rates by curvature bins.
#
# (b) Possible outcomes
#   • A burst of T1s in the mid-gut region during early bending, then tapering as tube straightens.
#   • Higher neighbor-exchange rates at high curvature sites, low rates in flatter zones.
#
# (c) Confirmation vs. falsification
#   • A statistically significant clustering of T1s in both time (e.g. 200–300 min) and space (mid-region) confirms A. A uniform distribution falsifies it.
#   • A positive correlation (e.g. Pearson r>0.6, p<0.01) between curvature magnitude and T1 frequency supports B.
#
# (d) Implications / next steps
#   • If curvature and T1s co-localize, test whether artificial bending (laser ablation or optogenetics) recruits intercalations.
#   • If no correlation, investigate other drivers (e.g. proliferation, pressure).
#
# 4. Lumen formation and epithelial polarity
# Hypotheses:
#   A. Apical constriction initiates at a defined time and propagates as a wave.
#   B. Lumen inflation drives tissue bending rather than bending creating space for lumen.
#
# (a) Approach
#   • Use a membrane marker or apical polarity reporter to measure apical area per cell over time.
#   • Segment the lumen in 3D and compute its volume and curvature simultaneously.
#
# (b) Possible outcomes
#   • A coherent reduction of apical areas starting at one pole and sweeping along the tube.
#   • Lumen volume increases precede measurable bending (or vice versa).
#
# (c) Confirmation vs. falsification
#   • Observation of a spatiotemporal “wave” of apical constriction confirms A; random onset falsifies it.
#   • If lumen volume growth curve leads curvature increase (cross‐correlation shows volume leads by Δt), it supports lumen-driven bending.
#
# (d) Implications / next steps
#   • If apical constriction is key, perturb actomyosin contractility (Rho kinase inhibitors) and assay lumen initiation.
#   • If lumen inflation drives bending, explore the role of fluid transporters or aquaporins genetically or pharmacologically.
#
# 5. Molecular patterning and reporter dynamics
# Hypotheses:
#   A. A morphogen reporter domain (e.g. Wnt) shifts position relative to the tissue as it elongates.
#   B. A graded reporter along A–P correlates with local behaviors (higher proliferation/polarity alignment).
#
# (a) Approach
#   • Quantify reporter intensity in each cell and map in a common coordinate system that moves and stretches with the tissue.
#   • Correlate per-cell intensity with proliferation rate, division orientation, or polarity vector.
#
# (b) Possible outcomes
#   • The expression domain remains fixed in embryonic coordinates (cells carry the signal) or appears to slide over the cell field.
#   • High‐reporter cells divide more and show stronger polarity alignment.
#
# (c) Confirmation vs. falsification
#   • If the reporter domain’s center of mass displaces at the same speed as tissue flow, it is passively transported rather than re-patterned. A stationary domain relative to fixed axes implies active re-establishment.
#   • A significant positive correlation between intensity and behavior metric confirms coupling; a flat correlation refutes it.
#
# (d) Implications / next steps
#   • If pattern shifts passively, investigate whether localized transcriptional control resets the domain.
#   • If intensity drives behavior, perform gain-/loss-of-function of that pathway and re-measure cell mechanics.
#
# 6. Mechanics and force inference
# Hypotheses:
#   A. Zones of high inferred tension (from cell shapes and topology) coincide with folding/bending regions.
#   B. Myosin II intensity peaks in regions of greatest curvature or neighbor rearrangement.
#
# (a) Approach
#   • Run a force‐inference algorithm (e.g. Bayesian or vertex‐model–based) on segmented cell shapes/topology to map relative edge tensions.
#   • Overlay a fluorescent myosin reporter channel and correlate intensity maps with curvature and T1 density.
#
# (b) Possible outcomes
#   • Tension hotspots align with bending crests; myosin pulses precede T1 bursts.
#   • No spatial match between myosin intensity and either curvature or T1s.
#
# (c) Confirmation vs. falsification
#   • A statistically significant overlap (e.g. Jaccard index >0.5, bootstrap p<0.01) of tension hotspots and curvature nodes confirms A.
#   • Lack of correlation between myosin intensity and morphogenetic markers refutes B.
#
# (d) Implications / next steps
#   • If tensions/myosin drive folding, use optogenetic myosin activation/inhibition to induce or block bends.
#   • If no correlation, explore alternative cytoskeletal regulators (actin turnover, adhesion remodeling).
#
# 7. Coupling between endoderm and adjacent tissues
# Hypotheses:
#   A. Endodermal movement is tightly mechanically coupled to the mesoderm/ectoderm.
#   B. Disrupting adhesion between layers slows or alters tube formation.
#
# (a) Approach
#   • Simultaneously image fluorescent labels in endoderm and one adjacent germ layer, compute cross‐correlation of velocity fields.
#   • In silico “adhesion knockouts” (set interlayer friction to zero in the analysis pipeline) or analyze embryos mutant for integrins/cadherins.
#
# (b) Possible outcomes
#   • High correlation coefficients (>0.8) indicate strong coupling; low (<0.3) implies sliding.
#   • In adhesion mutants, endoderm elongation is delayed or misaligned with neighbors.
#
# (c) Confirmation vs. falsification
#   • Tight temporal and spatial locking of velocities confirms mechanical coupling. Decoupled flows falsify it.
#   • Significant differences in elongation kinetics or shape precision in mutants vs. wild type confirm the adhesion role.
#
# (d) Implications / next steps
#   • If coupling is critical, test whether exogenous forces transmitted through the ectoderm can rescue endoderm movements.
#   • If decoupled, focus on endoderm-intrinsic drivers.
#
# 8. Variability and robustness
# Hypotheses:
#   A. Key morphometric metrics are consistent across embryos (low variability).
#   B. Compensatory behaviors (e.g. more intercalations if divisions are sparse) ensure robust length.
#
# (a) Approach
#   • Quantify elongation speed, division orientation, lumen volume, neighbor exchange rate in ≥10 embryos. Compute coefficients of variation.
#   • Correlate local intercalation rates against local proliferation rates across all embryos.
#
# (b) Possible outcomes
#   • Low CV (<10%) for each metric indicates high reproducibility.
#   • Negative correlation between proliferation and intercalation rates suggests compensation.
#
# (c) Confirmation vs. falsification
#   • High variability (>30% CV) refutes A.
#   • A statistically significant negative slope in the intercalation vs. proliferation scatter-plot confirms B.
#
# (d) Implications / next steps
#   • For low variability, pursue the conserved molecular underpinnings; for high variability, investigate maternal vs. zygotic contributions.
#   • If compensation occurs, disrupt one mechanism (e.g. block divisions) and see whether intercalation increases further.
#
# 9. Axis specification and left–right asymmetry
# Hypotheses:
#   A. Left–right differences in cell shape/proliferation/migration emerge at a defined stage.
#   B. Perturbing a laterality gene (e.g. Myo1D) causes quantifiable shifts in 3D tube chirality.
#
# (a) Approach
#   • Compute handedness metrics (e.g. average torsion of cell tracks, chirality of tissue curvature) separately for left and right halves.
#   • Image laterality mutants and compare symmetry metrics to wild type.
#
# (b) Possible outcomes
#   • A clear onset time when asymmetry metrics diverge from zero.
#   • Mutants show flat or inverted asymmetry curves.
#
# (c) Confirmation vs. falsification
#   • A statistically significant non‐zero asymmetry index confirms A; no change over time falsifies it.
#   • Absent or reversed chirality in mutants confirms B.
#
# (d) Implications / next steps
#   • Pinpoint the molecular switch by imaging upstream candidates (Nodal, Cerl2).
#   • Rescue experiments: restore laterality gene only in endoderm vs. mesoderm to map tissue-specific roles.
#
# 10. Feedback loops and emergent behavior
# Hypotheses:
#   A. Local curvature feeds back on cell polarity/division orientation (“cells sense global shape”).
#   B. A computational model incorporating your measured cell behaviors and mechanical parameters can recapitulate organ shape.
#
# (a) Approach
#   • Compute at each timepoint the local curvature and the polarity vector or mitotic spindle axis, then correlate them.
#   • Build a vertex‐ or continuum‐level simulation seeded with your empirical division rates, intercalation rules, and tension maps; compare simulated shapes to real ones.
#
# (b) Possible outcomes
#   • A positive correlation between curvature and polarity alignment indicates feedback.
#   • The model reproduces the tube’s 3D geometry only when feedback terms are included, but fails without them.
#
# (c) Confirmation vs. falsification
#   • Significant alignment (e.g. >45% of polarity vectors within 30° of curvature direction, p<0.01) confirms feedback.
#   • A model that matches shape only when you exclude curvature‐dependent behaviors falsifies the need for feedback.
#
# (d) Implications / next steps
#   • If feedback is real, identify the mechanosensors (e.g. integrin focal complexes) mediating it.
#   • Use the validated model to predict outcomes of untested perturbations (e.g. spatially confined myosin activation) and then test them in vivo.
#
# ––––––––––––––––––––––––––––––––––––––––––––––––
# By defining these hypotheses up front, you can tailor your image-analysis pipelines to extract exactly the features you need—cell tracks, neighbor graphs, strain maps, reporter intensities—and then apply rigorous statistical tests to confirm or refute each morphogenetic mechanism.

# %%
hyp = """1.  Optimal‐transport of cell density  
    •  Hypothesis: The tissue‐scale reorganization of cells during gut invagination follows a minimum‐energy (Wasserstein) path.  
    •  Test: Fit an SB model between an early “flat endoderm” state and a mid-stage “tube forming” state. Compare the inferred transport plan (vector field of cell movements) to actual cell‐tracking trajectories from the lightsheet data. Significant deviations would falsify a purely energy‐minimizing hypothesis.  
"""
program = ask("Frame the hindgut developmental program as minimizing energy as suggested by the following hypothesis.", hyp)
print(program)
# Out:
# Here is one way to cast the entire hindgut‐invagination program as an energy-minimization (optimal‐transport) process—and show how you would falsify or validate it experimentally.
#
# 1. Representing the tissue states as cell-density distributions
#    • At time t=0 (“flat endoderm”) measure the 2D (or 3D) cell density ρ₀(x).
#    • At an intermediate time t=1 (“tube forming”) measure ρ₁(x).
#    • These are your two end-points in the “space of densities.”
#
# 2. The optimal‐transport (Wasserstein) hypothesis
#    • Suppose the tissue evolves along the minimal‐action geodesic connecting ρ₀ to ρ₁ in Wasserstein-2 space.
#    • In the Benamou–Brenier formulation, one seeks velocity fields v(t,x) and intermediate densities ρ(t,x) that minimize
#        ∫₀¹ ∫ ½‖v(t,x)‖² ρ(t,x) dx dt
#      subject to the continuity equation ∂ₜρ + ∇·(ρ v)=0, with ρ(0)=ρ₀ and ρ(1)=ρ₁.
#    • The solution (ρ*(t),v*(t)) is the “least‐energy” transport plan.
#
# 3. Fitting a Schrödinger-Bridge (SB) or entropic‐OT model
#    • A Schrödinger‐Bridge adds a small diffusion term and an entropy penalty, making the inverse problem numerically stable.
#    • Fit the SB model to your measured ρ₀ and ρ₁. Numerically solve for the most likely drift field b*(t,x) that transports ρ₀→ρ₁.
#    • This yields a time-indexed vector field v*≈b* predicting how each infinitesimal parcel of endoderm should move to minimize “transport cost.”
#
# 4. Comparing to in vivo cell tracks
#    • From your lightsheet timelapse, extract single‐cell trajectories xᵢ(t) for many cells, then estimate their empirical velocity field v_obs(t,x).
#    • Compute a deviation metric, e.g.
#          E = ∫₀¹ ∫‖v_obs(t,x) – v*(t,x)‖² ρ_obs(t,x) dx dt
#      or an explicit cell‐by‐cell residual.
#    • Statistical test: if E is significantly larger than what you’d expect from experimental noise, the pure energy-minimization hypothesis is falsified.
#
# 5. Biological interpretation
#    • A close match (small E) would suggest that morphogen-driven changes in cell polarity and adhesion effectively implement a tissue-scale gradient descent on a global “transport‐energy” functional.
#    • Large systematic deviations would imply additional driving forces (e.g. local actomyosin pulses, regional differential growth) that cannot be captured by a single minimal‐energy geodesic.
#
# 6. Extensions and perturbations
#    • Perturb a candidate regulator (e.g. inhibit Rho kinase, alter extracellular matrix stiffness) and repeat the analysis. A shift toward higher transport cost would link that regulator to global energy budgeting.
#    • Couple the OT model to gene‐regulatory or signaling models by letting the target density ρ₁ itself depend on morphogen gradients.
#    • If you can map mechanical stresses, incorporate a more detailed cost function—for instance, one that penalizes changes in local tissue curvature or inhomogeneous strain.
#
# In sum, framing hindgut invagination as finding the minimum-action path in density‐space lets you (a) predict a unique tissue‐scale flow field from two snapshots, and (b) directly confront that prediction with cell‐tracking data. Significant mismatches falsify the hypothesis that the system is merely following a “cheapest” morphological route.

# %%
phrase = "antibodies, antibody design"
act1 = ask("If I have a lightsheet imaging dataset of hindgut development over time, what hypothesis driven inquires should be performed on the following information?", phrase)
act2 = ask("If I have a 2D movie of the developing Drosophila hindgut acquired by identifying and unraveling the apical surface of the epithelial tissue of a lightsheet dataset of developing hindgut, what hypothesis driven inquires should be performed on the following information?", phrase)
print(act1)
print(act2)
# Out:
# Below are two sets of concrete, hypothesis‐driven questions you can ask of your 4D lightsheet movies, first using commercially available or published antibodies, and then in the context of designing or optimizing new antibodies for this system.
#
# 1. Hypotheses for antibody‐based readouts in hindgut development
#    A. Patterning & cell‐type specification
#      •  Hypothesis: “Cells along the dorsal–ventral axis of the hindgut exhibit a graded expression of Sonic Hedgehog (Shh) over time.”
#        – Stain for Shh protein; quantify intensity gradients at successive somite stages.
#      •  Hypothesis: “Endodermal progenitors switch from a FOXA2⁺ state to a CDX2⁺ fate between 24–36 h of development.”
#        – Co‐stain for FOXA2 and CDX2; score single‐cell co‐localizations in 3D.
#    B. Proliferation, differentiation & apoptosis
#      •  Hypothesis: “Proliferative index (Ki-67⁺) peaks just posterior to the forming cloacal membrane and then declines as cells differentiate.”
#        – Double stain for Ki-67 and a differentiation marker (e.g. cytokeratin-8); map proliferation hotspots over time.
#      •  Hypothesis: “Spatial pattern of apoptosis (cleaved Caspase-3⁺) coincides with lumen formation.”
#        – Quantify Caspase-3⁺ voxels relative to luminal volume over time.
#    C. Cell migration & morphogenetic movements
#      •  Hypothesis: “Neural crest–derived neurons (TUJ1⁺ or SOX10⁺) colonize the hindgut in a wave from anterior to posterior.”
#        – 3D track TUJ1⁺ cell clusters; compare speed/directionality at different stages.
#    D. Extracellular matrix (ECM) remodeling
#      •  Hypothesis: “Fibronectin deposition increases at the lateral walls of the hindgut prior to epithelial bending.”
#        – 3D segmentation and volume‐rendering of fibronectin signal; correlate with cell‐shape changes.
#    E. Signaling pathway activation
#      •  Hypothesis: “Phospho-β-catenin accumulates basolaterally in hindgut epithelial cells at the onset of villus formation.”
#        – 3D surface‐intensity mapping of p-β-catenin antibody; measure co‐localization with cell‐junction markers (E-cadherin).
#
# 2. Hypotheses around antibody design & optimization
#    A. Penetration & clearing compatibility
#      •  Hypothesis: “A smaller (~12 kDa) nanobody against E-cadherin will penetrate cleared hindgut tissue twice as fast as a 150 kDa IgG and yield more uniform staining.”
#        – Compare signal‐to‐noise and depth‐profiles of directly labeled nanobody vs conventional secondary antibody.
#    B. Fluorophore selection & multiplexing
#      •  Hypothesis: “Far-red dyes (e.g. Alexa-647) exhibit less photobleaching under long‐term lightsheet illumination than green dyes, enabling longer time‐lapse captures.”
#        – Label identical antigens with different fluors; measure intensity decay over repeated scans.
#    C. Affinity & epitope accessibility
#      •  Hypothesis: “An antibody raised against the extracellular domain of integrin-β1 will show higher signal in intact 3D epithelium than one against its cytoplasmic tail (which may be masked).”
#        – Design two monoclonals to each epitope; compare staining homogeneity in whole‐mount samples.
#    D. Reducing cross-reactivity
#      •  Hypothesis: “A CDR-grafted scFv will display lower off-target binding in chick hindgut than the parent mouse monoclonal.”
#        – Perform side‐by‐side specificity screens (knockout or peptide‐block controls) in your lightsheet setup.
#    E. Quantitative readouts & calibration
#      •  Hypothesis: “Conjugating a known number of fluorophores per antibody molecule (degree of labeling = DOL) will enable absolute quantification of target proteins in 3D.”
#        – Prepare antibodies at different DOLs; verify linearity of signal vs epitope abundance using bead standards embedded in agarose.
#
# By framing your lightsheet dataset interrogation as “If X is true, then we should see Y in our antibody signal over time or space,” you turn descriptive imaging into rigorous, testable hypotheses. You can then use your longitudinal 3D data to statistically confirm or refute each.
# Below are several hypothesis‐driven inquires you can pursue by combining your 2D apical‐surface movie with targeted immunostaining (and, where needed, custom antibody design).  Each item states a biological hypothesis, suggests which proteins to probe, and outlines how you’d use antibodies or new antigen targets to test it.
#
# 1. Myosin II–driven Apical Constriction
#    • Hypothesis: Pulsatile activation of non-muscle Myosin II drives sequential apical constriction during hindgut invagination.
#    • Readouts: Spatiotemporal patterns of Myosin II regulatory light chain phosphorylation (pMRLC) vs. total Myosin II.
#    • Antibodies:
#      – Commercial anti-pMRLC (phospho-Sqh) and anti-Sqh (non-phospho).
#      – If off-the-shelf pMRLC gives high background, design a phospho-specific peptide antigen around the Ser21 (Sqh) site and raise a rabbit polyclonal.
#    • Analysis: Correlate local peaks of pMRLC intensity with changes in cell shape (apical area reduction) frame by frame.
#
# 2. Apicobasal Polarity Remodeling
#    • Hypothesis: Redistribution of Par complex components (Bazooka/Par3, Par6, aPKC) precedes directional cell elongation along the hindgut axis.
#    • Readouts: Apical vs. junctional levels of Bazooka and aPKC over time.
#    • Antibodies:
#      – Anti-Bazooka (mouse monoclonal) and anti-aPKC.
#      – If aPKC signal is weak, design a synthetic peptide encompassing the activation loop and produce a guinea-pig antiserum.
#    • Analysis: Quantify fluorescence intensity ratios (junction vs. medial apical) and test whether differential localization predicts the main axis of cell elongation.
#
# 3. Planar Cell Polarity (PCP) Coordination
#    • Hypothesis: Core PCP proteins (Frizzled, Dishevelled, Van Gogh) establish a tissue‐scale axis that orients cell intercalations.
#    • Readouts: Subcellular asymmetry of PCP components at cell–cell interfaces.
#    • Antibodies:
#      – Anti-Dishevelled (Dsh) and anti-Van Gogh (Vang).
#      – For higher specificity, design antibodies against Dsh’s DIX domain or Vang’s C-terminal tail.
#    • Analysis: Map vector fields of PCP orientation and overlay with cell intercalation trajectories from your movie.
#
# 4. Extracellular Matrix (ECM)–Integrin Feedback
#    • Hypothesis: Local deposition of Laminin or Collagen IV under the apical surface modulates integrin‐mediated adhesion, influencing cell shape changes.
#    • Readouts: Laminin/Collagen IV distribution and integrin βPS localization at the basal side of the apical surface.
#    • Antibodies:
#      – Anti-Laminin α (commercial) and anti-Collagen IV.
#      – Anti-Integrin βPS (myospheroid); if signal is low, raise a rat monoclonal against the PSI domain.
#    • Analysis: Co‐registration of ECM patterns with regions of high curvature or persistent cell rearrangement.
#
# 5. Hedgehog (Hh) Gradient and Proliferation
#    • Hypothesis: A gradient of Hedgehog signaling across the hindgut epithelium differentially regulates proliferation or cell cycle exit.
#    • Readouts: Levels of Hh ligand, Patched (Ptc), and downstream pMad (Dpp pathway cross‐talk).
#    • Antibodies:
#      – Anti-Hh (C-terminal), anti-Ptc, anti-pMad.
#      – To separate Hh isoforms, design N-vs. C-terminal peptide antibodies.
#    • Analysis: Measure nuclear pMad and Ptc membrane intensity vs. cell cycle markers (e.g., anti-PH3 for mitosis) in mapped coordinates.
#
# 6. Notch Boundary Formation
#    • Hypothesis: Notch signaling at compartment boundaries restricts lateral cell mixing and defines hindgut segmental borders.
#    • Readouts: Notch intracellular domain (NICD) nuclear accumulation, Delta and Serrate ligand localization.
#    • Antibodies:
#      – Anti-NICD (rabbit polyclonal) and anti-Delta.
#      – For greater temporal resolution, design an anti-NICD phospho-site antibody if the cleavage site is known.
#    • Analysis: Relate boundary‐specific NICD peaks to cell motility barriers in your time‐lapse.
#
# 7. Rho GTPase Dynamics
#    • Hypothesis: Local activation of Rho1 vs. Rac1 underlies different modes of apical constriction vs. basal protrusion.
#    • Readouts: GTP‐bound Rho1 and Rac1 using conformation‐specific antibodies or biosensors.
#    • Antibodies/Biosensors:
#      – If no good antibodies exist, clone and express Rho1‐ or Rac1‐binding domains (e.g., Rhotekin-RBD) fused to GFP for live imaging or fix-stain with anti-GFP.
#    • Analysis: Overlay active-GTPase signals with cell shape oscillations.
#
# 8. Phosphoinositide Redistribution
#    • Hypothesis: Local PI(4,5)P2 enrichment at the apical cortex recruits actin–linker proteins (e.g., Moesin) to drive membrane stability.
#    • Readouts: PI(4,5)P2 reporters or anti-PIP2 antibodies + anti-Moesin (pERM).
#    • Antibodies:
#      – Anti-pERM for active Moesin; to boost specificity, design a peptide around the phosphorylated Thr556.
#    • Analysis: Temporal cross‐correlation of PIP2 signals, pERM recruitment, and apical area fluctuations.
#
# 9. Apoptotic Cell Clearance
#    • Hypothesis: Programmed cell death at specific positions sculpts the hindgut curve; neighboring cells engulf corpses via Rac1‐dependent crawling.
#    • Readouts: Cleaved Caspase-3, Mosaic sensor (e.g., Caspase activation reporter), plus anti-Engulfment receptor Draper.
#    • Antibodies:
#      – Anti-cleaved Dcp-1 (Drosophila Caspase-1) and anti-Draper.
#    • Analysis: Track timing of apoptosis events vs. local cell neighbor movements in your movie.
#
# 10. Custom Antibody Design Workflow
#    • Target selection: Choose key phosphorylation sites, low‐complexity loops, or unique C-terminal tails not conserved in other proteins.
#    • Antigen: Synthesize 12–20 aa peptides, conjugate to KLH, immunize rabbits/guinea pigs.
#    • Validation: Western on embryo lysates, peptide competition, immunostain of known mutants.
#
# By embedding one or more of these antibody‐based assays into your 2D movie pipeline, you can move from descriptive imaging to hypothesis testing: quantifying how spatiotemporal patterns of signaling, cytoskeleton, polarity, or adhesion relate mechanistically to the morphogenetic choreography of the Drosophila hindgut.
