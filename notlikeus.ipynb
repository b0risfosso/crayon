# %%
import sqlite3, random, pathlib
from search import search_library
from dotenv import load_dotenv
from openai import OpenAI, OpenAIError
from pydantic import BaseModel, Field, ValidationError
import os
from openai import OpenAI
from pydantic import BaseModel
import json
import time
import random
from helpers.sentence_splitter import split_sentences
from time import sleep
from tqdm import tqdm  # optional: pip install tqdm


SYS_PROMPT_PARSE_ELEMENTS = ("Read the following text and separate each element of the suggested story framework into a object with the name and text.\n"
        "You should return a list of objects containing each story element in a given structure.\n"
        "Do not add or remove text; your job is to parse and deconstruct the text string into the given structure.\n"
        "Treat every line that begins with a number followed by “.” and a space (e.g. “1. ”) or **Element** as the NAME of a new element."
        "Capture all following lines up to—but not including—the next such line as the TEXT for that element.")

SYSTEM_PROMPT_IMAGINE = """
Your task is to take a human imaginative directive and translate it into a coherent, structured list of domains, technologies, and disciplines that could be explored to realize or approximate that imaginative directive.
The goal is to break down the directive into actionable or researchable avenues across science, technology, psychology, education, or other relevant fields.
Each entry should be self-contained, meaning it should be understandable on its own, and clearly tied back to the core imaginative directive.
"""


ELEM_FUNC = {
    "type": "function",
    "function": {
        "name": "element_function",
        "description": "Read the following text and separate each element of the suggested story framework into a object with the name and text. \
        You should return a list of objects containing each story element in a given structure. \
        Do not add or remove text; your job is to parse and deconstruct the text string into the given structure.",
        "parameters": {
            "type": "object",
            "properties": {
                "element": {
                    "type": "array",
                    "items": {
                        "type": "object",
                        "properties": {
                            "name": { "type": "string" },
                            "text": { "type": "string" }
                        },
                        "required": ["name", "text"]
                    }
                }
            },
            "required": ["element"]
        }
    }
}



def ask(sys_msg, usr_msg):
    resp = client.chat.completions.create(
        model=OPENAI_MODEL,
        messages=[
            {"role": "system", "content": sys_msg},
            {"role": "user", "content": usr_msg}
        ]
    )
    return resp.choices[0].message.content

def sample_text(text, x):
    max_start = max(0, len(text) - x)
    random_start = random.randint(0, max_start)
    excerpt = text[random_start:random_start + x]
    return excerpt


load_dotenv()
client = OpenAI()
OPENAI_MODEL = os.getenv("OPENAI_MODEL", "gpt-4o")

DB_FILE = "library.sqlite"
MAX_RESULTS = 100
# Out:
# /Users/b/fantasiagenesis/crayon/library/meaning/ACFrOgDaxpNvLwDDUDTTp4s1S6tXIfmIIGkt6672UYmdd33l1h-Ce6f0FHUWReZp5H9EQ72qb0V0lKI88KC4nQmpmnejqMBMk_WQSYB3ijM8XEyG1vbKEuj9CPWtonjTTCIwY4h7Gca5iuwb4GkD.pdf

# %%
KEYWORDS = ["hindgut morphogenesis"]
search_results = search_library(DB_FILE, KEYWORDS, MAX_RESULTS, match_all=True)
hindgut = {}
for r in search_results:
    title, text = r['title'], r['text']
    hindgut[title] = text
    print(title, len(text))
# Out:
# Distinct Cellular and Junctional Dynamics Independently Regulate the Rotation and Elongation of the Embryonic Gut in Drosophila 86702
# It Takes Guts: The Drosophila Hindgut as a Model System for Organogenesis 99729

# %%
KEYWORDS = ["biology"]
search_results = search_library(DB_FILE, KEYWORDS, MAX_RESULTS, match_all=True)
biology = {}
for r in search_results:
    title, text = r['title'], r['text']
    biology[title] = text
    print(title, len(text))
# Out:
# The Birds of East Africa: Kenya, Tanzania, Uganda, Rwanda, and Burundi 1256135
# Industrial Microbiology and Biotechnology 1994002
# The Collective Intelligence of Evolution and Development 108822
# Bioelectromagnetism - Principles and Applications of Bioelectric and Biomagnetic Fields 1279813
# A Review of Morphogenetic Engineering 95479
# Gene regulatory networks exhibit several kinds of memory: Quantification of memory in biological and random transcriptional networks 121145
# A Cellular Platform for the Development of Synthetic Living Machines 78897
# Bioelectric Signaling: Reprogrammable Circuits Underlying Embryogenesis, Regeneration, and Cancer 105977
# CRISPR/Cas9 Engineering of Adult Mouse Liver Demonstrates That the Dnajb1–Prkaca Gene Fusion Is Sufficient to Induce Tumors Resembling Fibrolamellar Hepatocellular Carcinoma 78713
# Physiological Inputs Regulate Species-Specific Anatomy during Embryogenesis and Regeneration 91465
# How Proteins Work 138487
# Errors of Geometry: Regeneration in a Broader Perspective 15213
# The structural biology of CRISPR-Cas systems 55940
# Endogenous Bioelectric Signaling Networks: Exploiting Voltage Gradients for Control of Growth and Form 127642
# How Do Living Systems Create Meaning? 103140
# Bistability of Somatic Pattern Memories: Stochastic Outcomes in Bioelectric Circuits Underlying Regeneration 76981
# Are Planaria Individuals? What Regenerative Biology is Telling Us About the Nature of Multicellularity 54062
# Revisiting Burr and Northrop’s “The Electro‑Dynamic Theory of Life” (1935) 44737
# None 2495074
# The Closing of the American Mind 959700
# The CRISPR-Cas Immune System: Biology, Mechanisms and Applications 61494
# Introduction to Biomedical Engineering: Biomechanics and Bioelectricity - Part I 193033
# Lehninger Principles of Biochemistry 4585929
# None 101872
# Role of Membrane Potential in the Regulation of Cell Proliferation and Differentiation 91704
# Principles for the Design of Multicellular Engineered Living Systems 173048
# Re-Membering the Body: applications of computational neuroscience to the top-down control of regeneration of limbs and other complex organs 143168
# Gap Junctional Communication in Morphogenesis 107931
# A call for a better understanding of causation in cell biology 12040
# Base Editing Rescue of Spinal Muscular Atrophy in Cells and in Mice 132544
# Bioinformatics and Functional Genomics 3627645
# Introduction to Protein Science - Architecture, Function, and Genomics 1400994
# Living Things Are Not (20th Century) Machines: Updating Mechanism Metaphors in Light of the Modern Science of Machine Behavior 97854
# Principles of Economics 3028227
# Humans and Electricity: Understanding Body Electricity and Applications 1675468
# Why isn’t sex optional? 70180
# Frohlich Coherent States: Implications for Thermal Sensitivity of Cells (1985) 16924
# Deep Learning 1780338
# Somatic multicellularity as a satisficing solution to the prediction-error minimization problem 70018
# None 5149195
# In Pursuit of Designing Multicellular Engineered Living Systems: A Fluid Mechanical Perspective 103477
# AI-driven Automated Discovery Tools Reveal Diverse Behavioral Competencies of Biological Networks 154329
# Nested Selves: Self-Organization and Shared Markov Blankets in Prenatal Development in Humans 84896
# Internet of Things and Big Data Technologies for Next Generation Healthcare 844493
# None 108416
# Elements of Information Theory: Second Edition 1212302
# The Nature of Man and the Meaning of Existence 219388
# The bioelectric code: An ancient computational medium for dynamic control of growth and form 117399
# Screening Biophysical Sensors and Neurite Outgrowth Actuators in Human Induced-Pluripotent-Stem-Cell-Derived Neurons 80655
# The Biology of Cancer (Second Edition) 3844708
# The stability of memories during brain remodeling: A perspective 77522
# ENGINEERED MULTICELLULAR ORGANISMS 77213
# Technological Approach to Mind Everywhere: An Experimentally-Grounded Framework for Understanding Diverse Bodies and Minds 261609
# Transcriptome Profiling: Progress and Prospects 1792638
# Engineered Multicellular Organisms 262308
# Future Medicine: From Molecular Pathways to the Collective Intelligence of the Body 108416
# Applications and Ethics of Computer-Designed Organisms 12396
# Physiological Inputs Regulate Species-specific Anatomy During Embryogenesis and Regeneration 92524
# None 101872
# Synthetic Living Machines: A New Window on Life 101872
# Energy and Civilization: A History 1245429
# Biological Robots: Perspectives on an Emerging Interdisciplinary Field 72675
# Biochemical Production Capabilities of Escherichia coli 69684
# Motile Living Biobots Self-Construct from Adult Human Somatic Progenitor Seed Cells 128021
# Endogenous Bioelectrical Networks Store Non-Genetic Patterning Information 58545
# Gene Cloning and DNA Analysis 822860
# Developmental Neurobiology 1273475
# Endless forms most beautiful 2.0: teleonomy and the bioengineering of chimaeric and synthetic organisms 133502
# Bioelectricity: A Quantitative Approach 1065125
# Transducing Bioelectric Signals into Epigenetic Pathways During Tadpole Tail Regeneration 57753
# Bioelectric Signals that Reveal, Induce and Normalize Cancer 196020
# Gap Junctional Blockade Stochastically Induces Different Species-Specific Head Anatomies in Genetically Wild-Type Girardia dorotocephala Flatworms 117269
# Top-down models in biology: explanation and control of complex living systems above the molecular level 100188
# The Yin and Yang of Breast Cancer: Ion Channels as Determinants of Left–Right Functional Differences 59689
# Perspective: The Promise of Multi-Cellular Engineered Living Systems 96361
# Signal Processing Techniques for Computational Health Informatics 804841
# Introduction to Biomedical Engineering: Biomechanics and Bioelectricity - Part II 216049
# Kinematic self-replication in reconﬁgurable organisms 51812
# Endogenous bioelectrical networks store non-genetic patterning information during development and regeneration 54925
# Embryos Assist Morphogenesis through Collective Teratogen Resistance 127128
# Gap Junctions Provide New Links in Left-Right Patterning 13735
# Multiple Frohlich Coherent States in Biological Systems: Computer Simulation 12059
# Engineering multicellular living systems—a Keystone Symposia report 84556
# Principled Limitations on Self-Representation for Generic Physical Systems 70522
# Information Theory as an Experimental Tool for Integrating Disparate Biophysical Signaling Modules 62018
# Fundamental Neuroscience (3rd edition) 5149195
# Motile Living Biobots Self-Construct from Adult Human Somatic Progenitor Seed Cells 128401
# CRISPy-web: An online resource to design sgRNAs for CRISPR applications 16932
# Blueprint for Immortality: The Electric Patterns of Life 366705
# The Molecules of Life: Physical and Chemical Principles 307936
# Progress in Molecular Biology and Translational Science, Volume 181 54842
# Physiological Controls of Large-Scale Patterning in Planarian Regeneration: A Molecular and Computational Perspective on Growth and Form 125671
# Mathematical Cardiac Electrophysiology 822750
# New Clues about the Origins of Biological Intelligence 13284
# TNRC18 engages H3K9me3 to mediate silencing of endogenous retrotransposons 131109
# Chemistry: Atoms First 2e 2495074
# The Cytoskeleton: Diverse Roles in a Plant’s Life 478781
# Molecular Biology of the Cell 6160108
# Electrical Diseases of the Heart: Basic Foundations and Primary Electrical Diseases 2453914
# Cellular signaling pathways as plastic, proto-cognitive systems: Implications for biomedicine 118816

# %%
KEYWORDS = ["math"]
search_results = search_library(DB_FILE, KEYWORDS, MAX_RESULTS, match_all=True)
math = {}
for r in search_results:
    title, text = r['title'], r['text']
    math[title] = text
    print(title, len(text))
# Out:
# Electricity and Magnetism 2060417
# Bioelectromagnetism - Principles and Applications of Bioelectric and Biomagnetic Fields 1279813
# A Cellular Platform for the Development of Synthetic Living Machines 78897
# Bioelectric Signaling: Reprogrammable Circuits Underlying Embryogenesis, Regeneration, and Cancer 105977
# Physiological Inputs Regulate Species-Specific Anatomy during Embryogenesis and Regeneration 91465
# Endogenous Bioelectric Signaling Networks: Exploiting Voltage Gradients for Control of Growth and Form 127642
# How Do Living Systems Create Meaning? 103140
# An Introduction to Mechanics 1039248
# Revisiting Burr and Northrop’s “The Electro‑Dynamic Theory of Life” (1935) 44737
# None 2495074
# The Closing of the American Mind 959700
# Introduction to Biomedical Engineering: Biomechanics and Bioelectricity - Part I 193033
# Bioinformatics and Functional Genomics 3627645
# Introduction to Protein Science - Architecture, Function, and Genomics 1400994
# Living Things Are Not (20th Century) Machines: Updating Mechanism Metaphors in Light of the Modern Science of Machine Behavior 97854
# Principles of Economics 3028227
# Humans and Electricity: Understanding Body Electricity and Applications 1675468
# Deep Learning 1780338
# Learning Attentional Templates for Value-Based Decision-Making 142195
# Somatic multicellularity as a satisficing solution to the prediction-error minimization problem 70018
# None 5149195
# In Pursuit of Designing Multicellular Engineered Living Systems: A Fluid Mechanical Perspective 103477
# Internet of Things and Big Data Technologies for Next Generation Healthcare 844493
# Elements of Information Theory: Second Edition 1212302
# The bioelectric code: An ancient computational medium for dynamic control of growth and form 117399
# The Biology of Cancer (Second Edition) 3844708
# Technological Approach to Mind Everywhere: An Experimentally-Grounded Framework for Understanding Diverse Bodies and Minds 261609
# Engineered Multicellular Organisms 262308
# Physiological Inputs Regulate Species-specific Anatomy During Embryogenesis and Regeneration 92524
# Endogenous Bioelectrical Networks Store Non-Genetic Patterning Information 58545
# Bioelectricity: A Quantitative Approach 1065125
# Bioelectric Signals that Reveal, Induce and Normalize Cancer 196020
# Gap Junctional Blockade Stochastically Induces Different Species-Specific Head Anatomies in Genetically Wild-Type Girardia dorotocephala Flatworms 117269
# Top-down models in biology: explanation and control of complex living systems above the molecular level 100188
# Signal Processing Techniques for Computational Health Informatics 804841
# Introduction to Biomedical Engineering: Biomechanics and Bioelectricity - Part II 216049
# Endogenous bioelectrical networks store non-genetic patterning information during development and regeneration 54925
# Embryos Assist Morphogenesis through Collective Teratogen Resistance 127128
# Principled Limitations on Self-Representation for Generic Physical Systems 70522
# Fundamental Neuroscience (3rd edition) 5149195
# Physiological Controls of Large-Scale Patterning in Planarian Regeneration: A Molecular and Computational Perspective on Growth and Form 125671
# Mathematical Cardiac Electrophysiology 822750
# New Clues about the Origins of Biological Intelligence 13284
# Chemistry: Atoms First 2e 2495074
# Molecular Biology of the Cell 6160108
# The Invention of Enterprise: Entrepreneurship from Ancient Mesopotamia to Modern Times 2030465
# The Soul of a New Machine 562044
# Air and Missile Defense Systems Engineering 549026
# Davidson's Principles and Practice of Medicine, 24th Edition 7406533
# Military Handbook: Missile Flight Simulation Part One Surface-to-Air Missiles 839746
# Encyclopedia of Artificial Intelligence: The Past, Present, and Future of AI 1209133
# The Basics of American Government 853534
# War, Will, and Warlords 642606
# Gaining Victory in Systems Warfare: China’s Perspective on the U.S.-China Military Balance 627537
# The Age of AI and Our Human Future 377800
# Life After Death, Powerful Evidence You Will Never Die 282025
# Aulton's Pharmaceutics: The Design and Manufacture of Medicines (5th Edition) 3575349
# Crude Awakenings: Global Oil Security and American Foreign Policy 658594
# National Security Intelligence and Ethics 962755
# The Oxford History of Modern War 890100
# Personal Safety Handbook 2016-2017 49862
# The Psychology of Money: Timeless Lessons on Wealth, Greed, and Happiness 307032
# Where Honeybees Thrive: Stories from the Field 345066
# Money, Banking, and the Financial System, Third Edition 2368368
# Emerging Research on Monetary Policy, Banking, and Financial Markets 613830
# Modern Money Theory: A Primer on Macroeconomics for Sovereign Monetary Systems 813512
# The Datapreneurs: The Promise of AI and the Creators Building Our Future 272638
# Morality: An Introduction to Ethics 175264
# Guide to Money & Investing 575841
# Hierarchy Theory: An Overview 59769
# What is Time and What Causes Time? 65291
# The Power of Music: An Exploration of the Evidence 2063191
# God, Marriage, and Family: Rebuilding the Biblical Foundation 1011956
# A History of Modern Iran 601046
# Animal Eyes, Second Edition 628255
# The End of Banking: Money, Credit, and the Digital Revolution 434462
# Racialized Identities: Race and Achievement among African American Youth 472955
# Military Coercion and US Foreign Policy 688566
# Fasting During Pregnancy and Children's Academic Performance 62764
# The Algorithmic Beauty of Plants 326727
# Missile Configuration Design 510605
# The How and Why Wonder Book of Time 88692
# The Cambridge World History of Violence: Volume III, 1500–1800 CE 1917216
# Davidson's Principles and Practice of Medicine 7406660
# Engineering Surveying 1201290
# Aerodynamics - Ballistic Missile Series 258173
# The Age of Surveillance Capitalism: The Fight for a Human Future at the New Frontier of Power 1693161
# Nuclear Physics 1529080
# Computed Tomography: Principles, Design, Artifacts, and Recent Advances 1130956
# TubULAR: tracking in toto deformations of dynamic tissues via constrained maps 68564
# Principles of Computerized Tomographic Imaging 576060
# The Design of Approximation Algorithms 1355878
# Gray Hat Hacking: The Ethical Hacker’s Handbook (Third Edition) 1636123
# Data Structures and Algorithm Analysis, Edition 3.2 (C++ Version) 1321855
# Classical Mechanics 1861006
# Cryptography/Print version 376591
# The Functional Analysis of Quantum Information Theory 257431
# Principles of Algorithmic Problem Solving 487762
# None 932286
# Understanding Laterality Disorders and the Left-Right Organizer: Insights from Zebrafish 147554

# %%
KEYWORDS = ["mechanics"]
search_results = search_library(DB_FILE, KEYWORDS, MAX_RESULTS, match_all=True)
mechanics = {}
for r in search_results:
    title, text = r['title'], r['text']
    mechanics[title] = text
    print(title, len(text))
# Out:
# Industrial Microbiology and Biotechnology 1994002
# Electricity and Magnetism 2060417
# Bioelectromagnetism - Principles and Applications of Bioelectric and Biomagnetic Fields 1279813
# Development of Mass Marketing: The Automobile and Retailing Industries 718579
# Gene regulatory networks exhibit several kinds of memory: Quantification of memory in biological and random transcriptional networks 121145
# Bioelectric Signaling: Reprogrammable Circuits Underlying Embryogenesis, Regeneration, and Cancer 105977
# Physiological Inputs Regulate Species-Specific Anatomy during Embryogenesis and Regeneration 91465
# Endogenous Bioelectric Signaling Networks: Exploiting Voltage Gradients for Control of Growth and Form 127642
# An Introduction to Mechanics 1039248
# None 2495074
# Introduction to Biomedical Engineering: Biomechanics and Bioelectricity - Part I 193033
# Lehninger Principles of Biochemistry 4585929
# None 101872
# Principles for the Design of Multicellular Engineered Living Systems 173048
# Some Aspects of the Early Sense of Self 132800
# Electrical Stimulation for Pelvic Floor Disorders 734489
# Introduction to Protein Science - Architecture, Function, and Genomics 1400994
# Living Things Are Not (20th Century) Machines: Updating Mechanism Metaphors in Light of the Modern Science of Machine Behavior 97854
# Humans and Electricity: Understanding Body Electricity and Applications 1675468
# Deep Learning 1780338
# None 5149195
# Reinventing the State: Economic Strategy and Institutional Change in Peru 828796
# In Pursuit of Designing Multicellular Engineered Living Systems: A Fluid Mechanical Perspective 103477
# Nested Selves: Self-Organization and Shared Markov Blankets in Prenatal Development in Humans 84896
# Elements of Information Theory: Second Edition 1212302
# The bioelectric code: An ancient computational medium for dynamic control of growth and form 117399
# The Biology of Cancer (Second Edition) 3844708
# Technological Approach to Mind Everywhere: An Experimentally-Grounded Framework for Understanding Diverse Bodies and Minds 261609
# Physiological Inputs Regulate Species-specific Anatomy During Embryogenesis and Regeneration 92524
# None 101872
# Synthetic Living Machines: A New Window on Life 101872
# Energy and Civilization: A History 1245429
# Bioelectricity: A Quantitative Approach 1065125
# Bioelectric Signals that Reveal, Induce and Normalize Cancer 196020
# Gap Junctional Blockade Stochastically Induces Different Species-Specific Head Anatomies in Genetically Wild-Type Girardia dorotocephala Flatworms 117269
# Top-down models in biology: explanation and control of complex living systems above the molecular level 100188
# A Life of George Westinghouse 546832
# Perspective: The Promise of Multi-Cellular Engineered Living Systems 96361
# Signal Processing Techniques for Computational Health Informatics 804841
# Introduction to Biomedical Engineering: Biomechanics and Bioelectricity - Part II 216049
# Kinematic self-replication in reconﬁgurable organisms 51812
# Embryos Assist Morphogenesis through Collective Teratogen Resistance 127128
# Engineering multicellular living systems—a Keystone Symposia report 84556
# Principled Limitations on Self-Representation for Generic Physical Systems 70522
# Fundamental Neuroscience (3rd edition) 5149195
# The Molecules of Life: Physical and Chemical Principles 307936
# Mathematical Cardiac Electrophysiology 822750
# Chemistry: Atoms First 2e 2495074
# The Cytoskeleton: Diverse Roles in a Plant’s Life 478781
# Molecular Biology of the Cell 6160108
# Electrical Diseases of the Heart: Basic Foundations and Primary Electrical Diseases 2453914
# Cellular signaling pathways as plastic, proto-cognitive systems: Implications for biomedicine 118816
# The Invention of Enterprise: Entrepreneurship from Ancient Mesopotamia to Modern Times 2030465
# The View Camera 222023
# Air and Missile Defense Systems Engineering 549026
# Davidson's Principles and Practice of Medicine, 24th Edition 7406533
# Green Banking and Green Central Banking 519080
# Military Handbook: Missile Flight Simulation Part One Surface-to-Air Missiles 839746
# Encyclopedia of Artificial Intelligence: The Past, Present, and Future of AI 1209133
# Nuclear and Particle Physics 803652
# The Basics of American Government 853534
# Ballistic Missile Defense: Capabilities and Constraints 77142
# Clinical Emergency Medicine 1448602
# Your Brain On Porn: Internet Pornography and the Emerging Science of Addiction 320891
# Health Policymaking in the United States, Sixth Edition 1580298
# The Denial of Death 713054
# The Age of AI and Our Human Future 377800
# A History of God: From Abraham to the Present: The 4,000-year Quest for God 1097817
# Everyday Life in the Culture of Surveillance 623459
# Life After Death, Powerful Evidence You Will Never Die 282025
# The Hard Rock Miner's Handbook, Edition 3 1165644
# Aulton's Pharmaceutics: The Design and Manufacture of Medicines (5th Edition) 3575349
# National Security Intelligence and Ethics 962755
# The Oxford History of Modern War 890100
# Evil Money: The Inside Story of Money Laundering and the Ineffective War on Drugs 460238
# Of Corpse: Death and Humor in Folklore and Popular Culture 823226
# Where Does Money Come From? A Guide to the UK Monetary and Banking System 456804
# Monetary Policy in the United States: An Intellectual and Institutional History 1454109
# Personal Safety Handbook 2016-2017 49862
# The Negro Family in the United States 1209903
# Tactical Missile Design 595493
# The Psychology of Money: Timeless Lessons on Wealth, Greed, and Happiness 307032
# Plant Physiology 418332
# A Europe Made of Money: The Emergence of the European Monetary System 1071649
# Rum and Axes: The Rise of a Connecticut Merchant Family, 1795-1850 503834
# The Metalliferous Mines Regulations, 1961 411521
# The Camera 399201
# How to Pick Locks 54547
# Money, Banking, and the Financial System, Third Edition 2368368
# A Brief History of Time 387460
# A Beginner's Guide to Investing: How to Grow Your Money the Smart and Easy Way 157915
# Wastewater Operator Certification Training: Module 1 - Introduction to Wastewater Treatment 101478
# Open Cast (Strip) Mining 77728
# Monetary Economics, 2nd Edition 2486379
# Modern Money Theory: A Primer on Macroeconomics for Sovereign Monetary Systems 813512
# Death; An Inside Story - A Book for all Those who Shall Die 706639
# The Datapreneurs: The Promise of AI and the Creators Building Our Future 272638
# Killers of the Flower Moon: The Osage Murders and the Birth of the FBI 543104
# Health and Wealth Disparities in the United States 95691
# The Complete Book of Locks and Locksmithing 857290

# %%
n = random.randint(0, len(hindgut)-1)
title, text = list(hindgut.keys())[n], list(hindgut.values())[n]
excerpt = sample_text(text, 10000)

# %%
usr_msg = f"Summarize the following excerpt.\nExcerpt:\n{excerpt}"
summary = ask("", usr_msg)
print(summary)
# Out:
# This excerpt discusses the genetic factors involved in organ development, particularly focusing on the development and patterning of the hindgut in Drosophila as a model. The text highlights the roles of various genes and signaling pathways in establishing the anterior-posterior (AP) and dorsal-ventral (DV) axes necessary for organ formation, including the pancreas, lungs, and thyroid. While Hox-C genes are important for vertebrate and Drosophila midgut development, they are less significant in Drosophila hindgut development. Instead, non-HoxC homeodomain genes like cad, bap, and engrailed (en) are involved. The patterning of the hindgut into distinct domains such as small and large intestines depends on various genes like drm, bowl, lin, and signaling pathways like JAK/STAT. The excerpt also covers Drosophila's left-right asymmetry, discussing its genetic basis compared to other organisms and noting the importance of studies on live cell movements to understand these developmental mechanisms.

# %%
n = random.randint(0, len(biology)-1)
title, text = list(biology.keys())[n], list(biology.values())[n]
excerpt = sample_text(text, 10000)
print(title)
# Out:
# Principled Limitations on Self-Representation for Generic Physical Systems

# %%
usr_msg = f"Summarize the following excerpt.\nExcerpt:\n{excerpt}"
summary = ask("", usr_msg)
print(summary)
# Out:
# The excerpt explores the distinction between the narrative self and the processes that shape self-representation within the framework of the Free Energy Principle (FEP). It suggests that the narrative self is not the central driver of cognition but a constructed representation influenced by meta-level processes. Self-evidencing, a process central to active inference, targets not the narrative self but the environment observing the system overall. The excerpt highlights cognitive biases and confabulations in self-knowledge, indicating that individuals often rely on shared theories rather than actual causes when explaining their behaviors. The concept of the Cognitive Light Cone (CLC) and the Technological Approach to Mind Everywhere (TAME) are introduced to describe the limits on goals and competencies that systems can represent and pursue. It emphasizes the physical and enactive nature of cognition, pointing out fundamental limitations on self-representation due to system-environment boundaries. The narrative discusses the implications of these ideas on neuroscience, cognition, and broader areas like legal and ethical theories, and it argues against the notion of centralized control in favor of distributed cognition systems.

# %%
def summarize(excerpt):
    usr_msg = f"Summarize the following excerpt.\nExcerpt:\n{excerpt}"
    summary = ask("", usr_msg)
    print(summary)
