# %%
import sqlite3, random, pathlib
from search import search_library
from dotenv import load_dotenv
from openai import OpenAI, OpenAIError
from pydantic import BaseModel, Field, ValidationError
import os
from openai import OpenAI
from pydantic import BaseModel
import json
import time
import random
from helpers.sentence_splitter import split_sentences
from time import sleep
from tqdm import tqdm  # optional: pip install tqdm

# %%
def ask(sys_msg, usr_msg):
    resp = client.chat.completions.create(
        model=OPENAI_MODEL,
        messages=[
            {"role": "system", "content": sys_msg},
            {"role": "user", "content": usr_msg}
        ]
    )
    return resp.choices[0].message.content

def print_obj(obj, i=1, params=["agent", "interaction", "space", "time", "causal link", "physical law"]):
    print(f"{i} - ")
    for param in params:
        print(f"{param}: {obj[param]}")
    

def parse_func_resp(resp, obj_name="element", params=["name", "text"], print="True"):
    args_raw = resp.choices[0].message.tool_calls[0].function.arguments
    raws = json.loads(args_raw)[obj_name]

    obj_lst = []
    for i, obj in enumerate(raws, 1):
        if print:
            pass
            #print_obj(obj, i, params)
        obj_lst.append(obj)
    
    return obj_lst

def elements_to_string(dims, label="ELEMENTS"):
    s = ""
    for dim, elems in dims.items():
        s += f"{dim}\n{label}:\n"
        for elem in elems:
            s += elem + "\n"
        s += "\n"

    return s

def sample_text(text, x):
    max_start = max(0, len(text) - x)
    random_start = random.randint(0, max_start)
    excerpt = text[random_start:random_start + x]
    return excerpt

def ask_func(sys_msg, usr_msg, FUNC):
    resp = client.chat.completions.create(
            model=OPENAI_MODEL,
            messages=[{"role":"system","content":sys_msg}, {"role":"user","content":usr_msg}],
            tools=[FUNC], tool_choice="auto", temperature=0.5
            )
    return resp

def sample_elems(elements, per_dim, per_elem):
    total_dim = len(elements)
    ndims = min(int(per_dim * total_dim), total_dim)

    # Sample dimension indices
    dimension_indices = random.sample(range(total_dim), ndims)

    sample_elems = {}

    for di in dimension_indices:
        dimension_name = list(elements.keys())[di]
        dimension_elems = list(elements.values())[di]

        total_elems = len(dimension_elems)
        nelems = min(int(per_elem * total_elems), total_elems)

        # Sample element indices from this dimension
        element_indices = random.sample(range(total_elems), nelems)
        sample_elems[dimension_name] = [dimension_elems[ei] for ei in element_indices]

    return sample_elems

def clean_elements(elements_raw):
    elements = {}
    for element_raw in elements_raw:
        k = element_raw["name"]
        v = element_raw["text"]
        element = (k, [item.strip() for item in v.split('\n') if item.strip()])
        elements[element[0]] = element[1]
    return elements


def remove_story_scaffold_keys(data):
    return {k: v for k, v in data.items() if "Story Scaffold" not in k}

    



load_dotenv()
client = OpenAI()
OPENAI_MODEL = os.getenv("OPENAI_MODEL", "gpt-4o")

DB_FILE = "library.sqlite"
MAX_RESULTS = 100

# %%
SYS_PROMPT_ELEMENTS = """
My goal is a description of the mechanical forces driving the development of the hindgut and an understanding of how the overexpression of myosin 1c drives the inversion of LR asymmetry 
during development. I want to write a complete story of hindgut development incorporating mechanical force as central players in this story, 
then create a complete story of hindgut development under Myo1C OE, the generation of LR inversion from the role of Myo1C to the hindgut rotation. 
The following text is from a paper on hindgut morphogenesis.
Extract a list of agents, interactions, spatial compartments, developmental stages, causal chains, and physical constraints involved in hindgut morphogenesis and the effect of myosin 1c overexpression on LR inversion.
Structure the output as a story scaffold:
Agents: ...
Interactions: ...
Spaces: ...
Time: ...
Causal links: ...
Physical laws/constraints: ...
"""


SYS_PROMPT_DIMENSIONS = """
You are helping build a complete narrative of hindgut morphogenesis in Drosophila, with special attention to the role of mechanical forces - driving the rotation and elongation of the hindgut - and the overexpression of myosin 1c (Myo1C) in left-right (LR) inversion.

Your task is not to tell the story, but to define what would be required to tell a **complete and comprehensive story** for this set of story elements.

- Break down these elements into their essential **story dimensions** or **sub-components**.
- Think about biological scale (molecular, cellular, tissue), space, time, dynamics, agents, interactions, functions, and unknowns.
- Consider how these elements might relate to:
  - other parts of the hindgut
  - the mechanical forces shaping the tissue
  - the overexpression of Myo1C and its effects on LR inversion

Output a structured list of **story dimensions** that should be explored in order to fully develop these elements. If helpful, include example questions or variables within each dimension.

Format:

**1. Dimension Name**  
- Description of what this dimension involves.  
- Example questions or aspects to explore.

(Repeat as needed for all relevant dimensions)
"""

SYS_PROMPT_PARSE_ELEMENTS = ("Read the following text and separate each element of the suggested story framework into a object with the name and text.\n"
        "You should return a list of objects containing each story element in a given structure.\n"
        "Do not add or remove text; your job is to parse and deconstruct the text string into the given structure.\n"
        "Treat every line that begins with a number followed by “.” and a space (e.g. “1. ”) or **Element** as the NAME of a new element."
        "Capture all following lines up to—but not including—the next such line as the TEXT for that element.")


ELEM_FUNC = {
    "type": "function",
    "function": {
        "name": "element_function",
        "description": "Read the following text and separate each element of the suggested story framework into a object with the name and text. \
        You should return a list of objects containing each story element in a given structure. \
        Do not add or remove text; your job is to parse and deconstruct the text string into the given structure.",
        "parameters": {
            "type": "object",
            "properties": {
                "element": {
                    "type": "array",
                    "items": {
                        "type": "object",
                        "properties": {
                            "name": { "type": "string" },
                            "text": { "type": "string" }
                        },
                        "required": ["name", "text"]
                    }
                }
            },
            "required": ["element"]
        }
    }
}

ADD_ELEM_FUNC = {
    "type": "function",
    "function": {
        "name": "elements_function",
        "description": "Converts a string of elements into a list of elements.",
        "parameters": {
            "type": "object",
            "properties": {
                "element": {
                    "type": "array",
                    "items": {
                        "type": "object",
                        "properties": {
                            "name": { "type": "string" }
                        },
                        "required": ["name"]
                    }
                }
            },
            "required": ["element"]
        }
    }
}

# %%
KEYWORDS = ["Drosophila", "hindgut"]# ["active tension network", "epithelial"]  # list of words
search_results = search_library(DB_FILE, KEYWORDS, MAX_RESULTS, match_all=True)
# papers = {}
for r in search_results:
    title, text = r['title'], r['text']
    papers[title] = text

KEYWORDS = ["active tension network", "epithelial"]  # list of words
search_results = search_library(DB_FILE, KEYWORDS, MAX_RESULTS, match_all=True)
# papers = {}
for r in search_results:
    title, text = r['title'], r['text']
    papers[title] = text


rem = [None, "Fundamental Neuroscience (3rd edition)","Harrison's Principles of Internal Medicine 15th Edition", "Developmental Biology, 7th Edition"]
for r in rem:
    if r in papers:
        del papers[r]


for title in list(papers.keys()):
    print(title)
# Out:
# Active Tension Network Model in Epithelial Tissues
# The Geometric Basis of Epithelial Convergent Extension
# Generating Active T1 Transitions through Mechanochemical Feedback
# The Drosophila actin nucleator DAAM is essential for left-right asymmetry
# Myosin1D is an evolutionarily conserved regulator of animal left–right asymmetry
# An unconventional myosin in Drosophila reverses the default handedness in visceral organs
# Chiral cell sliding drives left-right asymmetric organ twisting
# Cell Chirality Drives Left-Right Asymmetric Morphogenesis
# Chirality in Planar Cell Shape Contributes to Left-Right Asymmetric Epithelial Morphogenesis
# Vertebrate myosin 1d regulates left–right organizer morphogenesis and laterality
# Distinct Cellular and Junctional Dynamics Independently Regulate the Rotation and Elongation of the Embryonic Gut in Drosophila
# Genital disc growth in Drosophila
# Understanding Laterality Disorders and the Left-Right Organizer: Insights from Zebrafish
# Left–right Myosin-Is, Myosin1C, and Myosin1D exhibit distinct single molecule behaviors on the plasma membrane of Drosophila macrophages
# It Takes Guts: The Drosophila Hindgut as a Model System for Organogenesis

# %%
stories = {}
elements_all = []

for n in range(len(papers)):
    title, text = list(papers.keys())[n], list(papers.values())[n]
    excerpt = sample_text(text, 10000)

    sys_msg = SYS_PROMPT_ELEMENTS
    user_msg = f"TEXT EXCERPT:\n{excerpt}"
    elements_resp = ask(sys_msg, user_msg)

    sys_msg = SYS_PROMPT_PARSE_ELEMENTS
    usr_msg = f"STORY FRAMEWORK:\n{elements_resp}"
    elements_func = ask_func(sys_msg, usr_msg, ELEM_FUNC)

    elements_raw = parse_func_resp(elements_func, "element", ["name", "text"], "False")
    elements = clean_elements(elements_raw)

    elements_all.append(elements)
    print(elements)
# Out:
# {'Story Scaffold': ['Hindgut Morphogenesis and Myosin 1c Overexpression'], 'Agents': ['- Cells (constituting the 2D array, each represented as polygons)', '- Actomyosin bundles (mechanically coupled to each cell edge)', '- Adherens junctions (connecting actomyosin bundles)', '- Vertices (representing nodes formed by cell edges)', '- Myosin motors (influencing contraction of actomyosin bundles)', '- Cadherin dimers (crosslinking actomyosin cables at interfaces)'], 'Interactions': ['- Tension (Tij) changes with edge length (r_ij) and actomyosin state', '- Apical pressure (pα) changes with cortical area (dAα)', '- Mechanical coupling of actomyosin bundles via cadherin', '- Myosin recruitment influenced by internal strain rate', '- Feedback mechanism affecting myosin distribution in response to mechanical load', '- Balance of mechanical forces to achieve equilibrium'], 'Spaces': ['- 2D plane (representing the array of cells)', '- Tension plane (a conceptual triangulation to illustrate tension vectors)', '- Cell interfaces (where actomyosin bundles exert force)', '- Vertex as nodes in the cellular meshwork'], 'Time': ['- Developmental stages of the hindgut', '- Dynamics of tension network relaxation over time with timescales determined by friction (ν)', '- Relative timescales of myosin recruitment versus mechanical relaxation'], 'Causal Links': ['- Vertex dynamics influence tension vector placement and shape', '- Changes in length and shape of actomyosin bundles affect mechanical forces', '- Myosin concentration affects edge tension, which then dictates cell movement', '- Mechanical feedback loop dictates myosin levels at interfaces, driving tension balance', '- Myosin 1c overexpression potentially alters load handling, affecting LR asymmetry in development (e.g., altered rotation of hindgut)'], 'Physical Laws/Constraints': ['- Tension nets satisfy mechanical equilibrium with sums of tension vectors forming geometric constraints', '- Law of sines applied to vertex and dual triangles dictates tension constraints', '- Isogonal deformations allow for free vertex movement without energy cost, maintaining equilibrium', '- Myosin-stall force relationships dictate edge tension increase beyond actomyosin bundle slipping point', '- Constraints on cell geometry dictated by equilibrium manifold of tension net triangulation']}
# {'Story Scaffold for Hindgut Morphogenesis with Myosin 1c Overexpression': [], 'Agents': ['- Cortical tensions', '- Myosin', '- Passive crosslinkers', '- Junctional proteins (e.g., actin, E-cadherin)', '- Tension triangles', '- Voronoi reference configuration', '- Myosin 1c (Myo1C)'], 'Interactions': ['- Tension-induced myosin recruitment', '- Positive tension feedback', '- Passive viscoelastic relaxation through crosslinker turnover', '- Mechanical feedback influencing tension dynamics'], 'Spaces': ['- Central cell interface', '- Cortical junctions', '- Quartet of cells in a periodic array', '- Tension triangulation (scaffold for cellular geometry)'], 'Time': ['- Effective viscoelastic relaxation timescale (minutes)', '- Experimental timescales for tension dynamics matching observed behaviors', '- Remodeling time (τp) for passive tension'], 'Causal Links': ['- Tension on cell-cell interfaces influences cell shape and vertex angles.', '- Myosin redistribution affects tension dynamics, leading to cell intercalation.', '- Positive tension feedback causes extension or collapse based on initial tensions.', '- Myosin 1c overexpression affects left-right (LR) asymmetry by altering mechanical forces during development.'], 'Physical Laws/Constraints': ['- Force balance at cell vertices dictates interface angles.', '- Tension dynamics reside in mechanical feedback, not constitutive elasticity relations.', '- Shape and deformation of cell arrays determined by tension triangulation and isogonal deformation.'], 'Hindgut Development under Normal Conditions': ['- The development involves mechanical forces where cortical tensions and myosin recruitment play central roles.', '- Tension feedback alters interface dynamics, affecting cellular rearrangement and intercalation.', '- A minimal model predicts the behavior of active and passive tensions, with influences from internal cell structures like myosin contractility.'], 'Hindgut Development under Myosin 1c Overexpression (Myo1C OE)': ['- Overexpression of Myo1C perturbs normal mechanical balance within cells.', '- The redistribution of myosin and altered tension dynamics lead to LR asymmetry inversion.', '- Myo1C OE impacts the rotational forces during hindgut morphogenesis, driving atypical rotational patterns and potentially reversing normal developmental asymmetries.'], 'Conclusion': ['This scaffold presents a foundational framework to explore the profound impact of myosin dynamics and mechanical tension interactions on the burgeoning hindgut structure in development, emphasizing particularly the alterations resulting from Myo1C overexpression.']}
# {'Story Scaffold': [], 'Agents': ['- Active cells', '- Myosin proteins (including phosphorylated myosin light chain)', '- Actomyosin cables', '- Voronoi tessellation generators', '- Embryos (from a transgenic chick line with GFP-tagged cell membranes)'], 'Interactions': ['- Myosin feedback loops influencing cell mechanics.', '- Formation of Voronoi diagrams to generate randomly shaped cell patches.', '- Application of force (fpull) on tissue boundaries to induce anisotropy.', '- Cell activities including anisotropic tension, convergence–extension, and intercalation events involving T1 transitions.', '- Flow anisotropy related to tissue stretching and myosin anisotropy.'], 'Spaces': ['- Tissue patches containing active and passive cells.', '- Square regions of cell arrangement.', '- Circular domains averaging spatial cell properties.', '- Regions within embryos including the posterior region aligning with the primitive streak formation.'], 'Time': ['- Simulation times including relaxation and activity phases (e.g., 103t∗ and 1.6 × 103t∗).', '- Developmental stages, typically starting from stage EGXIII-HH4.', '- Observation periods using light-sheet microscopy (~16 hours, with 3 min frame intervals).'], 'Causal Links': ['- Cell geometry influences resultant Voronoi diagrams affecting tissue strain.', '- Myosin activity and viscoelastic properties drive convergence–extension.', '- Pulling forces create anisotropy and shape changes in tissue.', '- Time trace averaging and strain tensors illuminate stress and genomic influences on hindgut morphogenesis.', '- Phosphomyosin patterns correlate with Myo1C OE effects and developmental symmetry changes.'], 'Physical Laws/Constraints': ['- Constraints in cellular spacing to avoid cell overlap.', '- Requirement for centroidal Voronoi tessellations structurally mimicking epithelia.', '- Boundary conditions preventing actomyosin cable formation.', '- Conservation of cell area and maintenance of isotropy in certain scenarios.', '- Use of eigenvalues and vectors to quantify tissue strain and stress anisotropy.']}
# {'Story Scaffold: Hindgut Development and Myosin 1c Overexpression': [], 'Agents': ['- DAAM (Formin)', '- Myo1D (Myosin 1D)', '- Myo1C (Myosin 1C)', '- Chic (Profilin)', '- Tec29 (Tec family kinase)', '- Rhea/Talin', '- Mys (beta integrin)', '- l(2)gl (lethal(2) giant larvae)', '- DE-cadherin', '- β-catenin', '- Actin', '- F-actin (Filamentous actin)'], 'Interactions': ['- DAAM nucleates actin and interacts with Myo1D to influence LR asymmetry.', '- Myo1D induces chiral movement of F-actin, creating a chiral cytoskeleton.', '- Profilin/Chic and Tec29 collaborate with DAAM for actin dynamics.', '- Rhea/Talin and Mys facilitate cell adhesion via integrins linking to ECM.', '- l(2)gl interacts with adherens junctions, influencing cell polarity.', '- Myo1D interacts directly with DE-cadherin and β-catenin at adherens junctions.', '- Overexpression of Myo1C influenced by DAAM modifies chirality pathways.'], 'Spaces': ['- Hindgut', '- Genitalia imaginal disc', '- Genitalia LR organizer', '- Adherens junctions', '- ECM (Extracellular Matrix)', '- Cellular cytoskeleton'], 'Time': ['- Developmental stages include native (normal) LR asymmetry and de novo development.', '- Stages of hindgut rotation and genitalia morphogenesis.'], 'Causal Links': ['- DAAM’s actin nucleation is crucial for LR asymmetry, working via Myo1D.', "- DAAM's overexpression leads to sinistral twisting through Myo1C, hinting at endogenous pathways.", '- Suppression of this twist observed with myo1C-RNAi confirms DAAM’s reliance on Myo1C.', '- Loss-of-function in Chic and Tec29 affects tissue chirality, impacting rotation phenotypes.', '- Myo1C overexpression leads to inversion of LR asymmetry via myosin-induced mechanical forces.'], 'Physical Laws/Constraints': ['- Mechanical forces generated through actin polymerization and interaction with myosins drive morphological changes.', '- Constraints of cellular adhesion (via integrins, DE-cadherin) guide tissue structure and polarity.', '- ECM interaction shapes cellular responses and positioning during morphogenesis.', '- Mechanical properties of actin and its network dictate its capacity to induce or maintain chirality.']}
# {'Story Scaffold: Hindgut Morphogenesis and Myosin 1c Overexpression': [], 'Agents': ['- Myo1D', '- Vangl2', '- MZ myo1D mutants', '- Fluorescent microspheres', '- Cilia', '- Basal bodies', '- RNA components like myo1Cb'], 'Interactions': ['- Myo1D and Vangl2 interacting to control zebrafish LRO cilia orientation.', '- Altered interaction between Myo1D and Vangl2 affecting flow geometry and circularity.', '- Rescue of KV flow and embryonic laterality by reducing vangl2 gene dosage.', '- Interaction between Myo1D, Dachsous, and Vangl2 in Drosophila chiral morphogenesis.'], 'Spaces (Spatial Compartments)': ['- Left-Right Organizer (LRO)', "- Kupffer's Vesicle (KV)", "- LRO cells' posterior half where basal bodies are located", '- Dorsal views of eight-somites stage KVs', '- Floor plate cilia, not affected by Myo1D'], 'Time (Developmental Stages)': ['- Eight-somite stage embryos', '- Adult stage analysis in Drosophila'], 'Causal Links': ['1. Myo1D and Vangl2 control cilia orientation → Directed LRO flow developed.', '2. Disruption in Myo1D or Vangl2 function → Altered cilia orientation and chaotic LRO flow → LR asymmetry defects.', '3. Reduction of vangl2 dosage → Partial restoration of KV flow and morphological laterality.', '4. Overexpression of Myo1C RNA → Reduced flow velocity and LR defects.'], 'Physical Laws/Constraints': ['- Mechanical forces determine cilia orientation.', '- Role of planar cell polarity (PCP) pathway in spatial cellular organization.', '- Translational and rotational PCP of KV cilia can be uncoupled.'], 'Hindgut Development with Myosin 1c Overexpression': ["With an understanding of Myo1D's role in maintaining directional flow and LR asymmetry through mechanical regulation, we can explore Myosin 1C overexpression effects. When Myo1C is overexpressed, it perturbs the equilibrium of forces that would typically orient cilia in a productive rotation to form directed flow, leading to LR asymmetry inversion. The story of hindgut development under Myo1C overexpression involves studying how increased Myo1C levels might alter the rotational PCP of cilia, shifting it from the usual direction, impacting the entire hindgut orientation during developmental stages. This establishes an inverted symmetry, manifesting the biological changes visibly both within organogenesis and external morphology."]}
# {'Agents': ['- Hindgut epithelial cells', '- Actin cytoskeleton', '- Myo31DF (myosin I protein in Drosophila)', '- Myo61F (also known as MyoIC in mammals)', '- GFP–moesin fusion protein', '- RNA interference (RNAi)', '- Gal4/UAS system'], 'Interactions': ['- Myo31DF and Myo61F have antagonistic functions in left–right (LR) asymmetry.', '- Overexpression of Myo61F leads to inversion of the midgut and hindgut, whereas Myo31DF overexpression does not affect handedness.', '- Actin cytoskeleton mediates cell rearrangements, which are crucial for LR bias.', '- Myo31DF and Myo61F are involved in vesicular transport along actin filaments, transferring LR determinants.'], 'Spaces': ['- Embryonic hindgut epithelium', '- Basal and apical surfaces of epithelial layers', '- Midgut and hindgut compartments of the Drosophila gut'], 'Time': ['- Developmental stages (e.g., embryonic stages 8, 9, 10, 11, 15, and 16)', '- Temporal manipulation using temperature-sensitive expression (TARGET method)', '- Time-lapse analysis for dynamic cellular movements and rearrangements'], 'Causal Links': ['- Myo31DF dependency on the actin cytoskeleton for developing LR asymmetry.', '- Cell intercalation and rearrangement align with the left-handed rotation of the hindgut.', '- Myo31DF and Myo61F regulate LR determinants differently, impacting organ handedness.', '- Disruption in actin organization may randomize LR asymmetry.'], 'Physical Laws/Constraints': ['- Actin filaments guide the movement of vesicular transport and LR determinants.', '- Rotation of epithelial cells is influenced by intracellular tension and actin dynamics.', '- Detectors of handedness may align to either an anteroposterior-dorsoventral reference or pre-existing tissue handedness, highlighting the biomechanical constraints in place.']}
# {'Story Scaffold': ['Story Scaffold:', 'Agents:', '- Hindgut epithelial cells', '- Myosin II (MyoII)', '- Myosin 1C', '- Myo31DF mutants', 'Interactions:', '- Anisotropic contraction of cell edges', '- Cell sliding as a dynamic cell process', '- Cell intercalation events', '- Chiral cell sliding associated with loss of cell chirality', 'Spaces:', '- Hindgut epithelial tube', '- Anterior-posterior axis of the model gut tube', '- 3D cell-based vertex model simulation environment', 'Time:', '- Initial leftward tilt before twisting (t = 0)', '- Tube twisted to 88.5° at t = 80.0, further to 91.0° at t = 100', '- Rapid cell deformation at early simulation phases (t = 1.0)', '- Continued sliding and rotation of cells over time', 'Causal links:', '- Anisotropic contraction of cell edges leading to LR asymmetry in cell chirality', '- Loss of cell chirality leading to gut-tube rotation', '- Overexpression of Myosin 1c leading to inversion of LR chirality in Myo31DF mutants', '- Cell chirality induces mechanical force bias, driving directional cell sliding and tube rotation', 'Physical laws/constraints:', '- Cell axis distributions, angle of 90° to -90° determining LR chirality', '- Mechanical differentiation between cell deformation and cell sliding due to viscoelastic properties', '- Vertex fixing preventing tube rotation in simulations, indicating mechanical requirements for chiral sliding', '- Enantiomorphic differences in Myo31DF mutants mirroring wild-type rotation', 'This story scaffold outlines the development and rotation of the hindgut epithelial tube, focusing on the mechanical forces and cellular processes involved, and how Myosin 1c overexpression influences LR asymmetry.']}
# {'Story Scaffold for Hindgut Morphogenesis and Myosin 1c Overexpression': ['Story Scaffold for Hindgut Morphogenesis and Myosin 1c Overexpression'], 'Agents': ['- F-actin', '- Formin family proteins', '- Myo31DF', '- Myosin Id and Myosin Ic', '- DE-Cadherin', '- Planar Cell Polarity (PCP) components', '- Apoptosis-related factors'], 'Interactions': ['- F-actin and Formin proteins contribute to cell chirality.', '- Myo31DF potentially influences the chiral status of F-actin structures.', '- DE-Cadherin regulates Myosin Id and Myosin Ic in establishing asymmetry.', '- Interaction between cell chirality and PCP in modifying cell architecture.', '- Apoptosis influences the speed of morphogenetic movements.'], 'Spaces': ['- Laterality (Left-Right) axis of Drosophila and other organisms.', '- Population of cells through which chiral cells might navigate.', '- Planar cell environments where chirality interplays with PCP.'], 'Time': ['- Various developmental stages where cell chirality emerges, including early embryogenesis.', '- Specific temporal sequences during organogenesis and morphogenetic movements.'], 'Causal Links': ['- Formin-induced F-actin rotation might initiate cell chirality.', '- Myo31DF and Myosin 1c alter F-actin and influence LR asymmetry.', '- Cell chirality may aid in navigating cell populations, impacting tissue morphology.', '- Apoptotic control of morphogenesis speed affects organ looping.', '- Myosin 1c overexpression alters normal chirality contributing to LR inversion.'], 'Physical Laws/Constraints': ['- Mechanical forces through actomyosin generate torque and drive asymmetry.', '- Chiral configurations are influenced by intrinsic cellular and cytoskeletal properties.', '- Cellular and molecular dynamics constrained by the architecture of cell populations.', '- Fluid dynamics and ciliary motion contribute to directional asymmetry development.'], 'Conclusion': ['This structured consideration builds a narrative on the integral role of mechanical forces and specific molecular agents such as myosin 1c in shaping hindgut morphogenesis and exploring how altered expression can lead to intriguing phenotypic modulations.']}
# {'Story Scaffold for Hindgut Development and Myosin 1c Overexpression': [], 'Agents': ['- DE-Cad (E-cadherin ortholog)', '- Myo31DF (Myosin ID)', '- Rab11-positive recycling endosomes', '- Planar cell chirality (PCC)', '- Cell boundaries', '- Myo1C (Myosin 1c)'], 'Interactions': ['- DE-Cad contributes to the formation and maintenance of the LR asymmetry in hindgut epithelial cells by its distribution along cell boundaries.', '- Myo31DF alters the LR asymmetric distribution of DE-Cad, affecting cell boundary expansion and LR chirality.', '- Recycling of DE-Cad is controlled by its trafficking via Rab11-positive endosomes, which is influenced by MyoID.', '- Overexpression of Myo31DFGFP can restore typical Myo31DF functions, altering DE-Cad distribution.'], 'Spaces (Spatial Compartments)': ['- Hindgut epithelium', '- Zones of adherens (ZA) between cell boundaries', '- Apical-middle part of cells in the hindgut epithelium'], 'Time (Developmental Stages)': ['- Late-stage 12 to late-stage 13 of hindgut development', '- Changes are observed as the hindgut progresses through late-stage 12 to 13 into the developmental rotation phase.'], 'Causal Links': ['- Myo31DF overexpression → Altered LR DE-Cad distribution → Changed cell boundary constraints → Hindgut rotation.', '- Myo31DF deficiency → Reduced Rab11-positive endosomes → Impaired DE-Cad recycling → Disruption in LR asymmetry.', '- Proper function of DE-Cad and MyoID → Introduction of cortical tension limiting cell boundary expansion → Facilitation of PCC.', '- DE-Cad enrichment at specific angles → Hindgut epithelial shape maintenance → Left-handed rotation under normal conditions.', '- Simulation showed that PCC is sufficient to model hindgut rotation, providing evidence that these mechanisms control the physical transformation of the tissue.'], 'Physical Laws/Constraints': ['- Cortical tension regulated by DE-Cad and MyoID restricts cell boundary expansion, establishing shape and preventing unwanted growth.', '- Physical constraints established by DE-Cad distribution guide the LR asymmetry necessary for proper hindgut rotation.', '- The geometric bias in DE-Cad distribution indicates a role in managing the spatial alignment of cells and subsequent tissue morphogenesis.', '- Biomechanical forces inherent in the arrangement of epithelial cell boundaries drive the observed physical changes in the gut during rotation.']}
# {'Story Scaffold': ['Hindgut Morphogenesis and Myosin 1c Overexpression'], 'Agents': ['- Kupffer’s Vesicle (KV)', '- Myosin 1c (Myo1c)', '- Myosin 1d (Myo1d)', '- CFTR (Cystic Fibrosis Transmembrane Conductance Regulator)', '- Cilia', '- Embryonic cells'], 'Interactions': ['- Myo1d regulates KV lumen expansion through vacuole delivery.', '- Myo1c influences rotation and lateral movement.', '- Cilia-driven flow determines left-right asymmetry.', '- Myo1c binding to membrane lipids and interaction with calmodulin influences cell shape and orientation.', '- CFTR regulates ion transport and assists in lumen expansion.'], 'Spaces': ['- Kupffer’s Vesicle (KV)', '- Cellular membranes', '- Embryonic organizer tissue'], 'Time': ['- Eight-somite stage of zebrafish embryo development', '- Hindgut development initiated during early embryogenesis'], 'Causal Links': ['- Proper lumen expansion in KV is essential for correct asymmetry. Myo1d and CFTR play a critical role in this process by regulating vacuole delivery and ion transport.', '- Failure of centrosome migration leads to loss of motile cilia, impacting asymmetry.', '- Overexpression of Myo1c disrupts default handedness, leading to LR inversion through altered membrane dynamics and cellular interactions.', '- Cilia generate a leftward flow, establishing the direction of asymmetry.'], 'Physical Laws/Constraints': ['- Circular flow kinetics in KV, influenced by ciliary motion.', '- Mechanical forces generated by Myo1c impact tissue chirality and cell shape.', '- Cilia dynamics adhere to fluid-dynamic constraints that ensure directional flow.', '- Structural integrity of cilia and associated motor proteins like KIF3 impacts asymmetry establishment.']}
# {'Story Scaffold for Hindgut Development and Myosin 1c Overexpression-Induced LR Inversion': [], 'Agents': ['- Myo1D (Myosin 1D)', '- E-cadherin (E-cad)', '- Cellular nuclei (visualized with RedStinger)', '- Cell boundaries (visualized with myr-GFP)'], 'Interactions': ['- Overexpression of Myo1D leads to enhanced cell sliding.', '- E-cadherin influences the patterns of cell sliding and junctional remodeling.', '- Cell sliding and convergent extension operate independently.'], 'Spaces': ['- Hindgut epithelium: The cellular structure where rotation and elongation are observed.', '- Hook-like structure of the hindgut', '- Pivot line: Axis for hindgut rotation', '- Wild type, E-cad homozygote, and Myo1D-overexpressing embryo conditions'], 'Time': ['- Observations conducted from 0 to 120 minutes, highlighting specific intervals: 0, 30, 60, and 120 minutes.', '- Quantitative analyses focus on changes from 0 to 60 minutes.'], 'Causal links': ['- Myo1D overexpression -> Increased cell sliding -> Overrotation of hindgut.', '- Reduced E-cadherin -> Decreased cell sliding -> Reduced hindgut rotation.', '- Cell sliding levels are correlated to Myo1D expression, independent of convergent extension or cell intercalation.'], 'Physical laws/constraints': ['- The directionality of hindgut lumen is parallel to the rotation axis (pivot line), constraining rotation.', '- Junctional dynamics (T3 to T1 transitions) and their lack of effect on hindgut rotation.', '- Hindgut rotation measure (rotational movement index) influenced by cellular dynamics.', '- Physical spacing of cellular components along anterior–posterior axis affects measurements of displacement.'], 'Conclusion': ['In this scaffold, the overexpression of Myo1D emerges as a critical factor enhancing cell sliding and causing an overrotation of the hindgut, indicative of a mechanical force altering normal developmental asymmetry. This alteration of mechanical dynamics in the hindgut can be considered a foundational element for understanding the inversion of left-right (LR) asymmetry under the influence of increased Myo1D levels.']}
# {'Story Scaffold': ['Hindgut Morphogenesis and Myosin 1c Overexpression'], 'Agents': ['- JNK (c-Jun N-terminal kinase)', '- Bsk- clones', '- DfH99 clones', '- Egr (Eiger)', '- RHG products', '- puc (puckered gene)', '- Myosin 1c (Myo1C)', '- p35 anti-apoptotic protein', '- Wg (Wingless)', '- Dpp (Decapentaplegic)'], 'Interactions': ['- JNK signaling is crucial for cell proliferation and survival; its absence leads to cell death.', '- Bsk- clones exhibit reduced growth due to lack of JNK activity.', '- DfH99 clones lead to asymmetric growth and can undergo cell death signaling, enhanced when Egr is absent.', '- Egr and RHG products regulate JNK activity, affecting growth.', '- The prevention of cell death via p35 shows that growth can occur without death, but clone cells are still prone to die.', '- Myosin 1c overexpression impacts left-right (LR) asymmetry, altering normal developmental signaling pathways.'], 'Spaces': ['- Genital disc (particularly A8, A9, A10 primordial regions)', '- Female and male genitalia regions'], 'Time': ['- Developmental stages of disc growth', '- Varying outcomes based on timing of clone induction (early vs. late stages)'], 'Causal Links': ['- **Developmental Apoptosis:** JNK influences both cell proliferation and developmental apoptosis, particularly in growing tissues like the genitalia.', '- **Cell Signaling:** Absence of JNK leads to reduced growth due to a lack of proliferative signaling.', '- **Death Prevention:** Prevents physical asymmetry and clone cell death through anti-apoptotic agents like p35.', '- **Myo1C Overexpression:** Drives inversion of normal LR asymmetry by altering mechanical forces during hindgut development.'], 'Physical Laws/Constraints': ['- Mechanical forces and spatial orientation influence hindgut development and final organ positioning.', '- Cytoarchitecture and tissue tension play roles in the symmetry and subsequent inversion processes.', '- Mimicking or disrupting normal apoptotic pathways showcases the importance of cellular competition and survival in maintaining organ morphology.']}
# {'Story Scaffold': ['Hindgut Development and the Role of Myosin 1c'], 'Agents': ['- KV cilia (motile and immotile)', '- Flow dynamics (related to cilia orientation and activity)', '- Actomyosin cytoskeleton', '- ROCK2/Rho kinase', '- Nodal signaling pathway', '- ECM components (Laminin and Fibronectin)', '- Sodium-potassium pump (Na+/K+-ATPase)', '- Myo1d (Myosin 1d)', '- Gdf3 and Nodal signaling pathways', '- Pkd2 and Pkd1l1 cation channels', '- Ca2+ signaling (intraciliary calcium oscillations)', '- CaMKII protein', '- Extracellular vesicles'], 'Interactions': ['- Motility of cilia creates directional fluid flow.', '- Actomyosin contractility influences cell shape and KV remodeling.', '- ROCK2/Rho kinase mediates contractility during KV remodeling.', '- Notch signaling regulates the number of immotile cilia.', '- Nodal and Gdf3 signaling pathways contribute to KV cell shape changes and LR asymmetry.', '- Cation channels on cilia (Pkd2 and Pkd1l1) facilitate Ca2+ signaling.', '- Intraciliary calcium oscillations initiate cytoplasmic Ca2+ fluxes, impacting protein activation and gene expression.', '- Biophysical drag forces created by KV movement in tailbud tissue affect cell shape changes.', '- Myo1d mediates ion channel activity influencing cell volume.'], 'Spaces': ["- Kupffer's vesicle (KV) in zebrafish embryos", '- Anterior and posterior regions of KV', '- Notochord adjacent to the KV', '- Tailbud of the elongating embryo', '- Lateral plate mesoderm'], 'Time': ['- Developmental stages from the 2-somite to 12-somite stages', '- Changes in KV architecture and ciliary dynamics occur precisely between these stages.'], 'Causal Links': ['- Meridional tilt of motile cilia in KV facilitates strong leftward directional flow.', '- Asymmetric flow due to anterior cluster of motile cilia is critical for LR asymmetry.', '- Actomyosin cytoskeleton contractility and ECM components like Laminin and Fibronectin aid KV remodeling and cell shape changes.', '- Intraciliary calcium oscillations triggered by motile cilia-derived flow activate downstream LR signaling pathways.', '- TGF-β/Nodal signaling, via Gdf3, regulates KV architecture and shapes that sustain fluid flow contributing to LR development.'], 'Physical Laws/Constraints': ['- Fluid dynamics regulated by ciliary motion and cell architecture.', '- Mechanical stress and drag forces resulting from KV movement influencing cell shape changes.', '- Diffusion and transport of molecules such as Ca2+ ions and signaling proteins depend on spatial and temporal gradients.', '- Contractility and volume change modulated by cytoskeletal and ion pump activities constrain cellular morphology.', 'In a scenario of Myosin 1c overexpression, the roles of contractility and volume change might be exacerbated, altering ciliary dynamics and structural remodeling processes, potentially leading to inversion of LR asymmetry by incorrectly directing or forcefully altering the normal pathways of hindgut development. Detailed studies on Myo1C effects would further establish this inversion mechanism.']}
# {'Agents': ['- Myosin 1c', '- Myosin D', '- Actin nucleators (e.g., DAAM)', '- Diffusion coefficients, weighted states', '- Drosophila (as a model organism)', '- Endothelial cells', '- Cilia (in the context of LR asymmetry)'], 'Interactions': ['- Myosin 1c overexpression affects cytoskeletal dynamics.', '- Actin nucleators influence the formation of left-right (LR) asymmetry.', '- Endothelial cell chirality regulates intercellular junctions and cellular permeability.', '- Myosin motors interact with cellular components to drive motility and chirality.'], 'Spaces': ['- Hindgut', '- Visceral organs', '- Cellular environments, e.g., T cell plasma membrane', '- Left-right axis of development', '- Node region in certain organisms (like vertebrates)'], 'Time': ['- Early developmental stages (from embryonic stages through organogenesis)', '- Stages of hindgut rotation and inversion actions', '- Time intervals within the assay periods (as per studies on MSD and dissociation rates)'], 'Causal links': ['- Overexpression of Myo1C leads to inversion of LR asymmetry.', '- Intracellular chirality impacts the orientation and rotation of the hindgut.', '- Actin nucleators and myosins play a role in the development of asymmetrical organ structures.', '- Alterations of cell signaling and cytoskeletal components affect LR development pathways.'], 'Physical laws/constraints': ['- Biomechanical forces affect the orientation and final positioning of internal organs.', '- Confined diffusion and spatial limitations within cellular environments.', '- Physical constraints imposed by the cytoskeleton on cellular and tissue chirality.', '- Potential impacts of cellular energy states (ATP dynamics) on motor proteins such as myosins.']}
# {'Story Scaffold: Hindgut Morphogenesis and Myosin 1c Overexpression': [], 'Agents': ['- Sonic Hedgehog (Shh)', '- Bmp-4', '- Hox genes', '- E-cadherin', '- Drosophila ribbon gene', '- Crumbs protein', '- Myosin 1c (Myo1C)', '- Fork Head transcription factors (HNF-3 alpha and beta)', '- Wnt signaling molecules (XWnt11)', '- Brachyury', '- Sox gene (Dichaete)', '- Chemokines like SDF-1'], 'Interactions': ['- Sonic Hedgehog signaling induces Bmp-4 and Hox gene expression.', '- Crumbs is involved in the apical membrane structure organization, interacting with E-cadherin.', '- E-cadherin mediates cell-cell adhesion during epithelial rearrangement.', '- Drosophila ribbon gene promotes epithelial migration and morphogenesis.', '- Myo1C interacts with actin filaments, influencing cell shape and tension.', '- Hox genes are regulated by signaling pathways and transcription factors for regional gut development.'], 'Spaces': ['- Chick and mouse embryos for vertebrate hindgut studies.', '- Drosophila melanogaster (fruit fly) as a model for invertebrate gut development.', '- Zebrafish embryos for observing axial pattern formation and gene expression.', '- Epithelial cells within the hindgut region, focusing on apical and basal membranes.', '- Visceral mesoderm and ectodermal compartments.'], 'Time': ['- During the embryonic development stages including gastrulation.', '- Sequential expressions such as HNF-3 alpha and beta during early stamping of organizers and notochord development.', '- Critical moments aligning with embryogenesis and organ regionalization.', '- Development until the inversion of LR asymmetry with Myo1C overexpression.'], 'Causal Links': ['- Shh signaling starts a cascade involving Bmp-4 and Hox genes for hindgut initiation and regionalization.', '- Overexpression of Myo1C affects cytoskeletal dynamics, causing LR inversions.', '- E-cadherin disruption leads to abnormal cell adhesion, influencing gut morphogenesis.', "- Fork Head transcription factors' expression in the notochord contributes to gut patterning.", '- Wnt signaling, particularly involving Disheveled, manages cell polarity and movements crucial during gastrulation.'], 'Physical Laws/Constraints': ['- Biomechanical forces governed by cytoskeletal tension (actin and myosin interactions).', '- Adherens junctions (mediated by E-cadherin) providing structural integrity within epithelial tissues.', '- Cellular polarity mechanisms defining apical-basal orientation.', '- Constraints by biochemical gradients (morphogens like Shh) influencing gene expression and morphogenesis.', '- Spatial and temporal expression constraints ensuring accurate developmental timing and spatial structuring.']}

# %%
elements_all_clean = [remove_story_scaffold_keys(d) for d in elements_all]
for elem in elements_all_clean:
    print(elem)
# Out:
# {'Agents': ['- Cells (constituting the 2D array, each represented as polygons)', '- Actomyosin bundles (mechanically coupled to each cell edge)', '- Adherens junctions (connecting actomyosin bundles)', '- Vertices (representing nodes formed by cell edges)', '- Myosin motors (influencing contraction of actomyosin bundles)', '- Cadherin dimers (crosslinking actomyosin cables at interfaces)'], 'Interactions': ['- Tension (Tij) changes with edge length (r_ij) and actomyosin state', '- Apical pressure (pα) changes with cortical area (dAα)', '- Mechanical coupling of actomyosin bundles via cadherin', '- Myosin recruitment influenced by internal strain rate', '- Feedback mechanism affecting myosin distribution in response to mechanical load', '- Balance of mechanical forces to achieve equilibrium'], 'Spaces': ['- 2D plane (representing the array of cells)', '- Tension plane (a conceptual triangulation to illustrate tension vectors)', '- Cell interfaces (where actomyosin bundles exert force)', '- Vertex as nodes in the cellular meshwork'], 'Time': ['- Developmental stages of the hindgut', '- Dynamics of tension network relaxation over time with timescales determined by friction (ν)', '- Relative timescales of myosin recruitment versus mechanical relaxation'], 'Causal Links': ['- Vertex dynamics influence tension vector placement and shape', '- Changes in length and shape of actomyosin bundles affect mechanical forces', '- Myosin concentration affects edge tension, which then dictates cell movement', '- Mechanical feedback loop dictates myosin levels at interfaces, driving tension balance', '- Myosin 1c overexpression potentially alters load handling, affecting LR asymmetry in development (e.g., altered rotation of hindgut)'], 'Physical Laws/Constraints': ['- Tension nets satisfy mechanical equilibrium with sums of tension vectors forming geometric constraints', '- Law of sines applied to vertex and dual triangles dictates tension constraints', '- Isogonal deformations allow for free vertex movement without energy cost, maintaining equilibrium', '- Myosin-stall force relationships dictate edge tension increase beyond actomyosin bundle slipping point', '- Constraints on cell geometry dictated by equilibrium manifold of tension net triangulation']}
# {'Agents': ['- Cortical tensions', '- Myosin', '- Passive crosslinkers', '- Junctional proteins (e.g., actin, E-cadherin)', '- Tension triangles', '- Voronoi reference configuration', '- Myosin 1c (Myo1C)'], 'Interactions': ['- Tension-induced myosin recruitment', '- Positive tension feedback', '- Passive viscoelastic relaxation through crosslinker turnover', '- Mechanical feedback influencing tension dynamics'], 'Spaces': ['- Central cell interface', '- Cortical junctions', '- Quartet of cells in a periodic array', '- Tension triangulation (scaffold for cellular geometry)'], 'Time': ['- Effective viscoelastic relaxation timescale (minutes)', '- Experimental timescales for tension dynamics matching observed behaviors', '- Remodeling time (τp) for passive tension'], 'Causal Links': ['- Tension on cell-cell interfaces influences cell shape and vertex angles.', '- Myosin redistribution affects tension dynamics, leading to cell intercalation.', '- Positive tension feedback causes extension or collapse based on initial tensions.', '- Myosin 1c overexpression affects left-right (LR) asymmetry by altering mechanical forces during development.'], 'Physical Laws/Constraints': ['- Force balance at cell vertices dictates interface angles.', '- Tension dynamics reside in mechanical feedback, not constitutive elasticity relations.', '- Shape and deformation of cell arrays determined by tension triangulation and isogonal deformation.'], 'Hindgut Development under Normal Conditions': ['- The development involves mechanical forces where cortical tensions and myosin recruitment play central roles.', '- Tension feedback alters interface dynamics, affecting cellular rearrangement and intercalation.', '- A minimal model predicts the behavior of active and passive tensions, with influences from internal cell structures like myosin contractility.'], 'Hindgut Development under Myosin 1c Overexpression (Myo1C OE)': ['- Overexpression of Myo1C perturbs normal mechanical balance within cells.', '- The redistribution of myosin and altered tension dynamics lead to LR asymmetry inversion.', '- Myo1C OE impacts the rotational forces during hindgut morphogenesis, driving atypical rotational patterns and potentially reversing normal developmental asymmetries.'], 'Conclusion': ['This scaffold presents a foundational framework to explore the profound impact of myosin dynamics and mechanical tension interactions on the burgeoning hindgut structure in development, emphasizing particularly the alterations resulting from Myo1C overexpression.']}
# {'Agents': ['- Active cells', '- Myosin proteins (including phosphorylated myosin light chain)', '- Actomyosin cables', '- Voronoi tessellation generators', '- Embryos (from a transgenic chick line with GFP-tagged cell membranes)'], 'Interactions': ['- Myosin feedback loops influencing cell mechanics.', '- Formation of Voronoi diagrams to generate randomly shaped cell patches.', '- Application of force (fpull) on tissue boundaries to induce anisotropy.', '- Cell activities including anisotropic tension, convergence–extension, and intercalation events involving T1 transitions.', '- Flow anisotropy related to tissue stretching and myosin anisotropy.'], 'Spaces': ['- Tissue patches containing active and passive cells.', '- Square regions of cell arrangement.', '- Circular domains averaging spatial cell properties.', '- Regions within embryos including the posterior region aligning with the primitive streak formation.'], 'Time': ['- Simulation times including relaxation and activity phases (e.g., 103t∗ and 1.6 × 103t∗).', '- Developmental stages, typically starting from stage EGXIII-HH4.', '- Observation periods using light-sheet microscopy (~16 hours, with 3 min frame intervals).'], 'Causal Links': ['- Cell geometry influences resultant Voronoi diagrams affecting tissue strain.', '- Myosin activity and viscoelastic properties drive convergence–extension.', '- Pulling forces create anisotropy and shape changes in tissue.', '- Time trace averaging and strain tensors illuminate stress and genomic influences on hindgut morphogenesis.', '- Phosphomyosin patterns correlate with Myo1C OE effects and developmental symmetry changes.'], 'Physical Laws/Constraints': ['- Constraints in cellular spacing to avoid cell overlap.', '- Requirement for centroidal Voronoi tessellations structurally mimicking epithelia.', '- Boundary conditions preventing actomyosin cable formation.', '- Conservation of cell area and maintenance of isotropy in certain scenarios.', '- Use of eigenvalues and vectors to quantify tissue strain and stress anisotropy.']}
# {'Agents': ['- DAAM (Formin)', '- Myo1D (Myosin 1D)', '- Myo1C (Myosin 1C)', '- Chic (Profilin)', '- Tec29 (Tec family kinase)', '- Rhea/Talin', '- Mys (beta integrin)', '- l(2)gl (lethal(2) giant larvae)', '- DE-cadherin', '- β-catenin', '- Actin', '- F-actin (Filamentous actin)'], 'Interactions': ['- DAAM nucleates actin and interacts with Myo1D to influence LR asymmetry.', '- Myo1D induces chiral movement of F-actin, creating a chiral cytoskeleton.', '- Profilin/Chic and Tec29 collaborate with DAAM for actin dynamics.', '- Rhea/Talin and Mys facilitate cell adhesion via integrins linking to ECM.', '- l(2)gl interacts with adherens junctions, influencing cell polarity.', '- Myo1D interacts directly with DE-cadherin and β-catenin at adherens junctions.', '- Overexpression of Myo1C influenced by DAAM modifies chirality pathways.'], 'Spaces': ['- Hindgut', '- Genitalia imaginal disc', '- Genitalia LR organizer', '- Adherens junctions', '- ECM (Extracellular Matrix)', '- Cellular cytoskeleton'], 'Time': ['- Developmental stages include native (normal) LR asymmetry and de novo development.', '- Stages of hindgut rotation and genitalia morphogenesis.'], 'Causal Links': ['- DAAM’s actin nucleation is crucial for LR asymmetry, working via Myo1D.', "- DAAM's overexpression leads to sinistral twisting through Myo1C, hinting at endogenous pathways.", '- Suppression of this twist observed with myo1C-RNAi confirms DAAM’s reliance on Myo1C.', '- Loss-of-function in Chic and Tec29 affects tissue chirality, impacting rotation phenotypes.', '- Myo1C overexpression leads to inversion of LR asymmetry via myosin-induced mechanical forces.'], 'Physical Laws/Constraints': ['- Mechanical forces generated through actin polymerization and interaction with myosins drive morphological changes.', '- Constraints of cellular adhesion (via integrins, DE-cadherin) guide tissue structure and polarity.', '- ECM interaction shapes cellular responses and positioning during morphogenesis.', '- Mechanical properties of actin and its network dictate its capacity to induce or maintain chirality.']}
# {'Agents': ['- Myo1D', '- Vangl2', '- MZ myo1D mutants', '- Fluorescent microspheres', '- Cilia', '- Basal bodies', '- RNA components like myo1Cb'], 'Interactions': ['- Myo1D and Vangl2 interacting to control zebrafish LRO cilia orientation.', '- Altered interaction between Myo1D and Vangl2 affecting flow geometry and circularity.', '- Rescue of KV flow and embryonic laterality by reducing vangl2 gene dosage.', '- Interaction between Myo1D, Dachsous, and Vangl2 in Drosophila chiral morphogenesis.'], 'Spaces (Spatial Compartments)': ['- Left-Right Organizer (LRO)', "- Kupffer's Vesicle (KV)", "- LRO cells' posterior half where basal bodies are located", '- Dorsal views of eight-somites stage KVs', '- Floor plate cilia, not affected by Myo1D'], 'Time (Developmental Stages)': ['- Eight-somite stage embryos', '- Adult stage analysis in Drosophila'], 'Causal Links': ['1. Myo1D and Vangl2 control cilia orientation → Directed LRO flow developed.', '2. Disruption in Myo1D or Vangl2 function → Altered cilia orientation and chaotic LRO flow → LR asymmetry defects.', '3. Reduction of vangl2 dosage → Partial restoration of KV flow and morphological laterality.', '4. Overexpression of Myo1C RNA → Reduced flow velocity and LR defects.'], 'Physical Laws/Constraints': ['- Mechanical forces determine cilia orientation.', '- Role of planar cell polarity (PCP) pathway in spatial cellular organization.', '- Translational and rotational PCP of KV cilia can be uncoupled.'], 'Hindgut Development with Myosin 1c Overexpression': ["With an understanding of Myo1D's role in maintaining directional flow and LR asymmetry through mechanical regulation, we can explore Myosin 1C overexpression effects. When Myo1C is overexpressed, it perturbs the equilibrium of forces that would typically orient cilia in a productive rotation to form directed flow, leading to LR asymmetry inversion. The story of hindgut development under Myo1C overexpression involves studying how increased Myo1C levels might alter the rotational PCP of cilia, shifting it from the usual direction, impacting the entire hindgut orientation during developmental stages. This establishes an inverted symmetry, manifesting the biological changes visibly both within organogenesis and external morphology."]}
# {'Agents': ['- Hindgut epithelial cells', '- Actin cytoskeleton', '- Myo31DF (myosin I protein in Drosophila)', '- Myo61F (also known as MyoIC in mammals)', '- GFP–moesin fusion protein', '- RNA interference (RNAi)', '- Gal4/UAS system'], 'Interactions': ['- Myo31DF and Myo61F have antagonistic functions in left–right (LR) asymmetry.', '- Overexpression of Myo61F leads to inversion of the midgut and hindgut, whereas Myo31DF overexpression does not affect handedness.', '- Actin cytoskeleton mediates cell rearrangements, which are crucial for LR bias.', '- Myo31DF and Myo61F are involved in vesicular transport along actin filaments, transferring LR determinants.'], 'Spaces': ['- Embryonic hindgut epithelium', '- Basal and apical surfaces of epithelial layers', '- Midgut and hindgut compartments of the Drosophila gut'], 'Time': ['- Developmental stages (e.g., embryonic stages 8, 9, 10, 11, 15, and 16)', '- Temporal manipulation using temperature-sensitive expression (TARGET method)', '- Time-lapse analysis for dynamic cellular movements and rearrangements'], 'Causal Links': ['- Myo31DF dependency on the actin cytoskeleton for developing LR asymmetry.', '- Cell intercalation and rearrangement align with the left-handed rotation of the hindgut.', '- Myo31DF and Myo61F regulate LR determinants differently, impacting organ handedness.', '- Disruption in actin organization may randomize LR asymmetry.'], 'Physical Laws/Constraints': ['- Actin filaments guide the movement of vesicular transport and LR determinants.', '- Rotation of epithelial cells is influenced by intracellular tension and actin dynamics.', '- Detectors of handedness may align to either an anteroposterior-dorsoventral reference or pre-existing tissue handedness, highlighting the biomechanical constraints in place.']}
# {}
# {'Agents': ['- F-actin', '- Formin family proteins', '- Myo31DF', '- Myosin Id and Myosin Ic', '- DE-Cadherin', '- Planar Cell Polarity (PCP) components', '- Apoptosis-related factors'], 'Interactions': ['- F-actin and Formin proteins contribute to cell chirality.', '- Myo31DF potentially influences the chiral status of F-actin structures.', '- DE-Cadherin regulates Myosin Id and Myosin Ic in establishing asymmetry.', '- Interaction between cell chirality and PCP in modifying cell architecture.', '- Apoptosis influences the speed of morphogenetic movements.'], 'Spaces': ['- Laterality (Left-Right) axis of Drosophila and other organisms.', '- Population of cells through which chiral cells might navigate.', '- Planar cell environments where chirality interplays with PCP.'], 'Time': ['- Various developmental stages where cell chirality emerges, including early embryogenesis.', '- Specific temporal sequences during organogenesis and morphogenetic movements.'], 'Causal Links': ['- Formin-induced F-actin rotation might initiate cell chirality.', '- Myo31DF and Myosin 1c alter F-actin and influence LR asymmetry.', '- Cell chirality may aid in navigating cell populations, impacting tissue morphology.', '- Apoptotic control of morphogenesis speed affects organ looping.', '- Myosin 1c overexpression alters normal chirality contributing to LR inversion.'], 'Physical Laws/Constraints': ['- Mechanical forces through actomyosin generate torque and drive asymmetry.', '- Chiral configurations are influenced by intrinsic cellular and cytoskeletal properties.', '- Cellular and molecular dynamics constrained by the architecture of cell populations.', '- Fluid dynamics and ciliary motion contribute to directional asymmetry development.'], 'Conclusion': ['This structured consideration builds a narrative on the integral role of mechanical forces and specific molecular agents such as myosin 1c in shaping hindgut morphogenesis and exploring how altered expression can lead to intriguing phenotypic modulations.']}
# {'Agents': ['- DE-Cad (E-cadherin ortholog)', '- Myo31DF (Myosin ID)', '- Rab11-positive recycling endosomes', '- Planar cell chirality (PCC)', '- Cell boundaries', '- Myo1C (Myosin 1c)'], 'Interactions': ['- DE-Cad contributes to the formation and maintenance of the LR asymmetry in hindgut epithelial cells by its distribution along cell boundaries.', '- Myo31DF alters the LR asymmetric distribution of DE-Cad, affecting cell boundary expansion and LR chirality.', '- Recycling of DE-Cad is controlled by its trafficking via Rab11-positive endosomes, which is influenced by MyoID.', '- Overexpression of Myo31DFGFP can restore typical Myo31DF functions, altering DE-Cad distribution.'], 'Spaces (Spatial Compartments)': ['- Hindgut epithelium', '- Zones of adherens (ZA) between cell boundaries', '- Apical-middle part of cells in the hindgut epithelium'], 'Time (Developmental Stages)': ['- Late-stage 12 to late-stage 13 of hindgut development', '- Changes are observed as the hindgut progresses through late-stage 12 to 13 into the developmental rotation phase.'], 'Causal Links': ['- Myo31DF overexpression → Altered LR DE-Cad distribution → Changed cell boundary constraints → Hindgut rotation.', '- Myo31DF deficiency → Reduced Rab11-positive endosomes → Impaired DE-Cad recycling → Disruption in LR asymmetry.', '- Proper function of DE-Cad and MyoID → Introduction of cortical tension limiting cell boundary expansion → Facilitation of PCC.', '- DE-Cad enrichment at specific angles → Hindgut epithelial shape maintenance → Left-handed rotation under normal conditions.', '- Simulation showed that PCC is sufficient to model hindgut rotation, providing evidence that these mechanisms control the physical transformation of the tissue.'], 'Physical Laws/Constraints': ['- Cortical tension regulated by DE-Cad and MyoID restricts cell boundary expansion, establishing shape and preventing unwanted growth.', '- Physical constraints established by DE-Cad distribution guide the LR asymmetry necessary for proper hindgut rotation.', '- The geometric bias in DE-Cad distribution indicates a role in managing the spatial alignment of cells and subsequent tissue morphogenesis.', '- Biomechanical forces inherent in the arrangement of epithelial cell boundaries drive the observed physical changes in the gut during rotation.']}
# {'Agents': ['- Kupffer’s Vesicle (KV)', '- Myosin 1c (Myo1c)', '- Myosin 1d (Myo1d)', '- CFTR (Cystic Fibrosis Transmembrane Conductance Regulator)', '- Cilia', '- Embryonic cells'], 'Interactions': ['- Myo1d regulates KV lumen expansion through vacuole delivery.', '- Myo1c influences rotation and lateral movement.', '- Cilia-driven flow determines left-right asymmetry.', '- Myo1c binding to membrane lipids and interaction with calmodulin influences cell shape and orientation.', '- CFTR regulates ion transport and assists in lumen expansion.'], 'Spaces': ['- Kupffer’s Vesicle (KV)', '- Cellular membranes', '- Embryonic organizer tissue'], 'Time': ['- Eight-somite stage of zebrafish embryo development', '- Hindgut development initiated during early embryogenesis'], 'Causal Links': ['- Proper lumen expansion in KV is essential for correct asymmetry. Myo1d and CFTR play a critical role in this process by regulating vacuole delivery and ion transport.', '- Failure of centrosome migration leads to loss of motile cilia, impacting asymmetry.', '- Overexpression of Myo1c disrupts default handedness, leading to LR inversion through altered membrane dynamics and cellular interactions.', '- Cilia generate a leftward flow, establishing the direction of asymmetry.'], 'Physical Laws/Constraints': ['- Circular flow kinetics in KV, influenced by ciliary motion.', '- Mechanical forces generated by Myo1c impact tissue chirality and cell shape.', '- Cilia dynamics adhere to fluid-dynamic constraints that ensure directional flow.', '- Structural integrity of cilia and associated motor proteins like KIF3 impacts asymmetry establishment.']}
# {'Agents': ['- Myo1D (Myosin 1D)', '- E-cadherin (E-cad)', '- Cellular nuclei (visualized with RedStinger)', '- Cell boundaries (visualized with myr-GFP)'], 'Interactions': ['- Overexpression of Myo1D leads to enhanced cell sliding.', '- E-cadherin influences the patterns of cell sliding and junctional remodeling.', '- Cell sliding and convergent extension operate independently.'], 'Spaces': ['- Hindgut epithelium: The cellular structure where rotation and elongation are observed.', '- Hook-like structure of the hindgut', '- Pivot line: Axis for hindgut rotation', '- Wild type, E-cad homozygote, and Myo1D-overexpressing embryo conditions'], 'Time': ['- Observations conducted from 0 to 120 minutes, highlighting specific intervals: 0, 30, 60, and 120 minutes.', '- Quantitative analyses focus on changes from 0 to 60 minutes.'], 'Causal links': ['- Myo1D overexpression -> Increased cell sliding -> Overrotation of hindgut.', '- Reduced E-cadherin -> Decreased cell sliding -> Reduced hindgut rotation.', '- Cell sliding levels are correlated to Myo1D expression, independent of convergent extension or cell intercalation.'], 'Physical laws/constraints': ['- The directionality of hindgut lumen is parallel to the rotation axis (pivot line), constraining rotation.', '- Junctional dynamics (T3 to T1 transitions) and their lack of effect on hindgut rotation.', '- Hindgut rotation measure (rotational movement index) influenced by cellular dynamics.', '- Physical spacing of cellular components along anterior–posterior axis affects measurements of displacement.'], 'Conclusion': ['In this scaffold, the overexpression of Myo1D emerges as a critical factor enhancing cell sliding and causing an overrotation of the hindgut, indicative of a mechanical force altering normal developmental asymmetry. This alteration of mechanical dynamics in the hindgut can be considered a foundational element for understanding the inversion of left-right (LR) asymmetry under the influence of increased Myo1D levels.']}
# {'Agents': ['- JNK (c-Jun N-terminal kinase)', '- Bsk- clones', '- DfH99 clones', '- Egr (Eiger)', '- RHG products', '- puc (puckered gene)', '- Myosin 1c (Myo1C)', '- p35 anti-apoptotic protein', '- Wg (Wingless)', '- Dpp (Decapentaplegic)'], 'Interactions': ['- JNK signaling is crucial for cell proliferation and survival; its absence leads to cell death.', '- Bsk- clones exhibit reduced growth due to lack of JNK activity.', '- DfH99 clones lead to asymmetric growth and can undergo cell death signaling, enhanced when Egr is absent.', '- Egr and RHG products regulate JNK activity, affecting growth.', '- The prevention of cell death via p35 shows that growth can occur without death, but clone cells are still prone to die.', '- Myosin 1c overexpression impacts left-right (LR) asymmetry, altering normal developmental signaling pathways.'], 'Spaces': ['- Genital disc (particularly A8, A9, A10 primordial regions)', '- Female and male genitalia regions'], 'Time': ['- Developmental stages of disc growth', '- Varying outcomes based on timing of clone induction (early vs. late stages)'], 'Causal Links': ['- **Developmental Apoptosis:** JNK influences both cell proliferation and developmental apoptosis, particularly in growing tissues like the genitalia.', '- **Cell Signaling:** Absence of JNK leads to reduced growth due to a lack of proliferative signaling.', '- **Death Prevention:** Prevents physical asymmetry and clone cell death through anti-apoptotic agents like p35.', '- **Myo1C Overexpression:** Drives inversion of normal LR asymmetry by altering mechanical forces during hindgut development.'], 'Physical Laws/Constraints': ['- Mechanical forces and spatial orientation influence hindgut development and final organ positioning.', '- Cytoarchitecture and tissue tension play roles in the symmetry and subsequent inversion processes.', '- Mimicking or disrupting normal apoptotic pathways showcases the importance of cellular competition and survival in maintaining organ morphology.']}
# {'Agents': ['- KV cilia (motile and immotile)', '- Flow dynamics (related to cilia orientation and activity)', '- Actomyosin cytoskeleton', '- ROCK2/Rho kinase', '- Nodal signaling pathway', '- ECM components (Laminin and Fibronectin)', '- Sodium-potassium pump (Na+/K+-ATPase)', '- Myo1d (Myosin 1d)', '- Gdf3 and Nodal signaling pathways', '- Pkd2 and Pkd1l1 cation channels', '- Ca2+ signaling (intraciliary calcium oscillations)', '- CaMKII protein', '- Extracellular vesicles'], 'Interactions': ['- Motility of cilia creates directional fluid flow.', '- Actomyosin contractility influences cell shape and KV remodeling.', '- ROCK2/Rho kinase mediates contractility during KV remodeling.', '- Notch signaling regulates the number of immotile cilia.', '- Nodal and Gdf3 signaling pathways contribute to KV cell shape changes and LR asymmetry.', '- Cation channels on cilia (Pkd2 and Pkd1l1) facilitate Ca2+ signaling.', '- Intraciliary calcium oscillations initiate cytoplasmic Ca2+ fluxes, impacting protein activation and gene expression.', '- Biophysical drag forces created by KV movement in tailbud tissue affect cell shape changes.', '- Myo1d mediates ion channel activity influencing cell volume.'], 'Spaces': ["- Kupffer's vesicle (KV) in zebrafish embryos", '- Anterior and posterior regions of KV', '- Notochord adjacent to the KV', '- Tailbud of the elongating embryo', '- Lateral plate mesoderm'], 'Time': ['- Developmental stages from the 2-somite to 12-somite stages', '- Changes in KV architecture and ciliary dynamics occur precisely between these stages.'], 'Causal Links': ['- Meridional tilt of motile cilia in KV facilitates strong leftward directional flow.', '- Asymmetric flow due to anterior cluster of motile cilia is critical for LR asymmetry.', '- Actomyosin cytoskeleton contractility and ECM components like Laminin and Fibronectin aid KV remodeling and cell shape changes.', '- Intraciliary calcium oscillations triggered by motile cilia-derived flow activate downstream LR signaling pathways.', '- TGF-β/Nodal signaling, via Gdf3, regulates KV architecture and shapes that sustain fluid flow contributing to LR development.'], 'Physical Laws/Constraints': ['- Fluid dynamics regulated by ciliary motion and cell architecture.', '- Mechanical stress and drag forces resulting from KV movement influencing cell shape changes.', '- Diffusion and transport of molecules such as Ca2+ ions and signaling proteins depend on spatial and temporal gradients.', '- Contractility and volume change modulated by cytoskeletal and ion pump activities constrain cellular morphology.', 'In a scenario of Myosin 1c overexpression, the roles of contractility and volume change might be exacerbated, altering ciliary dynamics and structural remodeling processes, potentially leading to inversion of LR asymmetry by incorrectly directing or forcefully altering the normal pathways of hindgut development. Detailed studies on Myo1C effects would further establish this inversion mechanism.']}
# {'Agents': ['- Myosin 1c', '- Myosin D', '- Actin nucleators (e.g., DAAM)', '- Diffusion coefficients, weighted states', '- Drosophila (as a model organism)', '- Endothelial cells', '- Cilia (in the context of LR asymmetry)'], 'Interactions': ['- Myosin 1c overexpression affects cytoskeletal dynamics.', '- Actin nucleators influence the formation of left-right (LR) asymmetry.', '- Endothelial cell chirality regulates intercellular junctions and cellular permeability.', '- Myosin motors interact with cellular components to drive motility and chirality.'], 'Spaces': ['- Hindgut', '- Visceral organs', '- Cellular environments, e.g., T cell plasma membrane', '- Left-right axis of development', '- Node region in certain organisms (like vertebrates)'], 'Time': ['- Early developmental stages (from embryonic stages through organogenesis)', '- Stages of hindgut rotation and inversion actions', '- Time intervals within the assay periods (as per studies on MSD and dissociation rates)'], 'Causal links': ['- Overexpression of Myo1C leads to inversion of LR asymmetry.', '- Intracellular chirality impacts the orientation and rotation of the hindgut.', '- Actin nucleators and myosins play a role in the development of asymmetrical organ structures.', '- Alterations of cell signaling and cytoskeletal components affect LR development pathways.'], 'Physical laws/constraints': ['- Biomechanical forces affect the orientation and final positioning of internal organs.', '- Confined diffusion and spatial limitations within cellular environments.', '- Physical constraints imposed by the cytoskeleton on cellular and tissue chirality.', '- Potential impacts of cellular energy states (ATP dynamics) on motor proteins such as myosins.']}
# {'Agents': ['- Sonic Hedgehog (Shh)', '- Bmp-4', '- Hox genes', '- E-cadherin', '- Drosophila ribbon gene', '- Crumbs protein', '- Myosin 1c (Myo1C)', '- Fork Head transcription factors (HNF-3 alpha and beta)', '- Wnt signaling molecules (XWnt11)', '- Brachyury', '- Sox gene (Dichaete)', '- Chemokines like SDF-1'], 'Interactions': ['- Sonic Hedgehog signaling induces Bmp-4 and Hox gene expression.', '- Crumbs is involved in the apical membrane structure organization, interacting with E-cadherin.', '- E-cadherin mediates cell-cell adhesion during epithelial rearrangement.', '- Drosophila ribbon gene promotes epithelial migration and morphogenesis.', '- Myo1C interacts with actin filaments, influencing cell shape and tension.', '- Hox genes are regulated by signaling pathways and transcription factors for regional gut development.'], 'Spaces': ['- Chick and mouse embryos for vertebrate hindgut studies.', '- Drosophila melanogaster (fruit fly) as a model for invertebrate gut development.', '- Zebrafish embryos for observing axial pattern formation and gene expression.', '- Epithelial cells within the hindgut region, focusing on apical and basal membranes.', '- Visceral mesoderm and ectodermal compartments.'], 'Time': ['- During the embryonic development stages including gastrulation.', '- Sequential expressions such as HNF-3 alpha and beta during early stamping of organizers and notochord development.', '- Critical moments aligning with embryogenesis and organ regionalization.', '- Development until the inversion of LR asymmetry with Myo1C overexpression.'], 'Causal Links': ['- Shh signaling starts a cascade involving Bmp-4 and Hox genes for hindgut initiation and regionalization.', '- Overexpression of Myo1C affects cytoskeletal dynamics, causing LR inversions.', '- E-cadherin disruption leads to abnormal cell adhesion, influencing gut morphogenesis.', "- Fork Head transcription factors' expression in the notochord contributes to gut patterning.", '- Wnt signaling, particularly involving Disheveled, manages cell polarity and movements crucial during gastrulation.'], 'Physical Laws/Constraints': ['- Biomechanical forces governed by cytoskeletal tension (actin and myosin interactions).', '- Adherens junctions (mediated by E-cadherin) providing structural integrity within epithelial tissues.', '- Cellular polarity mechanisms defining apical-basal orientation.', '- Constraints by biochemical gradients (morphogens like Shh) influencing gene expression and morphogenesis.', '- Spatial and temporal expression constraints ensuring accurate developmental timing and spatial structuring.']}

# %%
# Assuming `list_of_dicts` is your list of dictionaries

elements = []
for d in elements_all:
    for value in d.values():
        if isinstance(value, list):
            elements.extend(value)
        else:
            elements.append(value)

# %%
print(len(elements))
# Out:
# 400

# %%
print(elements)
# Out:
# ['- Cells (constituting the 2D array, each represented as polygons)', '- Actomyosin bundles (mechanically coupled to each cell edge)', '- Adherens junctions (connecting actomyosin bundles)', '- Vertices (representing nodes formed by cell edges)', '- Myosin motors (influencing contraction of actomyosin bundles)', '- Cadherin dimers (crosslinking actomyosin cables at interfaces)', '- Tension (Tij) changes with edge length (r_ij) and actomyosin state', '- Apical pressure (pα) changes with cortical area (dAα)', '- Mechanical coupling of actomyosin bundles via cadherin', '- Myosin recruitment influenced by internal strain rate', '- Feedback mechanism affecting myosin distribution in response to mechanical load', '- Balance of mechanical forces to achieve equilibrium', '- 2D plane (representing the array of cells)', '- Tension plane (a conceptual triangulation to illustrate tension vectors)', '- Cell interfaces (where actomyosin bundles exert force)', '- Vertex as nodes in the cellular meshwork', '- Developmental stages of the hindgut', '- Dynamics of tension network relaxation over time with timescales determined by friction (ν)', '- Relative timescales of myosin recruitment versus mechanical relaxation', '- Vertex dynamics influence tension vector placement and shape', '- Changes in length and shape of actomyosin bundles affect mechanical forces', '- Myosin concentration affects edge tension, which then dictates cell movement', '- Mechanical feedback loop dictates myosin levels at interfaces, driving tension balance', '- Myosin 1c overexpression potentially alters load handling, affecting LR asymmetry in development (e.g., altered rotation of hindgut)', '- Tension nets satisfy mechanical equilibrium with sums of tension vectors forming geometric constraints', '- Law of sines applied to vertex and dual triangles dictates tension constraints', '- Isogonal deformations allow for free vertex movement without energy cost, maintaining equilibrium', '- Myosin-stall force relationships dictate edge tension increase beyond actomyosin bundle slipping point', '- Constraints on cell geometry dictated by equilibrium manifold of tension net triangulation', '- Cortical tensions', '- Myosin', '- Passive crosslinkers', '- Junctional proteins (e.g., actin, E-cadherin)', '- Tension triangles', '- Voronoi reference configuration', '- Myosin 1c (Myo1C)', '- Tension-induced myosin recruitment', '- Positive tension feedback', '- Passive viscoelastic relaxation through crosslinker turnover', '- Mechanical feedback influencing tension dynamics', '- Central cell interface', '- Cortical junctions', '- Quartet of cells in a periodic array', '- Tension triangulation (scaffold for cellular geometry)', '- Effective viscoelastic relaxation timescale (minutes)', '- Experimental timescales for tension dynamics matching observed behaviors', '- Remodeling time (τp) for passive tension', '- Tension on cell-cell interfaces influences cell shape and vertex angles.', '- Myosin redistribution affects tension dynamics, leading to cell intercalation.', '- Positive tension feedback causes extension or collapse based on initial tensions.', '- Myosin 1c overexpression affects left-right (LR) asymmetry by altering mechanical forces during development.', '- Force balance at cell vertices dictates interface angles.', '- Tension dynamics reside in mechanical feedback, not constitutive elasticity relations.', '- Shape and deformation of cell arrays determined by tension triangulation and isogonal deformation.', '- The development involves mechanical forces where cortical tensions and myosin recruitment play central roles.', '- Tension feedback alters interface dynamics, affecting cellular rearrangement and intercalation.', '- A minimal model predicts the behavior of active and passive tensions, with influences from internal cell structures like myosin contractility.', '- Overexpression of Myo1C perturbs normal mechanical balance within cells.', '- The redistribution of myosin and  ...

# %%
unique_items = list(set(elements))
print(len(unique_items))
# Out:
# 394

# %%
from collections import Counter
from difflib import SequenceMatcher

# Example input: long list (abbreviated for runtime demonstration)
long_list = elements

# Option 1: Remove exact duplicates, preserving order
seen = set()
unique_ordered = []
for item in long_list:
    if item not in seen:
        seen.add(item)
        unique_ordered.append(item)

# Option 2: Group near-duplicates using string similarity
def group_similar_items(items, threshold=0.90):
    groups = []
    used = set()
    for i, item in enumerate(items):
        if i in used:
            continue
        group = [item]
        used.add(i)
        for j in range(i + 1, len(items)):
            if j in used:
                continue
            similarity = SequenceMatcher(None, item.lower(), items[j].lower()).ratio()
            if similarity >= threshold:
                group.append(items[j])
                used.add(j)
        groups.append(group)
    return groups

near_duplicate_groups = group_similar_items(unique_ordered)

#import ace_tools as tools; tools.display_dataframe_to_user(name="Near-Duplicate Groups", dataframe={"Group": near_duplicate_groups})

#print(near_duplicate_groups)

# Merge duplicates by taking the first element in each group and replacing the others
merged_values = []
replacements = {}

for group in near_duplicate_groups:
    if len(group) > 1:
        canonical = group[0]
        for duplicate in group[1:]:
            replacements[duplicate] = canonical

# Apply replacements to the original list
merged_list = []
for item in elements:
    merged_list.append(replacements.get(item, item))

# Remove exact duplicates after merging
elements = list(set(merged_list))
# Out:
# [['- Cells (constituting the 2D array, each represented as polygons)'], ['- Actomyosin bundles (mechanically coupled to each cell edge)'], ['- Adherens junctions (connecting actomyosin bundles)'], ['- Vertices (representing nodes formed by cell edges)'], ['- Myosin motors (influencing contraction of actomyosin bundles)'], ['- Cadherin dimers (crosslinking actomyosin cables at interfaces)'], ['- Tension (Tij) changes with edge length (r_ij) and actomyosin state'], ['- Apical pressure (pα) changes with cortical area (dAα)'], ['- Mechanical coupling of actomyosin bundles via cadherin'], ['- Myosin recruitment influenced by internal strain rate'], ['- Feedback mechanism affecting myosin distribution in response to mechanical load'], ['- Balance of mechanical forces to achieve equilibrium'], ['- 2D plane (representing the array of cells)'], ['- Tension plane (a conceptual triangulation to illustrate tension vectors)'], ['- Cell interfaces (where actomyosin bundles exert force)'], ['- Vertex as nodes in the cellular meshwork'], ['- Developmental stages of the hindgut'], ['- Dynamics of tension network relaxation over time with timescales determined by friction (ν)'], ['- Relative timescales of myosin recruitment versus mechanical relaxation'], ['- Vertex dynamics influence tension vector placement and shape'], ['- Changes in length and shape of actomyosin bundles affect mechanical forces'], ['- Myosin concentration affects edge tension, which then dictates cell movement'], ['- Mechanical feedback loop dictates myosin levels at interfaces, driving tension balance'], ['- Myosin 1c overexpression potentially alters load handling, affecting LR asymmetry in development (e.g., altered rotation of hindgut)'], ['- Tension nets satisfy mechanical equilibrium with sums of tension vectors forming geometric constraints'], ['- Law of sines applied to vertex and dual triangles dictates tension constraints'], ['- Isogonal deformations allow for free vertex movement without energy cost, maintaining equilibrium'], ['- Myosin-stall force relationships dictate edge tension increase beyond actomyosin bundle slipping point'], ['- Constraints on cell geometry dictated by equilibrium manifold of tension net triangulation'], ['- Cortical tensions'], ['- Myosin'], ['- Passive crosslinkers'], ['- Junctional proteins (e.g., actin, E-cadherin)'], ['- Tension triangles'], ['- Voronoi reference configuration'], ['- Myosin 1c (Myo1C)', '- Myosin 1c (Myo1c)'], ['- Tension-induced myosin recruitment'], ['- Positive tension feedback'], ['- Passive viscoelastic relaxation through crosslinker turnover'], ['- Mechanical feedback influencing tension dynamics'], ['- Central cell interface'], ['- Cortical junctions'], ['- Quartet of cells in a periodic array'], ['- Tension triangulation (scaffold for cellular geometry)'], ['- Effective viscoelastic relaxation timescale (minutes)'], ['- Experimental timescales for tension dynamics matching observed behaviors'], ['- Remodeling time (τp) for passive tension'], ['- Tension on cell-cell interfaces influences cell shape and vertex angles.'], ['- Myosin redistribution affects tension dynamics, leading to cell intercalation.'], ['- Positive tension feedback causes extension or collapse based on initial tensions.'], ['- Myosin 1c overexpression affects left-right (LR) asymmetry by altering mechanical forces during development.'], ['- Force balance at cell vertices dictates interface angles.'], ['- Tension dynamics reside in mechanical feedback, not constitutive elasticity relations.'], ['- Shape and deformation of cell arrays determined by tension triangulation and isogonal deformation.'], ['- The development involves mechanical forces where cortical tensions and myosin recruitment play central roles.'], ['- Tension feedback alters interface dynamics, affecting cellular rearrangement and intercalation.'], ['- A minimal model predicts the behavior of active and passive tensions, with influences from internal cell structures like my ...

# %%
# Print or use the sampled elements
#for i, item in enumerate(sampled_elements, 1):
#    print(f"{i}. {item}")
# Out:
# 381

# %%
SYSTEM_PROMPT_ELEMENTS_COMPLETE = """
You are a developmental biology expert helping to extract all relevant mechanistic, molecular, and morphological elements described in a text about Drosophila hindgut morphogenesis. 
Your task is to read the full text, examine a provided list of extracted elements, and evaluate whether it is complete. 
If any relevant elements (e.g., proteins, structures, interactions, cellular events, mechanisms, stages, forces) are mentioned in the text but missing from the list, identify and list them clearly.
"""

USER_PROMPT_ELEMENTS_COMPLETE = """
Here is the text describing the biological process:

{excerpt}

Below is the current list of identified elements:

{elements_string}

Is this list of elements comprehensive based on the text? If not, what elements are missing? Please provide the missing elements in a clean list.
"""

# %%
additional_elements = []
for n in range(len(papers)):
    title, text = list(papers.keys())[n], list(papers.values())[n]
    excerpt = sample_text(text, 10000)
    sampled_elements = random.sample(elements, min(100, len(elements)))
    elements_string = "\n".join(f"- {el}" for el in sampled_elements)
    sys_msg = SYSTEM_PROMPT_ELEMENTS_COMPLETE
    usr_msg = USER_PROMPT_ELEMENTS_COMPLETE.format(excerpt=excerpt, elements_string=elements_string)
    add_elem = ask(sys_msg, usr_msg)
    print(add_elem)
    additional_elements.append(add_elem)
# Out:
# Upon reviewing the text, there are several additional elements mentioned that are not included in the current list. Below is the list of missing elements:
#
# 1. Cortical tension
# 2. Adherens junctions
# 3. Friction (ν) as a factor in the timescale of mechanical relaxation
# 4. Triangulation of tension plane
# 5. Actomyosin bundles
# 6. Force balance at vertices
# 7. Tension vectors (Tij, Tik, Til)
# 8. Myosin recruitment based on mechanical feedback
# 9. Intrinsic variables representing actomyosin and cadherin interface state
# 10. Elastic form of tension, Tij = K(rij − ℓij)
# 11. Walking kernel W(x) responsible for myosin activity
# 12. Stall force Ts and its impact on the actomyosin bundle
# 13. Load per myosin and its physiological effects
# 14. Isogonal modes and deformations
# 15. Conformational changes such as 'isogonal breathing mode'
# 16. Compatibility constraint χα = 1 for cell geometry and tension balance
# 17. Displacement (δri) dependent on equilibrium state parameters
# 18. Geometry implications from dual triangulation
# 19. Isogonal soft modes and their excitation
# 20. Mechanical equilibrium manifold and its properties
#
# These elements provide important context to the mechanical and dynamic processes described in the text and should be included in the comprehensive list.
# The provided text primarily discusses elements related to cell mechanics, tension dynamics, and geometric transformations during tissue morphogenesis, particularly in Drosophila or similar developmental contexts. The text focuses on concepts like isogonal shear, Delaunay triangulations, and the behavior of tension triangles rather than any specific proteins or traditional molecular pathways.
#
# Here are some missing or additional relevant elements extracted from the text:
#
# 1. Isogonal shear
# 2. Cell-level shear modulus
# 3. Tissue-level shear modulus
# 4. Cortical tensions
# 5. Isogonal deformation
# 6. Pure shear
# 7. Tension vectors and their arrangement
# 8. Isogonal displacement field
# 9. Linear gradient in the tension space
# 10. Quadratic isogonal potential
# 11. Force balance equations in tissue
# 12. Symmetric lattice of tension triangles
# 13. Mechanosensitive feedback loop for tension dynamics
# 14. Passive tension at vertex junctions
# 15. Elastic energy based on cell shape tensor
# 16. Cortical area changes affecting apical pressure
# 17. Intracellular tension dynamics
# 18. Tension triangulation
# 19. Random Delaunay triangulation
# 20. Marginalized angle distribution
#
# These elements reflect specific mechanical and geometric concepts that are part of the broader study of cell and tissue morphogenesis in biological systems. The focus is on modeling the interactions of tension, shear, and deformation in shaping cellular arrangements and tissues, which appears to be central to the description provided in the text.
# The provided list is comprehensive regarding typical biological elements involved in hindgut morphogenesis in Drosophila. However, a few specific elements and concepts described in the text were not included in the list. Here are the missing elements and concepts:
#
# 1. **Vertex Model Dynamics**: The text extensively describes the use of a vertex model with active junctions to simulate tissue dynamics. This concept was not explicitly listed.
#
# 2. **Mechanical Anisotropy**: The generation of anisotropy by applying forces to boundary vertices was described but not listed.
#
# 3. **T1 Transitions**: Details of T1 transition implementations and their effects, such as junction length criteria and forces involved in vertex stability, were described but not listed.
#
# 4. **Myosin Redistribution**: While myosin distribution was mentioned, the specific redistribution process during T1 transitions was detailed in the text but not highlighted in the list.
#
# 5. **Topological Texture Change (Tensor)**: Explained specifically in the context of T1 transitions as a tensor calculating cell contact changes over time.
#
# 6. **Statistical Continuum Tensors**: The text describes statistical counterparts of discrete tensor analysis—specifically statistical strain (U), velocity gradient (V), and topological rearrangements rate (P) tensors—to link discrete model descriptions to continuum mechanics, which wasn't detailed in the list.
#
# 7. **Voronoi Tessellation**: The method used to design the initial random-shaped cell patch was detailed but not explicitly mentioned in the list.
#
# 8. **Force Dynamics and Equilibrium**: The concept of forces reaching mechanical equilibrium pre- and post-activation was described but not included as a mechanistic element.
#
# 9. **Corotational Derivative**: Used in the text in the context of integrating velocity gradient contributions over time, which is an important concept in computational simulations for capturing strain dynamics accurately.
#
# 10. **Hexagonal Lattice Orientation**: The choice of lattice orientation relative to applied force was mentioned and is relevant for understanding simulation setup, but not included in the list explicitly.
#
# By adding these elements, the list would more accurately reflect the comprehensive mechanisms and interactions described in the text regarding Drosophila hindgut morphogenesis.
# The list of extracted elements is not comprehensive. Below are the missing elements based on the provided text:
#
# 1. **DAAM and Myo1D co-localization** - Localization of DAAM and Myo1D at the membrane and in puncta, especially in genitalia and hindgut LR organizers.
# 2. **DE-cadherin association** - DAAM and Myo1D co-localize with DE-cadherin in the hindgut LR organizer.
# 3. **TARGET method** - Used to determine the temporal requirement for myo1D and DAAM expression.
# 4. **Developmental timing (days 5-6 of Drosophila development)** - Specific time window required for DAAM and Myo1D expression before genitalia rotation.
# 5. **Abd-B regulation of DAAM** - Abd-B controls DAAM expression in the genitalia LR organizer, influencing sinistral and dextral development pathways.
# 6. **Tec29 as an interactor** - Tec29 interacts with DAAM for LR asymmetry and acts as an enhancer of DAAM function.
# 7. **Chic (Profilin) interaction with DAAM** - Chic interacts with DAAM genetically for LR asymmetry.
# 8. **fli (gelsolin family protein)** - Regulates DAAM activity and acts as a regulator of LR asymmetry.
# 9. **Genetic interaction among DAAM, Tec29, and chic** - These elements work together to control laterality in Drosophila.
# 10. **Myo1C role in sinistral twisting** - Though Myo1C typically does not affect LR asymmetry, its overexpression results in sinistral twisting.
# 11. **Interaction of Myo1D and DAAM** - DAAM is crucial for de novo LR asymmetry induced by Myo1D.
# 12. **Spatial organization in hindgut looping** - Involves DAAM function in hindgut rotation and looping defects.
# 13. **Co-immunoprecipitation experiments** - Indicates protein complex formation between Myo1D and DAAM.
# 14. **Suppression of myo1D and myo1C phenotypes by DAAM-RNAi** - Demonstrates the role of DAAM in twisting phenomena induced by Myo1D and Myo1C.
# 15. **Enhancement effects of DAAM overexpression** - Co-expression of DAAM-PD enhances twisting phenotype exerted by Myo1D or Myo1C.
#
# These elements are crucial to fully understanding the mechanistic and molecular aspects described in the hindgut morphogenesis text.
# The current list of identified elements is not comprehensive based on the text provided. Here are the missing elements from the text:
#
# 1. Myo1D's role in cilia orientation within Kupffer's vesicle (KV).
# 2. Circular counter-clockwise fluid flow in KV promoting left-right asymmetry.
# 3. Chaotic flow in KV of Myo1D mutant embryos.
# 4. Altered cilia orientation in Myo1D mutants causing laterality defects.
# 5. Kupffer's vesicle (KV) as a structure critical for left-right asymmetry.
# 6. Vangl2's opposing activity to Myo1D on cilia orientation.
# 7. Methodologies mentioned such as RNA in situ hybridization.
# 8. Tracking fluorescent beads in LRO (left-right organizer) to analyze fluid flow.
# 9. Use of pharmacological treatments such as IBMX, Forskolin, and Ouabain in experiments.
# 10. Use of primary antibodies for immunohistochemistry (e.g., ZO-1, Acetylated Tubulin, γ-Tubulin).
# 11. Arl13b-GFP RNA microinjection for labeling motile cilia.
# 12. Spaw expression analysis in genetic interaction experiments.
# 13. Role of Myo1D mutation in causing chaotic LRO flow.
# 14. Kupffer's vesicle (KV) structure and its relation to left-right asymmetry.
# 15. Use of ImageJ scripts for analyzing ciliary orientation and flow dynamics.
#
# These elements are integral to understanding the mechanistic and structural aspects of Drosophila hindgut morphogenesis as described in the text.
# Upon reviewing the text, the current list of elements extracted appears to be comprehensive, but there are some additional elements from the text that should also be considered. Here is a list of missing elements:
#
# 1. Myo31DF binds to actin in an ATP-dependent manner.
# 2. Co-localization of Myo31DF and the actin cytoskeleton in cultured Drosophila S2 cells.
# 3. GFP-tagged Myo31DF (Myo31DF-GFP) used for localization studies.
# 4. Moesin as an actin-binding protein affecting actin filament distribution.
# 5. Rho GTPase family proteins (Rho, Rac, Cdc42) that regulate actin cytoskeleton organization and influence LR defects.
# 6. RNA interference (RNAi) as a method for gene knockdown in functional studies.
# 7. Phenocritical period for inducing left-right defects through Myo31DF RNAi and GFP–moesin misexpression.
# 8. Expression of dominant-negative Rho, affecting actin cytoskeleton and LR defects.
# 9. Intercalation of epithelial cells coinciding with left-handed rotation of the hindgut.
# 10. Antagonistic functions of Myo31DF and Myo61F in left-right asymmetry.
# 11. Experiments employing UAS-Gal4 system to control gene expression.
# 12. Use of NP2432 driver line for tissue-specific expression studies.
# 13. Time-lapse analysis to demonstrate cell rearrangement during asymmetry development.
# 14. Sinistral gene comparison in Drosophila and freshwater snail Limnea.
# 15. Overexpression of Myo61F resulting in organ inversion.
# 16. By- and pros expression affects actin filament distribution in the hindgut.
#
# These elements provide additional relevant mechanistic and molecular insights into the described process of hindgut morphogenesis in Drosophila.
# The list of identified elements is missing some relevant details that are present in the text. Here are the missing elements:
#
# 1. **Counter-clockwise (ccw) and Clockwise (cw) Boundaries:** Describes the rotational direction of boundaries during hindgut morphogenesis.
# 2. **Leftward Tilt of Cell Axes:** Initial tilt of cell axes to the left before starting the twist.
# 3. **Cell Intercalation:** Change in cell arrangement during lateral rotation, contributing to hindgut morphogenesis.
# 4. **3D Vertex Model:** A model developed to simulate hindgut morphogenesis dynamics in 3D space allowing for the movement of vertices.
# 5. **Anisotropic Contraction of Edges:** Mechanism through which cell chirality is achieved in simulations.
# 6. **Relaxation and Activity Phases:** Simulation phases where structural changes occur.
# 7. **Left-Handed Screw Formation:** Result of the morphogenetic twist in the model.
# 8. **Cell Sliding:** Dynamic process driving hindgut rotation associated with the shift in relative positions of cells.
# 9. **Mechanical Distinction between Cell Chirality Loss and Cell Sliding:** A finding in simulations indicating separate processes.
# 10. **Time Lag Between Cell Deformation and Cell Sliding:** Observed sequence in the model showing different processes.
# 11. **Unsupervised Chirality Loss:** Indicates that chirality loss can occur independently of rotation or cell sliding.
# 12. **Vertex Fixation Simulation:** A control experiment to identify the effect of rotation on chirality loss.
#
# These elements provide a more complete understanding of the morphogenetic processes and mechanisms described in the text.
# The provided list of elements is missing some key mechanistic, molecular, and morphological aspects described in the text about Drosophila hindgut morphogenesis. Here are the missing elements:
#
# 1. **Actin Cytoskeleton**: The role of the actin cytoskeleton in cell chirality and LR asymmetric development is mentioned but not listed.
# 2. **F-Actin**: Mentioned as part of the conserved elements contributing to LR asymmetry.
# 3. **Intrinsic Chirality of Cilia**: The concept of intrinsic chirality of structures such as nodal cilia that have an important implication for asymmetric development.
# 4. **Nodal Flow**: The leftward flow of extra-embryonic fluid induced by cilia rotation.
# 5. **Apical-Basal Polarity**: Hindgut epithelial cells possess apical-basal polarity.
# 6. **Chirality of Cells**: This intrinsic property of hindgut epithelial cells before rotation is not explicitly listed.
# 7. **Mechanical Force**: The influence of mechanical force on cell chirality as driven by Myo31DF.
# 8. **Rotation Direction**: Counterclockwise rotation of the hindgut is a crucial morphological event not specified.
# 9. **Computer Simulation**: Describes how computer simulation supports the role of cell chirality in hindgut rotation.
# 10. **LR Asymmetry Reversal in Myo31DF Mutants**: This specific role of Myo31DF mutation leading to reversed chirality and organ laterality.
# 11. **Neighboring Cell Influence**: Influence of neighboring cells on intrinsic cell chirality through mechanical interaction.
#
# These elements should be added to the list to ensure it comprehensively captures all relevant details from the text.
# The current list of identified elements is not comprehensive based on the text. Here are the missing elements:
#
# 1. **PCC Formation** - Polarized Cell Contractility is a cellular event crucial for LR asymmetry.
# 2. **Rho Family GTPases** - Including Rho1 and Rac1 involved in actin cytoskeleton organization and PCC formation.
# 3. **DE-Cad (DE-cadherin)** - A transmembrane protein involved in cell-cell adhesion and mechanistic roles in PCC formation.
# 4. **Overexpression of Dominant-Negative Rho1 or Rac1** - Disrupts the actin cytoskeleton and hinders PCC formation.
# 5. **Rab11-positive Recycling Endosomes** - Involved in DE-Cad recycling and affecting LR asymmetry.
# 6. **ZA (Zones of Adherens)** - Important in the context of DE-Cad localization.
# 7. **Genetic Mutations** - Such as shg (encoding DE-Cad) mutations that disrupt hindgut laterality.
# 8. **Centrosome Polarization** - Mechanistic role in the orientation of hindgut epithelial cells.
# 9. **Cell Boundary Angles** - Represent LR asymmetry in cellular structures.
# 10. **EPGFP-tagged Proteins** - Used for visualization and experimental manipulation of protein expressions in cells.
# 11. **Myo31DF (Myosin ID)** - Mentioned specifically with its role in LR bias reversal.
# 12. **Importance of Mosaic Analysis** - Demonstrating cell-autonomous effects of MyoID on DE-Cad distribution.
# 13. **Role of Cortical Tension** - Introduced by DE-Cad and MyoID in restricting cell boundary expansion.
# 14. **Simulated Models of PCC** - Used to understand the mechanisms underlying epithelial rotation.
# 15. **Apical-middle Cellular Localization** - Specifically for Rab11-positive endosomes, indicating subcellular compartmentalization.
# 16. **Screen for Mutations** - To identify genes involved in asymmetry and PCC formation like the shg mutation screen.
#
# These elements describe additional proteins, structures, interactions, and cellular events that are critical to the described process of Drosophila hindgut morphogenesis.
# The current list of elements is not comprehensive based on the text provided. Here are the missing elements:
#
# 1. Kupffer’s Vesicle (KV)
# 2. Laterality defects
# 3. Asymmetric expression of dand5
# 4. Nodal gene spaw
# 5. T-box transcription factor Ta (tbxta, also known as ntla)
# 6. Myogenic differentiation 1 (myod1)
# 7. Motile cilia
# 8. Acetylated tubulin staining for cilia
# 9. KV epithelial cells
# 10. Unidirectional fluid flow in KV
# 11. Vacuolar trafficking
# 12. Vacuole clearance and vacuole-like structures in KV
# 13. Lumen expansion in KV
# 14. Transmission electron microscopy
# 15. Directed vacuolar movement and fusion
# 16. Kv fluid flow measurement with FITC fluorescent microbeads
# 17. Failure of unidirectional KV fluid flow affecting LR patterning
# 18. Rock2b and non-muscle myosin II in AP asymmetry
# 19. Chemical inhibition of ion channels in KV formation
# 20. Cavities in KV for actomyosin activity and vacuolar movement
# 21. Filtration through contractile vacuoles
# 22. Apical membrane
#
# These elements add context and depth to the mechanistic, molecular, and morphological details described in the text.
# The provided list of elements extracted does not appear to be fully comprehensive based on the given text. Here are the missing elements relevant to Drosophila hindgut morphogenesis as described:
#
# 1. **Cell boundary contractions**
# 2. **Chirality**
# 3. **Anterior-posterior/distal-proximal anisotropy**
# 4. **Edge tension**
# 5. **Axial elongation**
# 6. **Tube rotation**
# 7. **Cell intercalation**
# 8. **MyoII (Myosin II)**
# 9. **zip (zipper)**
# 10. **Dominant-negative form of zip (DN-zip)**
# 11. **Spaghetti squash (sqh)**
# 12. **Myosin regulatory light chain (MRLC)**
# 13. **Ex vivo assay**
# 14. **Y-27632 (MyoII inhibitor)**
# 15. **Rho kinase**
# 16. **T3 to T1 cell junction remodeling/transition**
# 17. **Convergent extension**
#
# These elements were mentioned in the context of Drosophila hindgut morphogenesis and should be included to make the list more comprehensive.
# The list provided seems to focus on elements related to Drosophila hindgut morphogenesis and left-right asymmetry mechanisms. However, the text included additional elements related to cell proliferation and apoptosis that are part of the broader context of Drosophila development.
#
# Here are the missing elements from the text:
#
# 1. **Cell Competition**: A mechanism that eliminates cells with a reduced growth rate ("losers") compared to those with enhanced growth ("winners").
#
# 2. **Growth/Survival Factors**: Factors whose withdrawal can lead to physiological death via cell competition.
#
# 3. **Proliferation Signals**: Notably, Decapentaplegic (Dpp), Wingless (Wg), and Hedgehog (Hh) play roles in tissue growth and patterning.
#
# 4. **"Undead" Cells**: Cells that survive despite apoptotic signaling due to the prevention of death, leading to tissue overgrowth.
#
# 5. **Eiger (Egr)**: The Drosophila orthologue of mammalian TNF, involved in signaling for cell death and connected with the JNK pathway.
#
# 6. **Jun-NH2-Terminal-Kinase (JNK) Pathway**: Plays roles in apoptosis, the signaling associated with it, and in promoting growth, essential for cell death signaling.
#
# 7. **Reaper (rpr), Head Involution Defective (hid), Grim (RHG)**: Pro-apoptotic genes that promote activation of caspases.
#
# 8. **Caspases**: Dronc and Drice are mentioned as effectors of apoptosis.
#
# 9. **p53**: A stress-activated protein involved in the secretion of proliferative signals.
#
# 10. **Male vs. Female Genital Disc Growth**: Sex-specific differences in growth and cell death processes, regulated by genes such as hid.
#
# 11. **Genetic Mosaic Analysis**: Used to study the prevention or promotion of cell death in the genital disc growth context.
#
# 12. **Baculovirus Protein p35**: An anti-apoptotic protein used in experimental manipulation of cell death pathways.
#
# The list should be expanded to include these elements to comprehensively cover the mechanistic, molecular, and morphological aspects described in the text.
# The provided list of elements appears to be focused on hindgut development and Myosin-related processes in Drosophila and other organisms like zebrafish. However, based on the text's focus, several elements associated with cellular, molecular, and morphological features during zebrafish embryogenesis and organ development are missing. Here are the missing elements extracted from the described supplementary materials and context in the text:
#
# 1. Kupffer's Vesicle (KV) – An important organ in zebrafish for determining laterality.
# 2. Dorsal Forerunner Cells (DFCs) – Precursor cells that contribute to forming Kupffer's Vesicle.
# 3. Leftward fluid flow in KV – Establishes the direction of asymmetry.
# 4. Mesenchymal-to-epithelial transition in DFC/KV cells.
# 5. Ciliogenesis in KV and its impact on directional fluid flow.
# 6. Vortical beating pattern of cilia in KV.
# 7. Rosette-like structure of KV cells.
# 8. Timelapse imaging of cellular behaviors (proliferation, movement, clustering).
# 9. Cadherin2 as a molecular marker for cell-cell junctions in KV.
# 10. Fluid-ﬁlled lumen expansion in KV.
# 11. Distinct cell shape changes during anterior and posterior KV morphogenesis.
# 12. Role of fluid flow dynamics and ciliary motility in establishing left-right axis.
# 13. Counterclockwise directional fluid flow in the anterior region of KV.
# 14. Use of fluorescent microspheres to visualize fluid dynamics in KV.
# 15. Cell lineage tracing using Tg(dusp6:memGFP) and Tg(sox17:GFP-CAAX) transgenic zebrafish lines.
#
# These elements should be added to the list to capture the comprehensive description of zebrafish embryonic development and organogenesis mechanisms presented in the text.
# The provided list appears to cover many relevant aspects mentioned in the text; however, several specific elements and details from the text are missing from the list. Here's a list of those missing elements:
#
# 1. **Myo1D-HaloTag and Myo1C-HaloTag** - Specific constructs used to study the diffusion states of Myo1D and Myo1C.
#
# 2. **Diffusion States** - The fast, intermediate, and slow diffusion states of Myo1D and Myo1C.
#
# 3. **Myo1D and Myo1C Head and Tail Domains** - Examine their roles separately in governing diffusion properties.
#
# 4. **HMM (Hidden Markov Model)** - Used to determine the proportion of diffusion states.
#
# 5. **Actin-activated steady-state ATPase rate** - Myo1D exhibited a higher rate compared to Myo1C, linked to kinetic differences.
#
# 6. **MgATP release rate** - Related to Myo1D's higher efficiency in propulsion and vesicle transport compared to Myo1C.
#
# 7. **Vesicle transportation in vitro** - Myo1D is involved in efficient vesicle transport along F-actin, unlike Myo1C.
#
# 8. **Dextral vs. Sinistral Functions** - How Myo1C counteracts the dextral function of Myo1D.
#
# 9. **Lipid interactions** - Distinct affinities of Myo1D and Myo1C tail domains to specific lipids, impacting membrane dynamics.
#
# 10. **F-actin interaction** - The prolonged attachment of Myo1C to F-actin compared to Myo1D.
#
# 11. **Mechanochemical functions** - Referring to the Myo1D's F-actin propulsion capabilities.
#
# This list of missing elements focuses on the mechanistic and molecular aspects directly discussed in the text and are distinct from those already included in the provided list.
# The provided text is primarily a list of references and acknowledgments rather than a detailed description of Drosophila hindgut morphogenesis. However, I can distinguish a few missing potential elements related to the biological context that were mentioned within the references:
#
# 1. Forkhead/HNF-3 proteins - Mentioned in the references as involved in endoderm lineage and motor protein functions but not clearly listed.
# 2. Tinman and Bagpipe genes - Involvement in determining cell fates in Drosophila, essential for morphological development.
# 3. Rho GTPase and RhoGEF - Relevant for cell shape changes during gastrulation, mentioned in a reference.
# 4. Grain - A GATA transcription factor required for cell rearrangement during morphogenesis, as per reference.
# 5. JNK signaling - Mentioned in list but potentially linked to specific genes like raw in detailed references, which might need to be more specified.
#
# These elements might be worth exploring or understanding in the context of Drosophila hindgut morphogenesis as they could influence the genetic and morphological mechanisms underlying the process.

# %%
SYSTEM_PROMPT_PARSE_ADD_ELEMENTS = """
You are a helpful assistant that extracts scientific elements from technical biological or biophysical texts. 
Your job is to read the text and convert any listed or described biological or mechanical elements into a structured list of objects. 
Each object represents a single element with its name (include any associated description inside the name parameter).
"""

USER_PROMPT_PARSE_ADD_ELEMENTS = """
Read the following scientific text and extract all elements it lists or implies. Convert them into a structured list using the provided function. Each element should appear once with its name in a clean format.

The provided text primarily discusses elements related to cell mechanics, tension dynamics, and geometric transformations during tissue morphogenesis, particularly in Drosophila or similar developmental contexts.

{elems}
"""
elems_all = []
for elems in additional_elements:
    # convert to a list
    elements_func = ask_func(sys_msg, usr_msg, ELEM_FUNC)

    sys_msg = SYSTEM_PROMPT_PARSE_ADD_ELEMENTS
    usr_msg = USER_PROMPT_PARSE_ADD_ELEMENTS.format(elems=elems)
    elems_func = ask_func(sys_msg, usr_msg, ADD_ELEM_FUNC)

    elems_raw = parse_func_resp(elems_func, "element", ["name"])
    elems_all.extend(elems_raw)
    #elements = clean_elements(elements_raw)

# %%
print(len(elems_all))
print(len(elements))
# Out:
# 217
# 400

# %%
elements.extend(elems_all)
print(len(elements))
# Out:
# 617

# %%
num_batches = 10        # how many different samples to take
sample_size = 50        # number of elements per sample
output_file = "element_summaries.txt"
sys_prompt = """
You are a scientific summarizer and storyteller. 
Given a list of biological and mechanical elements involved in Drosophila hindgut morphogenesis, analyze and summarize the types of elements, 
the morphogenetic dimensions they span, and the kinds of developmental narratives they enable. 
Focus on their diversity, depth, and potential integration into causal and mechanistic explanations of development.
"""

# Create output file
with open(output_file, "w") as out:
    out.write("# Summary of Random Samples from Element List\n\n")

# Run the loop
for i in tqdm(range(num_batches), desc="Sampling and summarizing"):
    sampled = random.sample(elements, sample_size)
    formatted_elements = "\n".join(f"- {el}" for el in sampled)

    usr_prompt = f"""Here is a list of elements sampled from a larger library (>500 elements) involved in hindgut morphogenesis:

    {formatted_elements}

    Please:
    1. Summarize what these elements are and what they represent.
    2. Describe the dimensions of hindgut morphogenesis they help capture (e.g. mechanical forces, gene regulation, spatial organization, feedback loops).
    3. Comment on the types of developmental stories or causal narratives these elements allow us to tell (e.g. stories of tissue twisting, cellular rearrangement, molecular feedback).
    """
    try: 
        summary = ask(sys_prompt, usr_prompt)
        with open(output_file, "a") as out:
                out.write(f"\n\n## Batch {i+1}\n\n")
                out.write(summary)

        sleep(1.5)  # respectful pause
    except Exception as e:
        print(f"Error on batch {i+1}: {e}")
        continue
# Out:
# Sampling and summarizing: 100%|██████████| 10/10 [03:03<00:00, 18.40s/it]
